# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В нашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Наша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Обзор данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Обработка-пропусков-и-изменение-типа-данных" data-toc-modified-id="Обработка-пропусков-и-изменение-типа-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обработка пропусков и изменение типа данных</a></span><ul class="toc-item"><li><span><a href="#Столбец-'total_images'" data-toc-modified-id="Столбец-'total_images'-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Столбец 'total_images'</a></span></li><li><span><a href="#Столбец-'last_price'" data-toc-modified-id="Столбец-'last_price'-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Столбец 'last_price'</a></span></li><li><span><a href="#Столбец-'total_area'" data-toc-modified-id="Столбец-'total_area'-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Столбец 'total_area'</a></span></li><li><span><a href="#Столбец-'first_day_exposition'" data-toc-modified-id="Столбец-'first_day_exposition'-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Столбец 'first_day_exposition'</a></span></li><li><span><a href="#Столбец-'rooms'" data-toc-modified-id="Столбец-'rooms'-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>Столбец 'rooms'</a></span></li><li><span><a href="#Столбец-'ceiling_height'" data-toc-modified-id="Столбец-'ceiling_height'-2.1.6"><span class="toc-item-num">2.1.6&nbsp;&nbsp;</span>Столбец 'ceiling_height'</a></span></li><li><span><a href="#Столбец-'floors_total'" data-toc-modified-id="Столбец-'floors_total'-2.1.7"><span class="toc-item-num">2.1.7&nbsp;&nbsp;</span>Столбец 'floors_total'</a></span></li><li><span><a href="#Столбец-'floor'" data-toc-modified-id="Столбец-'floor'-2.1.8"><span class="toc-item-num">2.1.8&nbsp;&nbsp;</span>Столбец 'floor'</a></span></li><li><span><a href="#Столбец-'is_apartment'" data-toc-modified-id="Столбец-'is_apartment'-2.1.9"><span class="toc-item-num">2.1.9&nbsp;&nbsp;</span>Столбец 'is_apartment'</a></span></li><li><span><a href="#Столбец-'studio'" data-toc-modified-id="Столбец-'studio'-2.1.10"><span class="toc-item-num">2.1.10&nbsp;&nbsp;</span>Столбец 'studio'</a></span></li><li><span><a href="#Столбец-'open_plan'" data-toc-modified-id="Столбец-'open_plan'-2.1.11"><span class="toc-item-num">2.1.11&nbsp;&nbsp;</span>Столбец 'open_plan'</a></span></li><li><span><a href="#Столбец-'balcony'" data-toc-modified-id="Столбец-'balcony'-2.1.12"><span class="toc-item-num">2.1.12&nbsp;&nbsp;</span>Столбец 'balcony'</a></span></li><li><span><a href="#Столбец-'locality_name'" data-toc-modified-id="Столбец-'locality_name'-2.1.13"><span class="toc-item-num">2.1.13&nbsp;&nbsp;</span>Столбец 'locality_name'</a></span></li><li><span><a href="#Столбец-'living_area'-и-'kitchen_area'" data-toc-modified-id="Столбец-'living_area'-и-'kitchen_area'-2.1.14"><span class="toc-item-num">2.1.14&nbsp;&nbsp;</span>Столбец 'living_area' и 'kitchen_area'</a></span></li><li><span><a href="#Столбец--'days_exposition'" data-toc-modified-id="Столбец--'days_exposition'-2.1.15"><span class="toc-item-num">2.1.15&nbsp;&nbsp;</span>Столбец  'days_exposition'</a></span></li><li><span><a href="#Столбцы-'airports_nearest',-'cityCenters_nearest',-'parks_around3000',-'parks_nearest-ponds_around3000',-'ponds_nearest'" data-toc-modified-id="Столбцы-'airports_nearest',-'cityCenters_nearest',-'parks_around3000',-'parks_nearest-ponds_around3000',-'ponds_nearest'-2.1.16"><span class="toc-item-num">2.1.16&nbsp;&nbsp;</span>Столбцы 'airports_nearest', 'cityCenters_nearest', 'parks_around3000', 'parks_nearest ponds_around3000', 'ponds_nearest'</a></span></li><li><span><a href="#Поиск-дубликатов" data-toc-modified-id="Поиск-дубликатов-2.1.17"><span class="toc-item-num">2.1.17&nbsp;&nbsp;</span>Поиск дубликатов</a></span></li><li><span><a href="#Результат-предобработки-данных" data-toc-modified-id="Результат-предобработки-данных-2.1.18"><span class="toc-item-num">2.1.18&nbsp;&nbsp;</span>Результат предобработки данных</a></span></li></ul></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Цена-квадратного-метра" data-toc-modified-id="Цена-квадратного-метра-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Цена квадратного метра</a></span></li><li><span><a href="#День-недели,-месяц-и-год-публикации-объявления" data-toc-modified-id="День-недели,-месяц-и-год-публикации-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>День недели, месяц и год публикации объявления</a></span></li><li><span><a href="#Этаж-квартиры;-варианты-—-первый,-последний,-другой" data-toc-modified-id="Этаж-квартиры;-варианты-—-первый,-последний,-другой-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Этаж квартиры; варианты — первый, последний, другой</a></span></li><li><span><a href="#Соотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей" data-toc-modified-id="Соотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Соотношение жилой и общей площади, а также отношение площади кухни к общей</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Время-продажи-квартиры" data-toc-modified-id="Время-продажи-квартиры-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Время продажи квартиры</a></span></li><li><span><a href="#Зависимость-стоимости-от-различных-факторов" data-toc-modified-id="Зависимость-стоимости-от-различных-факторов-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Зависимость стоимости от различных факторов</a></span><ul class="toc-item"><li><span><a href="#Зависимость-цены-от-площади" data-toc-modified-id="Зависимость-цены-от-площади-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Зависимость цены от площади</a></span></li><li><span><a href="#Зависимость-цены-от-количества-комнат" data-toc-modified-id="Зависимость-цены-от-количества-комнат-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Зависимость цены от количества комнат</a></span></li><li><span><a href="#Зависимость-цены-от-удалённости-от-центра" data-toc-modified-id="Зависимость-цены-от-удалённости-от-центра-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Зависимость цены от удалённости от центра</a></span></li><li><span><a href="#Зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом" data-toc-modified-id="Зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом</a></span></li><li><span><a href="#Изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года.-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>Изучите зависимость от даты размещения: дня недели, месяца и года.</a></span></li></ul></li><li><span><a href="#Анализ-по-населенным-пунктам" data-toc-modified-id="Анализ-по-населенным-пунктам-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Анализ по населенным пунктам</a></span></li><li><span><a href="#Поиск-центральной-зоны" data-toc-modified-id="Поиск-центральной-зоны-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Поиск центральной зоны</a></span></li><li><span><a href="#Сравнение-центра-города-со-всеми-объявлениями-в-городе" data-toc-modified-id="Сравнение-центра-города-со-всеми-объявлениями-в-городе-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Сравнение центра города со всеми объявлениями в городе</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# ## Обзор данных

# %%
#импорт необходимых библиотек
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# отображение всех строк
pd.set_option('display.max_rows', None)

# %%
# открываем файл с данными, сохраняем в df, смотрим первые строки
df = pd.read_csv('real_estate_data.csv', sep = '\t')
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# 1          11.0      2.0   посёлок Шушары           12817.0
# 2           8.3      0.0  Санкт-Петербург           21741.0
# 3           NaN      0.0  Санкт-Петербург           28098.0
# 4          41.0      NaN  Санкт-Петербург           31856.0
#
#   cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0             16028.0               1.0          482.0               2.0
# 1             18603.0               0.0            NaN               0.0
# 2             13933.0               1.0           90.0               2.0
# 3              6800.0               2.0           84.0               3.0
# 4              8098.0               2.0          112.0               1.0
#
#    ponds_nearest  days_exposition
# 0          755.0              NaN
# 1            NaN             81.0
# 2          574.0            558.0
# 3          234.0            424.0
# 4           48.0            121.0
#
# [5 rows x 22 columns]

# %%
# смотрим последние строки
df.tail()
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 23694             3.7           5.0         73.3      3          NaN  ...
# 23695             NaN           5.0         38.0      4          NaN  ...
# 23696             NaN           3.0         29.7      1          NaN  ...
# 23697             3.0          17.0          NaN     12          NaN  ...
# 23698             2.5           5.0         12.3      1          NaN  ...
#
#        kitchen_area  balcony        locality_name  airports_nearest  \
# 23694         13.83      NaN      Санкт-Петербург           24665.0
# 23695          8.50      NaN                Тосно               NaN
# 23696           NaN      NaN     село Рождествено               NaN
# 23697         23.30      2.0      Санкт-Петербург           39140.0
# 23698          9.00      NaN  поселок Новый Учхоз               NaN
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 23694              4232.0               1.0          796.0               3.0
# 23695                 NaN               NaN            NaN               NaN
# 23696                 NaN               NaN            NaN               NaN
# 23697             10364.0               2.0          173.0               3.0
# 23698                 NaN               NaN            NaN               NaN
#
#        ponds_nearest  days_exposition
# 23694          381.0              NaN
# 23695            NaN             45.0
# 23696            NaN              NaN
# 23697          196.0            602.0
# 23698            NaN              NaN
#
# [5 rows x 22 columns]

# %%
# общая информация о таблице
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# parks_nearest           8079 non-null float64
# ponds_around3000        18181 non-null float64
# ponds_nearest           9110 non-null float64
# days_exposition         20518 non-null float64
# dtypes: bool(2), float64(14), int64(3), object(3)
# memory usage: 3.7+ MB

# %% [markdown]
# **Вывод**
#
# В таблице 22 столбца с разным типом данных. Согласно документации:
#
# * `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# * `balcony` — число балконов
# * `ceiling_height` — высота потолков (м)
# * `cityCenters_nearest` — расстояние до центра города (м)
# * `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
# * `first_day_exposition` — дата публикации
# * `floor` — этаж
# * `floors_total` — всего этажей в доме
# * `is_apartment` — апартаменты (булев тип)
# * `kitchen_area` — площадь кухни в квадратных метрах (м²)
# * `last_price` — цена на момент снятия с публикации
# * `living_area` — жилая площадь в квадратных метрах (м²)
# * `locality_name` — название населённого пункта
# * `open_plan` — свободная планировка (булев тип)
# * `parks_around3000` — число парков в радиусе 3 км
# * `parks_nearest` — расстояние до ближайшего парка (м)
# * `ponds_around3000` — число водоёмов в радиусе 3 км
# * `ponds_nearest` — расстояние до ближайшего водоёма (м)
# * `rooms` — число комнат
# * `studio` — квартира-студия (булев тип)
# * `total_area` — площадь квартиры в квадратных метрах (м²)
# * `total_images` — число фотографий квартиры в объявлении
#
# Все колонки описывают параметры продаваемой недвижимости: площадь, цена, этаж, сколько комнат, балконов, удалённость от центра, парков, водоёмов и аэропортов.
#
# В таблице 23699 строк. В столбцах есть пропуски. Предварительно можно утверждать, что данных достаточно для решения поставленной задачи.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Обработка пропусков и изменение типа данных

# %%
# подсчёт пропусков
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# В столбцах `ceiling_height`, `floors_total`, `living_area`, `is_apartment`, `kitchen_area`, `balcony`, `locality_name`, `airports_nearest`, `cityCenters_nearest`, `parks_around3000`, `parks_nearest`, `ponds_around3000`, `ponds_nearest`, `days_exposition` имеются пропуски, чтобы двигаться дальше, нужно устранить проблемы в данных.
#
# Рассмотрим все столбцы по порядку.

# %% [markdown]
# #### Столбец 'total_images'

# %%
# Смотрим уникальные значения
df['total_images'].value_counts().sort_index(ascending=True)
# Out:
# 0     1059
# 1      872
# 2      640
# 3      769
# 4      986
# 5     1301
# 6     1482
# 7     1521
# 8     1585
# 9     1725
# 10    1798
# 11    1362
# 12    1225
# 13    1015
# 14     986
# 15     948
# 16     761
# 17     650
# 18     642
# 19     603
# 20    1694
# 21      12
# 22       8
# 23      16
# 24       8
# 25       1
# 26       5
# 27       2
# 28       4
# 29       3
# 30       2
# 31       2
# 32       4
# 35       2
# 37       1
# 39       1
# 42       1
# 50       3
# Name: total_images, dtype: int64

# %% [markdown]
# В столбце нет пропусков, тип данных целочисленный, каких-либо аномальных значений нет.

# %% [markdown]
# #### Столбец 'last_price'

# %%
#для лучшего восприятия данных отключим научную нотацию чисел
pd.options.display.float_format = '{:.2f}'.format

# %%
# числовое описание столбца
df['last_price'].describe()
# Out:
# count       23699.00
# mean      6541548.77
# std      10887013.27
# min         12190.00
# 25%       3400000.00
# 50%       4650000.00
# 75%       6800000.00
# max     763000000.00
# Name: last_price, dtype: float64

# %% [markdown]
# Изменим тип данных на целочисленный.

# %%
# меняем тип данных
df['last_price'] = df['last_price'].astype('int')

# %%
# проверяем тип данных
df['last_price'].dtypes
# Out:
# dtype('int32')

# %% [markdown]
# По полученным данным видим, что в столбце есть сильно большое значение 763 миллиона и сильно маленькое значение 12190 рассмотрим данные детальнее.

# %%
# смотрим на гистограмме как часто встречаются аномальные значения. 
df.hist('last_price', bins=100, figsize=(12,4), range=(0, 600000));

# %%
df.hist('last_price', bins=100, figsize=(12,4), range=(600000, 60000000));

# %%
df.hist('last_price', bins=100, figsize=(12,4), range=(60000000, 770000000));

# %% [markdown]
# По графикам видим, что у нас имеются аномальные значения - выбросы. Их совсем  не много, но лучше будет их удалить, для того, чтобы иследование стало более точным. Оставим все, что >400тыс.руб и <300млн.р., остальное удалим.

# %%
# удаляем выбросы
df= df.loc[(df['last_price']>400000) & (df['last_price']<300000000)]
df.reset_index(inplace=True, drop=True)

# %%
# числовое описание столбца
df['last_price'].describe()
# Out:
# count       23693.00
# mean      6449746.85
# std       8517635.13
# min        430000.00
# 25%       3400000.00
# 50%       4650000.00
# 75%       6799000.00
# max     289238400.00
# Name: last_price, dtype: float64

# %%
# смотрим сколько строк осталось
df.shape
# Out:
# (23693, 22)

# %%
# смотрим общий график после удаления выбросов
df['last_price'].hist(figsize=(12,4), bins=100);

# %%
# смотрим квартиры стоимостью от 0 до 10 млн. 
df['last_price'].hist(range=(0,10000000),figsize=(12,4), bins=50);

# %% [markdown]
# Выбросы удалили, удалилось всего 6 строк, тип данных изменили - сделали его целочисленным. Пропусков в столбце нет.

# %% [markdown]
# По полученным данным видим, что больше всего квартир стоимостью примерно 3,8 млн. Чаще всего продаются квартиры по стоимости в диапозоне от 2 млн до 7 млн.

# %% [markdown]
# #### Столбец 'total_area'

# %%
# числовое описание столбца
df['total_area'].describe()
# Out:
# count   23693.00
# mean       60.25
# std        34.90
# min        12.00
# 25%        40.00
# 50%        52.00
# 75%        69.80
# max       631.20
# Name: total_area, dtype: float64

# %%
# смотрим общий график
df['total_area'].hist(figsize=(12,4), bins=100);

# %%
# смотрим квартиры площадью от 200 кв. метров до  600 
df.hist('total_area', bins=100, figsize=(12,4), range=(200, 600));

# %%
# смотрим квартиры площадью от 0 кв. метров до 100 
df['total_area'].hist(range=(0,100),figsize=(12,4), bins=100);

# %% [markdown]
# Аномальных значений не наблюдается, пропусков нет, со столбцом все в порядке он готов к дальнейшей работе. Тип данных не меняем, так как тут площадь  квартиры в кв. метрах.

# %% [markdown]
# Из полученных данных видим, что больше всего квартир с площадями 30-45 кв.м - это скорее всего 1 и 2 комнатные квартиры. Далее идут квартиры с площадью до 75 кв.м., скорее всего 3-4 комнатные квартиры. Также видим, что чем больше площадь, тем меньше квартир и, что квартиры меньше 30 кв.м тоже довольно редко встречаются. Вывод больше всего в продаже квартир общей площадь от 30-45 кв.м

# %% [markdown]
# #### Столбец 'first_day_exposition'

# %% [markdown]
# В столбце указана дата публикации объявления  о продаже квартиры, изменим тип данных на datetime. Пропусков в столбце нет.

# %%
# меняем тип данных
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# Тип данных изменили. По заданию нам необходимо добавить в таблицу три столбца с днем недели, месяцем и годом. Сделаем это ниже.

# %% [markdown]
# #### Столбец 'rooms'

# %%
# смотрим уникальные значения столбца
df['rooms'].value_counts().sort_index(ascending=True)
# Out:
# 0      197
# 1     8047
# 2     7939
# 3     5813
# 4     1180
# 5      325
# 6      105
# 7       57
# 8       12
# 9        8
# 10       3
# 11       2
# 14       2
# 15       1
# 16       1
# 19       1
# Name: rooms, dtype: int64

# %% [markdown]
# Видим, что у нас есть значение "0" комнат, возможно так указали квартиры студии? Проверим это.

# %%
# смотрим сколько студий с "0" комнат
df.query('rooms == 0')['studio'].value_counts()
# Out:
# True     138
# False     59
# Name: studio, dtype: int64

# %% [markdown]
# В 138 строках из 197  квартиры студии, у них всего 1 жилая комната без кухни, заменим значение "0", в таких квартирах на "1"

# %%
# меняем значение "0" комнтат в студиях на "1"
df.loc[(df['rooms']==0) & (df['studio']==True), 'rooms'] = 1

# %% [markdown]
# Осталось 59 строк  со значение "0" комнат, рассмотрим их по площади.

# %%
df.query('rooms == 0')['total_area'].value_counts().sort_index(ascending=True)
# Out:
# 16.00     1
# 20.00     1
# 21.00     1
# 22.00     1
# 22.50     1
# 23.00     1
# 23.06     1
# 23.98     1
# 24.00     5
# 24.20     1
# 25.00     7
# 25.20     1
# 25.27     1
# 25.41     1
# 25.90     1
# 26.00     3
# 26.10     2
# 26.80     1
# 27.00     2
# 27.10     1
# 27.30     2
# 27.32     1
# 27.50     1
# 27.70     1
# 28.00     2
# 28.01     1
# 28.05     1
# 28.20     1
# 28.30     1
# 28.50     1
# 29.00     2
# 30.00     1
# 30.50     1
# 31.00     1
# 31.10     1
# 32.30     1
# 34.00     1
# 34.40     1
# 35.00     2
# 42.63     1
# 371.00    1
# Name: total_area, dtype: int64

# %% [markdown]
# Видим, что у нас все значения не более 43 кв. метров - будем считать, что это однакомнатные квартиры, заменим в таких квартирах "0" на "1"

# %%
# меняем значение "0" на "1" в квартирах с площадью менее 43кв. метров.
df.loc[(df['rooms']==0) & (df['total_area']<43), 'rooms'] = 1

# %% [markdown]
# Также у нас есть 1 квартира 371 кв. метр, возможно опечатка рассмотрим  строку  детальнее.

# %%
# смотрим квартиру со значение "0" комнат  и площадью 371 кв. метр
df.query('rooms == 0 and total_area == 371')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 19387             5    71000000      371.00           2018-07-26      0
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 19387            3.57          7.00          nan      6          NaN  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 19387           nan      nan  Санкт-Петербург          25257.00
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 19387             6060.00              1.00         761.00              1.00
#
#        ponds_nearest  days_exposition
# 19387         584.00            90.00
#
# [1 rows x 22 columns]

# %% [markdown]
# Квартира по стоимости дорогая, с высокими потолками, в многоэтажном доме, определить количество комнат по каким-либо параметрам  не возможно, удалим эту строку как аномальную.

# %%
# удаляем аномальную строку
df.drop(df.loc[(df['rooms']==0) & (df['total_area']==371)].index,inplace=True, axis=0)

# %%
# ещё раз проверяем уникальные значения
df['rooms'].value_counts()
# Out:
# 1     8243
# 2     7939
# 3     5813
# 4     1180
# 5      325
# 6      105
# 7       57
# 8       12
# 9        8
# 10       3
# 14       2
# 11       2
# 15       1
# 19       1
# 16       1
# Name: rooms, dtype: int64

# %%
# числовое описание столбца
df['rooms'].describe()
# Out:
# count   23692.00
# mean        2.08
# std         1.06
# min         1.00
# 25%         1.00
# 50%         2.00
# 75%         3.00
# max        19.00
# Name: rooms, dtype: float64

# %%
# Смотрим  график
df['rooms'].hist(figsize=(12,4), bins=100);

# %% [markdown]
# Видим, что самые популярные квартиры 1-2 комнатные, далее видим, что чем больше комнат, тем меньше таких  квартир.

# %% [markdown]
# Некорректное значение "0" заменили на  подходящее, удалили строку, в которой произвести замену не удалось, пропусков нет, со столбцом все в порядке он готов к дальнейшей работе.

# %% [markdown]
# #### Столбец 'ceiling_height'

# %%
#  смотрим уникальные значения
df['ceiling_height'].value_counts().sort_index(ascending=True)
# Out:
# 1.00         1
# 1.20         1
# 1.75         1
# 2.00        11
# 2.20         1
# 2.25         1
# 2.30         4
# 2.34         1
# 2.40        23
# 2.45        15
# 2.46         2
# 2.47         3
# 2.48         8
# 2.49         1
# 2.50      3515
# 2.51        34
# 2.52        79
# 2.53        67
# 2.54        83
# 2.55       980
# 2.56       139
# 2.57       103
# 2.58        63
# 2.59        14
# 2.60      1646
# 2.61         5
# 2.62        14
# 2.63        13
# 2.64        81
# 2.65       676
# 2.66        17
# 2.67        36
# 2.68        23
# 2.69         2
# 2.70      1574
# 2.71        13
# 2.72        31
# 2.73        35
# 2.74        28
# 2.75       909
# 2.76        60
# 2.77        61
# 2.78        51
# 2.79        10
# 2.80       992
# 2.81         9
# 2.82        18
# 2.83        15
# 2.84        19
# 2.85       101
# 2.86         6
# 2.87        10
# 2.88        12
# 2.89         1
# 2.90       164
# 2.91         4
# 2.92         9
# 2.93         4
# 2.94         3
# 2.95        47
# 2.96         5
# 2.97         4
# 2.98         2
# 2.99         1
# 3.00      1112
# 3.01         6
# 3.02         8
# 3.03         4
# 3.04         6
# 3.05        46
# 3.06        11
# 3.07        11
# 3.08        14
# 3.09         4
# 3.10       203
# 3.11         7
# 3.12        17
# 3.13        11
# 3.14         7
# 3.15        57
# 3.16         7
# 3.17         5
# 3.18        11
# 3.20       277
# 3.21         3
# 3.22         3
# 3.23         4
# 3.24         4
# 3.25        36
# 3.26         6
# 3.27         6
# 3.28         6
# 3.29         1
# 3.30       141
# 3.31         3
# 3.32         6
# 3.33        10
# 3.34         3
# 3.35        16
# 3.36         5
# 3.37         4
# 3.38         8
# 3.39         1
# 3.40        91
# 3.42         1
# 3.43         1
# 3.44         1
# 3.45         9
# 3.46         4
# 3.47         6
# 3.48         1
# 3.49         2
# 3.50       129
# 3.51         2
# 3.52         3
# 3.53         3
# 3.54         6
# 3.55        18
# 3.56         5
# 3.57         2
# 3.58         1
# 3.59         1
# 3.60        36
# 3.62         2
# 3.63         3
# 3.65         4
# 3.66         3
# 3.67         3
# 3.68         1
# 3.69         1
# 3.70        30
# 3.75         8
# 3.76         1
# 3.78         3
# 3.80        20
# 3.82         1
# 3.83         1
# 3.84         1
# 3.85         2
# 3.86         2
# 3.87         1
# 3.88         1
# 3.90        14
# 3.93         1
# 3.95         8
# 3.98         1
# 4.00        39
# 4.06         1
# 4.10         3
# 4.14         1
# 4.15         1
# 4.19         2
# 4.20        10
# 4.25         1
# 4.30         1
# 4.37         1
# 4.40         3
# 4.45         2
# 4.50         7
# 4.65         1
# 4.70         2
# 4.80         1
# 4.90         1
# 5.00         1
# 5.20         1
# 5.30         2
# 5.50         1
# 5.60         1
# 5.80         1
# 6.00         1
# 8.00         3
# 8.30         1
# 10.30        1
# 14.00        1
# 20.00        1
# 22.60        1
# 24.00        1
# 25.00        7
# 26.00        1
# 27.00        8
# 27.50        1
# 32.00        2
# 100.00       1
# Name: ceiling_height, dtype: int64

# %% [markdown]
# Из полученных данных видим, что у нас имеются  аномальные значения высоты потолков. Значение до 2 метров слишком малы,  стандарт потолков около 2,5 метров. Значения "1","1.2","1.75","10,3","14", "100"  не корректные, на опечатки не похожи, таких значений не много - всего по одному, удалим их.
#
# Также наблюдаются значения больше 20 метров, предположительно это опечатки и там где значение 20 - это 2 метра, 25 = 2,5 и т.д.  Расммотрим эти значения детальнее.

# %%
# смотрим срез некорректных значений
df.query('ceiling_height >= 20 and ceiling_height < 35')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 355              17     3600000       55.20           2018-07-12      2
# 3147             14     2900000       75.00           2018-11-12      3
# 4642              0     4300000       45.00           2018-02-01      2
# 4875              7     3000000       25.00           2017-09-27      1
# 5075              0     3850000       30.50           2018-10-03      1
# 5245              0     2500000       54.00           2017-10-13      2
# 5668              4     4400000       50.00           2017-08-08      2
# 5806             17     8150000       80.00           2019-01-09      2
# 6245              6     3300000       44.40           2019-03-25      2
# 9377              5     3950000       42.00           2017-03-26      3
# 10771             8     3800000       58.00           2017-10-13      2
# 11283             0     1950000       37.00           2019-03-20      1
# 14379             9     1700000       35.00           2015-12-04      1
# 17491            15     6700000       92.90           2019-02-19      3
# 17852             1     3900000       56.00           2017-12-22      3
# 18540             6     3750000       43.00           2019-03-18      2
# 20472            11     8000000       45.00           2017-07-18      1
# 20501            12     5950000       60.00           2018-02-19      2
# 21371            19     4900000       42.00           2017-04-18      1
# 21818            20     2450000       44.00           2019-02-12      2
# 22330            19     9999000       92.40           2019-04-05      2
# 22932            14     4000000       98.00           2018-03-15      4
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 355             25.00          5.00        32.00      2        False  ...
# 3147            32.00          3.00        53.00      2          NaN  ...
# 4642            25.00          9.00        30.00      2          NaN  ...
# 4875            27.00         25.00        17.00     17          NaN  ...
# 5075            24.00          5.00        19.50      1         True  ...
# 5245            27.00          5.00        30.00      3          NaN  ...
# 5668            26.00          9.00        21.30      3          NaN  ...
# 5806            27.00         36.00        41.00     13          NaN  ...
# 6245            25.00          5.00        31.30      5          NaN  ...
# 9377            25.00          5.00        30.00      2          NaN  ...
# 10771           27.00         10.00        30.10      3        False  ...
# 11283           25.00          5.00        17.00      4        False  ...
# 14379           25.00          5.00        20.00      2        False  ...
# 17491           20.00         17.00        53.20     14          NaN  ...
# 17852           27.00          5.00        33.00      4        False  ...
# 18540           25.00          5.00        29.00      3        False  ...
# 20472           27.00          4.00        22.00      2          NaN  ...
# 20501           22.60         14.00        35.00     11          NaN  ...
# 21371           27.50         24.00        37.70     19        False  ...
# 21818           27.00          2.00        38.00      2        False  ...
# 22330           32.00          6.00        55.50      5        False  ...
# 22932           27.00          2.00        73.00      2         True  ...
#
#        kitchen_area  balcony                    locality_name  \
# 355             nan     2.00                          Гатчина
# 3147           8.00      nan                           Волхов
# 4642           7.00     1.00                  Санкт-Петербург
# 4875            nan     2.00                   посёлок Мурино
# 5075           5.50      nan                  Санкт-Петербург
# 5245           9.00     2.00                     деревня Мины
# 5668           7.00     2.00                  Санкт-Петербург
# 5806          12.00     5.00                  Санкт-Петербург
# 6245           5.70      nan                        Кронштадт
# 9377           5.20      nan                  Санкт-Петербург
# 10771          8.10     2.00                   посёлок Мурино
# 11283          9.00     2.00                             Луга
# 14379          8.00     1.00               поселок Новый Свет
# 17491         12.00     5.00                  Санкт-Петербург
# 17852           nan      nan                  Санкт-Петербург
# 18540           nan      nan                  Санкт-Петербург
# 20472         10.00     1.00                  Санкт-Петербург
# 20501         13.00     1.00                  Санкт-Петербург
# 21371         11.00     2.00                  Санкт-Петербург
# 21818          8.60     2.00  городской поселок Большая Ижора
# 22330         16.50     4.00                  Санкт-Петербург
# 22932          9.00     1.00                   деревня Нижняя
#
#        airports_nearest cityCenters_nearest  parks_around3000  parks_nearest  \
# 355                 nan                 nan               nan            nan
# 3147                nan                 nan               nan            nan
# 4642           12016.00            13256.00              1.00         658.00
# 4875                nan                 nan               nan            nan
# 5075           29686.00             8389.00              3.00         397.00
# 5245                nan                 nan               nan            nan
# 5668           28981.00            10912.00              1.00         305.00
# 5806           18732.00            20444.00              0.00            nan
# 6245           68923.00            50649.00              1.00         417.00
# 9377           11647.00            13581.00              0.00            nan
# 10771               nan                 nan               nan            nan
# 11283               nan                 nan               nan            nan
# 14379               nan                 nan               nan            nan
# 17491          16295.00            15092.00              1.00         967.00
# 17852          41030.00            15543.00              0.00            nan
# 18540          27054.00             8033.00              1.00         540.00
# 20472          18975.00             3246.00              0.00            nan
# 20501          27028.00            12570.00              0.00            nan
# 21371          42742.00             9760.00              0.00            nan
# 21818               nan                 nan               nan            nan
# 22330          18838.00             3506.00              0.00            nan
# 22932               nan                 nan               nan            nan
#
#        ponds_around3000  ponds_nearest  days_exposition
# 355                 nan            nan           259.00
# 3147                nan            nan              nan
# 4642               1.00         331.00           181.00
# 4875                nan            nan            28.00
# 5075               1.00         578.00             7.00
# 5245                nan            nan           540.00
# 5668               0.00            nan           267.00
# 5806               3.00          80.00            38.00
# 6245               2.00          73.00              nan
# 9377               0.00            nan              nan
# 10771               nan            nan            71.00
# 11283               nan            nan            18.00
# 14379               nan            nan           206.00
# 17491              0.00            nan              nan
# 17852              0.00            nan            73.00
# 18540              0.00            nan            12.00
# 20472              3.00         449.00           429.00
# 20501              0.00            nan            40.00
# 21371              0.00            nan            61.00
# 21818               nan            nan              nan
# 22330              3.00         511.00              nan
# 22932               nan            nan            27.00
#
# [22 rows x 22 columns]

# %% [markdown]
# Судя по цене и площади, это больше похоже на обычные квартиры, поэтому лучше всего будет исправить предположительную опечатку на корректное значение. Поделим их на 10

# %%
# делим некорректные значения на 10 
df.loc[df.query('ceiling_height >= 20 and ceiling_height < 35').index, 'ceiling_height'] = \
    df.loc[df.query('ceiling_height >= 20 and ceiling_height < 35').index, 'ceiling_height'] / 10

# %%
# удаляем значения "1","1.2","1.75","10,3","14", "100"
df.drop(df.query('ceiling_height < 2 or ceiling_height > 9').index, inplace=True, axis=0)
df.reset_index(inplace=True, drop=True)

# %%
# проверяем, смотрим уникальные значения
df['ceiling_height'].value_counts().sort_index(ascending=True)
# Out:
# 2.00      12
# 2.20       1
# 2.25       1
# 2.26       1
# 2.30       4
# 2.34       1
# 2.40      24
# 2.45      15
# 2.46       2
# 2.47       3
# 2.48       8
# 2.49       1
# 2.50    3522
# 2.51      34
# 2.52      79
# 2.53      67
# 2.54      83
# 2.55     980
# 2.56     139
# 2.57     103
# 2.58      63
# 2.59      14
# 2.60    1647
# 2.61       5
# 2.62      14
# 2.63      13
# 2.64      81
# 2.65     676
# 2.66      17
# 2.67      36
# 2.68      23
# 2.69       2
# 2.70    1582
# 2.71      13
# 2.72      31
# 2.73      35
# 2.74      28
# 2.75     910
# 2.76      60
# 2.77      61
# 2.78      51
# 2.79      10
# 2.80     992
# 2.81       9
# 2.82      18
# 2.83      15
# 2.84      19
# 2.85     101
# 2.86       6
# 2.87      10
# 2.88      12
# 2.89       1
# 2.90     164
# 2.91       4
# 2.92       9
# 2.93       4
# 2.94       3
# 2.95      47
# 2.96       5
# 2.97       4
# 2.98       2
# 2.99       1
# 3.00    1112
# 3.01       6
# 3.02       8
# 3.03       4
# 3.04       6
# 3.05      46
# 3.06      11
# 3.07      11
# 3.08      14
# 3.09       4
# 3.10     203
# 3.11       7
# 3.12      17
# 3.13      11
# 3.14       7
# 3.15      57
# 3.16       7
# 3.17       5
# 3.18      11
# 3.20     279
# 3.21       3
# 3.22       3
# 3.23       4
# 3.24       4
# 3.25      36
# 3.26       6
# 3.27       6
# 3.28       6
# 3.29       1
# 3.30     141
# 3.31       3
# 3.32       6
# 3.33      10
# 3.34       3
# 3.35      16
# 3.36       5
# 3.37       4
# 3.38       8
# 3.39       1
# 3.40      91
# 3.42       1
# 3.43       1
# 3.44       1
# 3.45       9
# 3.46       4
# 3.47       6
# 3.48       1
# 3.49       2
# 3.50     129
# 3.51       2
# 3.52       3
# 3.53       3
# 3.54       6
# 3.55      18
# 3.56       5
# 3.57       2
# 3.58       1
# 3.59       1
# 3.60      36
# 3.62       2
# 3.63       3
# 3.65       4
# 3.66       3
# 3.67       3
# 3.68       1
# 3.69       1
# 3.70      30
# 3.75       8
# 3.76       1
# 3.78       3
# 3.80      20
# 3.82       1
# 3.83       1
# 3.84       1
# 3.85       2
# 3.86       2
# 3.87       1
# 3.88       1
# 3.90      14
# 3.93       1
# 3.95       8
# 3.98       1
# 4.00      39
# 4.06       1
# 4.10       3
# 4.14       1
# 4.15       1
# 4.19       2
# 4.20      10
# 4.25       1
# 4.30       1
# 4.37       1
# 4.40       3
# 4.45       2
# 4.50       7
# 4.65       1
# 4.70       2
# 4.80       1
# 4.90       1
# 5.00       1
# 5.20       1
# 5.30       2
# 5.50       1
# 5.60       1
# 5.80       1
# 6.00       1
# 8.00       3
# 8.30       1
# Name: ceiling_height, dtype: int64

# %% [markdown]
# Некорректные значения убрали, теперь остались пропуски, правильнее всего будет заменить пропуски медианным значением.

# %%
# меняем пропуски на медианное значение.
df['ceiling_height'] = df['ceiling_height'].fillna(df['ceiling_height'].median())

# %%
# проверяем количество пропусков
df['ceiling_height'].isna().sum()
# Out:
# 0

# %%
# числовое описание столбца
df['ceiling_height'].describe()
# Out:
# count   23686.00
# mean        2.70
# std         0.23
# min         2.00
# 25%         2.60
# 50%         2.65
# 75%         2.70
# max         8.30
# Name: ceiling_height, dtype: float64

# %%
# смотрим график
df['ceiling_height'].hist(figsize=(12,4), bins=100);

# %% [markdown]
# Больше всего потолков в диапозоне от 2,5 до 3 метров, что соответствует стандарту потолков. Самое частое значение: 2,65 - это медианное значение,  мы им заменяли пропуски. Чем выше высота потолков, тем реже встречаются такие квартиры, также и квартиры с низкими потолками встречаются редко.

# %% [markdown]
# Аномальные значения в столбце удалили, предположительные опечатки исправили, пропуски заменили на медиану. Столбец готов к дальнейшей работе.

# %% [markdown]
# #### Столбец 'floors_total'

# %%
# смотрим уникальные значения
df['floors_total'].value_counts().sort_index(ascending=True)
# Out:
# 1.00       25
# 2.00      382
# 3.00      668
# 4.00     1200
# 5.00     5787
# 6.00      914
# 7.00      589
# 8.00      390
# 9.00     3760
# 10.00    1173
# 11.00     203
# 12.00    1361
# 13.00     229
# 14.00     552
# 15.00     365
# 16.00    1375
# 17.00     833
# 18.00     505
# 19.00     339
# 20.00     271
# 21.00     158
# 22.00     286
# 23.00     352
# 24.00     469
# 25.00    1073
# 26.00     124
# 27.00     164
# 28.00      21
# 29.00       1
# 33.00       1
# 34.00       1
# 35.00      24
# 36.00       3
# 52.00       1
# 60.00       1
# Name: floors_total, dtype: int64

# %%
# смотрим количество пропусков
df['floors_total'].isna().sum()
# Out:
# 86

# %%
# вывели на экран строки с пропусками в столбце 'floors_total'
df[df['floors_total'].isna()].head(10)
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 186             12    11640000       65.20           2018-10-02      2
# 237              4     2438033       28.10           2016-11-23      1
# 457              4     9788348       70.80           2015-08-01      2
# 671              4     6051191       93.60           2017-04-06      3
# 1756             5     3600000       39.00           2017-04-22      1
# 1929             1     9750000       66.77           2016-05-13      2
# 2391             7     5395770       53.00           2017-06-29      2
# 2845             4     2325000       27.80           2016-09-21      1
# 2951            10     6500000       54.30           2019-04-23      1
# 3030             9     6400000       56.70           2018-03-27      2
#
#       ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 186             2.65           nan        30.80      4          NaN  ...
# 237             2.65           nan        20.75      1          NaN  ...
# 457             2.65           nan        38.40     12          NaN  ...
# 671             2.65           nan        47.10      8          NaN  ...
# 1756            2.65           nan          nan      9          NaN  ...
# 1929            2.65           nan          nan      4          NaN  ...
# 2391            2.65           nan        29.00     22          NaN  ...
# 2845            2.65           nan        19.40     15          NaN  ...
# 2951            2.65           nan        22.20      6          NaN  ...
# 3030            2.65           nan        32.00     12          NaN  ...
#
#       kitchen_area  balcony    locality_name  airports_nearest  \
# 186          12.00      nan  Санкт-Петербург          39197.00
# 237            nan     0.00  Санкт-Петербург          22041.00
# 457          10.63     0.00  Санкт-Петербург          37364.00
# 671          16.80     0.00  Санкт-Петербург          22041.00
# 1756           nan     0.00  Санкт-Петербург          22735.00
# 1929           nan     0.00  Санкт-Петербург          39886.00
# 2391          9.00     0.00  Санкт-Петербург          43074.00
# 2845           nan     0.00  Санкт-Петербург          22041.00
# 2951         12.30      nan  Санкт-Петербург          23606.00
# 3030         12.00      nan          Кудрово               nan
#
#      cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 186             12373.00              1.00         123.00              0.00
# 237             17369.00              0.00            nan              1.00
# 457              8322.00              2.00         309.00              2.00
# 671             17369.00              0.00            nan              1.00
# 1756            11618.00              1.00         835.00              1.00
# 1929            10660.00              1.00        2276.00              3.00
# 2391            10820.00              0.00            nan              0.00
# 2845            17369.00              0.00            nan              1.00
# 2951             3148.00              0.00            nan              0.00
# 3030                 nan               nan            nan               nan
#
#       ponds_nearest  days_exposition
# 186             nan            49.00
# 237          374.00           251.00
# 457          706.00           727.00
# 671          374.00           123.00
# 1756         652.00            77.00
# 1929         244.00            90.00
# 2391            nan            48.00
# 2845         374.00           307.00
# 2951            nan              nan
# 3030            nan           231.00
#
# [10 rows x 22 columns]

# %% [markdown]
# Для удобства изменим тип данных в столбце на целочисленный.

# %%
# Меняем тип данных
df['floors_total'] = df['floors_total'].astype('Int64')

# %% [markdown]
# Тип данных изменили. Пропущенных значений не много,  заменять их на какие-то дургие  не верно, этажность здания на основании других данных нам не узнать, оставим пропуски как есть.

# %% [markdown]
# #### Столбец 'floor'

# %%
# смотрим уникальные значения
df['floor'].value_counts().sort_index(ascending=True)
# Out:
# 1     2916
# 2     3368
# 3     3073
# 4     2804
# 5     2616
# 6     1304
# 7     1217
# 8     1083
# 9     1050
# 10     686
# 11     523
# 12     526
# 13     379
# 14     337
# 15     342
# 16     315
# 17     227
# 18     178
# 19     147
# 20     110
# 21     125
# 22     113
# 23     100
# 24      63
# 25      44
# 26      24
# 27      10
# 28       1
# 29       1
# 30       1
# 31       1
# 32       1
# 33       1
# Name: floor, dtype: int64

# %% [markdown]
# В столбце пропусков нет, каких-либо аномальных значений тоже нет.

# %% [markdown]
#  #### Столбец 'is_apartment'

# %%
# смотрим уникальные значения
df['is_apartment'].value_counts()
# Out:
# False    2724
# True       49
# Name: is_apartment, dtype: int64

# %%
# смотрим количество пропусков
df['is_apartment'].isna().sum()
# Out:
# 20913

# %% [markdown]
# В столбце большое количество пропусков, скорее всего пропуски  это не апартаменты. Заменим пропуски в столбце на False

# %%
# меняем пропуски в столбце на False
df.loc[df['is_apartment'].isna(),'is_apartment'] = False

# %%
# проверяем количество пропусков
df['is_apartment'].isna().sum()
# Out:
# 0

# %% [markdown]
# Пропуски заменили.

# %% [markdown]
# #### Столбец 'studio'

# %%
# смотрим уникальные значения
df['studio'].value_counts()
# Out:
# False    23537
# True       149
# Name: studio, dtype: int64

# %% [markdown]
# В столбце пропусков нет, каких-либо аномальных значений тоже нет.

# %% [markdown]
# #### Столбец 'open_plan'

# %%
# смотрим уникальные значения
df['open_plan'].value_counts()
# Out:
# False    23620
# True        66
# Name: open_plan, dtype: int64

# %% [markdown]
# В столбце пропусков нет, каких-либо аномальных значений тоже нет.

# %% [markdown]
# ####  Столбец 'balcony'

# %%
# смотрим уникальные значения
df['balcony'].value_counts().sort_index(ascending=True)
# Out:
# 0.00    3758
# 1.00    4195
# 2.00    3657
# 3.00      80
# 4.00     183
# 5.00     303
# Name: balcony, dtype: int64

# %% [markdown]
# В столбце balcony указано количество балконов, вероятнее всего пропуски в этом столбце означают, что балконы не указаны, так как их нет. Заменим пропуски на ноль. И заменим тип данных на int

# %%
# заменям пропущенные значения на "0"
df['balcony'] = df['balcony'].fillna(0)

# %%
# проверяем количество пропусков
df['balcony'].isna().sum()
# Out:
# 0

# %%
# меняем тип данных 
df['balcony'] = df['balcony'].astype('int')

# %%
# проверяем тип данных 
df['balcony'].dtypes
# Out:
# dtype('int32')

# %% [markdown]
# Пропуски заменили на "0", также изменили тип данных на целочисленный.

# %% [markdown]
# #### Столбец 'locality_name'

# %%
# смотрим количество пропусков
df['locality_name'].isna().sum()
# Out:
# 49

# %%
# смотрим уникальные значения столбца
df['locality_name'].value_counts()
# Out:
# Санкт-Петербург                                            15709
# посёлок Мурино                                               522
# посёлок Шушары                                               440
# Всеволожск                                                   398
# Пушкин                                                       369
# Колпино                                                      338
# посёлок Парголово                                            327
# Гатчина                                                      307
# деревня Кудрово                                              299
# Выборг                                                       237
# Петергоф                                                     201
# Сестрорецк                                                   183
# Красное Село                                                 178
# Кудрово                                                      173
# деревня Новое Девяткино                                      144
# Сертолово                                                    142
# Ломоносов                                                    133
# Кириши                                                       125
# Сланцы                                                       112
# Волхов                                                       111
# Тосно                                                        104
# Кингисепп                                                    104
# Кронштадт                                                     96
# Никольское                                                    93
# Коммунар                                                      89
# Сосновый Бор                                                  87
# Кировск                                                       84
# Отрадное                                                      80
# посёлок Бугры                                                 69
# посёлок Металлострой                                          66
# Приозерск                                                     66
# деревня Старая                                                64
# городской посёлок Янино-1                                     61
# Шлиссельбург                                                  57
# Луга                                                          56
# Тихвин                                                        49
# поселок Бугры                                                 45
# посёлок Стрельна                                              44
# посёлок Тельмана                                              39
# Павловск                                                      38
# поселок Романовка                                             36
# Волосово                                                      36
# Мурино                                                        34
# поселок Мурино                                                34
# посёлок городского типа Сиверский                             29
# Ивангород                                                     28
# городской посёлок Новоселье                                   28
# городской посёлок Мга                                         26
# поселок городского типа имени Свердлова                       25
# Зеленогорск                                                   24
# Сясьстрой                                                     24
# посёлок Щеглово                                               23
# посёлок городского типа Кузьмоловский                         22
# поселок городского типа Синявино                              21
# деревня Вартемяги                                             20
# посёлок Новогорелово                                          20
# посёлок Понтонный                                             20
# Лодейное Поле                                                 20
# деревня Лесколово                                             20
# поселок городского типа Рощино                                19
# Подпорожье                                                    19
# Пикалёво                                                      18
# посёлок Сосново                                               18
# деревня Бегуницы                                              17
# посёлок городского типа имени Морозова                        17
# посёлок Новый Свет                                            17
# Бокситогорск                                                  16
# посёлок городского типа Токсово                               16
# деревня Большие Колпаны                                       16
# городской поселок Большая Ижора                               16
# деревня Горбунки                                              15
# поселок городского типа Дубровка                              15
# поселок городского типа Рахья                                 15
# посёлок городского типа Рощино                                15
# городской посёлок Назия                                       15
# Новая Ладога                                                  14
# посёлок городского типа Ульяновка                             13
# посёлок городского типа Кузнечное                             13
# Каменногорск                                                  13
# деревня Гарболово                                             13
# поселок городского типа Кузьмоловский                         13
# поселок Елизаветино                                           13
# поселок городского типа Вырица                                12
# деревня Мистолово                                             11
# деревня Гостилицы                                             11
# деревня Белогорка                                             11
# посёлок Аннино                                                11
# деревня Малое Верево                                          11
# посёлок городского типа Лебяжье                               11
# деревня Нурма                                                 11
# Светогорск                                                    11
# посёлок городского типа имени Свердлова                       11
# деревня Колтуши                                               11
# посёлок городского типа Вырица                                10
# деревня Сяськелево                                            10
# поселок Войсковицы                                            10
# деревня Лаголово                                              10
# деревня Низино                                                10
# посёлок Пудость                                                9
# городской посёлок Павлово                                      9
# поселок городского типа Советский                              9
# поселок Молодцово                                              9
# деревня Батово                                                 9
# поселок городского типа Приладожский                           9
# поселок Сельцо                                                 9
# деревня Оржицы                                                 9
# село Русско-Высоцкое                                           9
# деревня Малое Карлино                                          9
# деревня Фёдоровское                                            8
# поселок Суходолье                                              8
# Любань                                                         8
# поселок Запорожское                                            8
# Приморск                                                       8
# поселок Первомайское                                           8
# деревня Малые Колпаны                                          7
# деревня Кипень                                                 7
# деревня Калитино                                               7
# деревня Куттузи                                                7
# деревня Кузьмолово                                             7
# деревня Кальтино                                               7
# поселок городского типа Никольский                             7
# поселок Углово                                                 7
# село Павлово                                                   7
# деревня Извара                                                 7
# городской посёлок Фёдоровское                                  7
# городской поселок Янино-1                                      7
# деревня Пудомяги                                               6
# поселок Новый Учхоз                                            6
# деревня Пеники                                                 6
# деревня Лампово                                                6
# посёлок городского типа Тайцы                                  6
# деревня Заневка                                                6
# посёлок Ильичёво                                               6
# деревня Лопухинка                                              6
# посёлок Сапёрный                                               6
# посёлок Мичуринское                                            6
# поселок Кобринское                                             6
# поселок Ушаки                                                  6
# посёлок городского типа Важины                                 6
# деревня Яльгелево                                              6
# посёлок городского типа Мга                                    6
# поселок Семрино                                                5
# поселок Глажево                                                5
# поселок Селезнёво                                              5
# село Копорье                                                   5
# поселок Аннино                                                 5
# посёлок Кобралово                                              5
# поселок городского типа Красный Бор                            5
# посёлок Стеклянный                                             5
# поселок городского типа Дружная Горка                          5
# поселок Мичуринское                                            5
# деревня Юкки                                                   5
# городской посёлок Рощино                                       5
# посёлок Молодёжное                                             5
# посёлок Войскорово                                             5
# посёлок Плодовое                                               5
# поселок Новый Свет                                             5
# посёлок Торфяное                                               4
# посёлок Репино                                                 4
# Высоцк                                                         4
# поселок городского типа Токсово                                4
# поселок Гарболово                                              4
# деревня Разметелево                                            4
# посёлок Кикерино                                               4
# деревня Келози                                                 4
# посёлок Суйда                                                  4
# поселок Кобралово                                              4
# городской посёлок Будогощь                                     4
# деревня Большая Вруда                                          4
# деревня Агалатово                                              4
# поселок станции Вещево                                         4
# посёлок Гаврилово                                              4
# деревня Разбегаево                                             4
# деревня Парицы                                                 4
# посёлок Усть-Луга                                              4
# посёлок Песочный                                               4
# посёлок Терволово                                              4
# посёлок Поляны                                                 4
# посёлок городского типа Форносово                              4
# поселок городского типа Лебяжье                                4
# поселок Цвелодубово                                            4
# поселок Лукаши                                                 3
# деревня Старополье                                             3
# деревня Заклинье                                               3
# поселок Оредеж                                                 3
# поселок Глебычево                                              3
# поселок Торковичи                                              3
# поселок Победа                                                 3
# поселок Заводской                                              3
# городской посёлок Виллози                                      3
# поселок Зимитицы                                               3
# поселок городского типа Лесогорский                            3
# посёлок Перово                                                 3
# поселок Котельский                                             3
# деревня Старосиверская                                         3
# деревня Торошковичи                                            3
# поселок Мельниково                                             3
# посёлок Пригородный                                            3
# поселок Любань                                                 3
# деревня Ваганово                                               3
# деревня Торосово                                               3
# поселок Красная Долина                                         3
# деревня Аро                                                    3
# село Рождествено                                               3
# поселок городского типа Ефимовский                             3
# посёлок Петровское                                             3
# поселок Стеклянный                                             3
# поселок Громово                                                3
# посёлок городского типа Красный Бор                            3
# посёлок Победа                                                 3
# посёлок станции Громово                                        3
# посёлок Возрождение                                            2
# посёлок Усть-Ижора                                             2
# поселок Серебрянский                                           2
# деревня Рабитицы                                               2
# село Путилово                                                  2
# поселок Барышево                                               2
# поселок Тельмана                                               2
# деревня Камышовка                                              2
# посёлок Жилгородок                                             2
# поселок городского типа Форносово                              2
# посёлок Старая Малукса                                         2
# поселок Терволово                                              2
# поселок Совхозный                                              2
# посёлок Мельниково                                             2
# деревня Фалилеево                                              2
# поселок Житково                                                2
# деревня Суоранда                                               2
# деревня Мины                                                   2
# посёлок Лисий Нос                                              2
# поселок Ильичёво                                               2
# поселок Кингисеппский                                          2
# посёлок Александровская                                        2
# посёлок городского типа Вознесенье                             2
# городской посёлок Лесогорский                                  2
# поселок Петровское                                             2
# посёлок станции Свирь                                          2
# село Старая Ладога                                             2
# посёлок Сапёрное                                               2
# деревня Выскатка                                               2
# поселок Лесное                                                 2
# деревня Бор                                                    2
# деревня Старые Бегуницы                                        2
# деревня Ненимяки                                               2
# поселок Пушное                                                 2
# деревня Коркино                                                2
# деревня Тарасово                                               2
# поселок Поляны                                                 2
# поселок Рябово                                                 2
# поселок Старая Малукса                                         2
# городской посёлок Советский                                    2
# поселок Починок                                                2
# деревня Старая Пустошь                                         2
# деревня Глинка                                                 2
# посёлок Ленинское                                              2
# поселок городского типа Назия                                  2
# деревня Ям-Тесово                                              2
# поселок станции Приветнинское                                  2
# посёлок городского типа Павлово                                2
# село Паша                                                      2
# посёлок Платформа 69-й километр                                1
# посёлок городского типа Рябово                                 1
# деревня Тойворово                                              1
# посёлок Пансионат Зелёный Бор                                  1
# поселок Калитино                                               1
# поселок городского типа Кондратьево                            1
# деревня Вахнова Кара                                           1
# посёлок Мыза-Ивановка                                          1
# деревня Пустынка                                               1
# деревня Снегирёвка                                             1
# поселок Севастьяново                                           1
# деревня Большой Сабск                                          1
# поселок Почап                                                  1
# деревня Зимитицы                                               1
# садовое товарищество Рахья                                     1
# деревня Меньково                                               1
# деревня Нижние Осельки                                         1
# поселок Лисий Нос                                              1
# посёлок Петро-Славянка                                         1
# деревня Хязельки                                               1
# поселок Семиозерье                                             1
# деревня Пижма                                                  1
# коттеджный поселок Счастье                                     1
# деревня Большая Пустомержа                                     1
# поселок станции Корнево                                        1
# посёлок Ропша                                                  1
# поселок Рабитицы                                               1
# посёлок Сумино                                                 1
# посёлок Белоостров                                             1
# поселок Гладкое                                                1
# поселок Цвылёво                                                1
# посёлок Плоское                                                1
# деревня Большое Рейзино                                        1
# село Никольское                                                1
# деревня Мануйлово                                              1
# посёлок Коробицыно                                             1
# поселок Сумино                                                 1
# поселок Жилпосёлок                                             1
# городской посёлок Свирьстрой                                   1
# поселок городского типа Рябово                                 1
# деревня Лупполово                                              1
# посёлок при железнодорожной станции Вещево                     1
# поселок Гончарово                                              1
# поселок Ромашки                                                1
# деревня Котлы                                                  1
# поселок Пчевжа                                                 1
# посёлок Шугозеро                                               1
# поселок Кирпичное                                              1
# посёлок Форт Красная Горка                                     1
# посёлок Алексеевка                                             1
# деревня Трубников Бор                                          1
# поселок Коробицыно                                             1
# деревня Пикколово                                              1
# деревня Шпаньково                                              1
# деревня Тихковицы                                              1
# коттеджный поселок Кивеннапа Север                             1
# деревня Куровицы                                               1
# деревня Новолисино                                             1
# деревня Каськово                                               1
# деревня Терпилицы                                              1
# поселок Перово                                                 1
# поселок Дружноселье                                            1
# посёлок Дзержинского                                           1
# поселок городского типа Большая Ижора                          1
# деревня Нижняя                                                 1
# деревня Ялгино                                                 1
# деревня Раздолье                                               1
# коттеджный посёлок Лесное                                      1
# поселок Пансионат Зелёный Бор                                  1
# деревня Малая Романовка                                        1
# деревня Борисова Грива                                         1
# деревня Русско                                                 1
# деревня Кривко                                                 1
# садовое товарищество Приладожский                              1
# деревня Сижно                                                  1
# деревня Старое Хинколово                                       1
# садовое товарищество Новая Ропша                               1
# деревня Пчева                                                  1
# деревня Лаврики                                                1
# садовое товарищество Садко                                     1
# поселок станции Лужайка                                        1
# посёлок при железнодорожной станции Приветнинское              1
# деревня Реброво                                                1
# садоводческое некоммерческое товарищество Лесная Поляна        1
# село Шум                                                       1
# деревня Щеглово                                                1
# деревня Хапо-Ое                                                1
# поселок Каложицы                                               1
# деревня Рапполово                                              1
# деревня Кисельня                                               1
# поселок Гаврилово                                              1
# посёлок Левашово                                               1
# деревня Иссад                                                  1
# поселок Возрождение                                            1
# поселок Коммунары                                              1
# поселок Жилгородок                                             1
# деревня Пельгора                                               1
# деревня Курковицы                                              1
# посёлок Высокоключевой                                         1
# поселок Тёсово-4                                               1
# поселок Усть-Луга                                              1
# деревня Чудской Бор                                            1
# поселок Володарское                                            1
# поселок Красносельское                                         1
# Name: locality_name, dtype: int64

# %% [markdown]
#  У слова поселок есть два варианта написания через "е" "ё", заменим  "ё"  на "е"

# %%
# заменяем "ё" на "е"
df['locality_name'] = df['locality_name'].str.replace('ё', 'е')

# %% [markdown]
# Определить местоположении квартиры  по имеющимся данным не возможно, поэтому заменим пропуски на "неизвестно"

# %%
# меняем пропуски
df['locality_name'] = df['locality_name'].fillna('неизвестно')

# %%
# проверяем пропуски
df['locality_name'].isna().sum()
# Out:
# 0

# %% [markdown]
# Пропуски заменили на "неизвестно", заменили  разное написание слова  поселок на одинаковое.

# %% [markdown]
# #### Столбец 'living_area' и 'kitchen_area'

# %%
# смотрим количество пропусков
df['living_area'].isna().sum()
# Out:
# 1902

# %%
# смотрим количество пропусков
df['kitchen_area'].isna().sum()
# Out:
# 2275

# %% [markdown]
# В  квартирах студиях нет кухни, проверим есть ли в таких квартирах пропуски в столбце `living_area`

# %%
# числовое описание в студиях с жилой площадью
df.loc[df['studio']==True, 'living_area'].describe()
# Out:
# count   139.00
# mean     19.00
# std       7.35
# min       2.00
# 25%      16.00
# 50%      18.00
# 75%      19.85
# max      68.00
# Name: living_area, dtype: float64

# %% [markdown]
# По полученным данным видим, что в студиях жилая площадь заполнена только в 139 строках, а их 149, значит в 10 строках есть пропуск, также видим, что у нас  есть  аномальное значение 2 кв. метра, рассмотрим его детальнее.

# %%
# смотрим строки в которых жилая площать меньше 10 кв. метров в студиях.
df.loc[df.loc[(df['living_area']<10) & (df['studio']==True),\
              ['living_area', 'total_area']].index, ['living_area', 'total_area']]
# Out:
#        living_area  total_area
# 17574         5.00       22.00
# 21748         2.00       23.00

# %% [markdown]
# Есть два аномальных значения жилой площади, возможно это опечатки,  узнать верные значения не возможно, поэтому лучше удалим эти строки.

# %%
# удаляем строки с анамальным значением жилой площади в студиях
df.drop(df.loc[df.loc[(df['living_area']<10) & (df['studio']==True),\
                      ['living_area', 'total_area']].index, ['living_area', 'total_area']].index,inplace=True, axis=0)

# %% [markdown]
# Теперь заполним пропуски  жилой площади в квартирах-студиях в соответствии со средним значением доли жилой площади к общей.

# %%
#  средняя доля жилой площади в студиях
living_area_studio = (df.loc[df['studio']==True, 'living_area'] / df.loc[df['studio']==True, 'total_area']).mean()

# %%
print("Средняя доля жилой площади в студях =", living_area_studio)
# Out:
# Средняя доля жилой площади в студях = 0.6891845871726122

# %%
# Меняем пропущенные значение жилой площади в студиях на = доля жилой площади*общую
df.loc[(df['living_area'].isna() == True) & (df['studio']==True), 'living_area'] = \
    df.loc[(df['living_area'].isna() == True) & (df['studio']==True), 'total_area'] * living_area_studio

# %%
# числовое описание столбца
df.loc[df['studio']==True, 'living_area'].describe()
# Out:
# count   147.00
# mean     19.13
# std       6.94
# min      10.00
# 25%      16.00
# 50%      18.00
# 75%      19.95
# max      68.00
# Name: living_area, dtype: float64

# %%
# проверяем количество пропусков
df.loc[df['studio']==True, 'living_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# Пропуски  жилой площади в квартирах студиях заполнили,  анамальные значения удалили.

# %% [markdown]
# Теперь заполним пропуски медианными значениями "living_area" и "kitchen_area" в зависимости от "total_area", квартиры студии исключим так там мы уже заполнили пропуски
#
# Для удобства сделаем отдельный датафрейм без студий

# %%
areas = pd.DataFrame(columns=['total','living', 'kitchen'])
areas['total'] = df.loc[(df['total_area'].isna() == False) & (df['studio']==False), 'total_area']
areas['living'] = df.loc[(df['living_area'].isna() == False) & (df['studio']==False), 'living_area']
areas['kitchen'] = df.loc[(df['kitchen_area'].isna() == False) & (df['studio']==False), 'kitchen_area']
areas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23537 entries, 0 to 23685
# Data columns (total 3 columns):
# total      23537 non-null float64
# living     21645 non-null float64
# kitchen    21411 non-null float64
# dtypes: float64(3)
# memory usage: 735.5 KB

# %% [markdown]
# Рассчитаем медианное значение доли кухни и жилой в общей площади а также добавим долю оставшейся площади (нежилая площадь = part_other)

# %%
# медиана долей кухонной площади к общей
part_kitchen_median = (areas['kitchen'] / areas['total']).median()
print("Медиана долей кухонной площади к общей =", part_kitchen_median)

# медиана долей жилой площади к общей
part_living_median = (areas['living'] / areas['total']).median()
print("Медиана долей жилой площади к общей =", part_living_median)
# Out:
# Медиана долей кухонной площади к общей = 0.1724137931034483
# Медиана долей жилой площади к общей = 0.567219152854512

# %%
# медиана долей нежилой площади
part_other = 1 - part_living_median - part_kitchen_median
print('Медиана долей нежилой площади =',part_other)
# Out:
# Медиана долей нежилой площади = 0.26036705404203975

# %% [markdown]
# Заполним пропуски в столбцах кухня и жилая значениями = медиана соответствующих долей x общую.
# Начнем с кухни.

# %%
# Индексы где пропуски в значениях 'kitchen_area'
index_insa_kitchen = df.loc[(df['kitchen_area'].isna() == True) & (df['studio']==False)].index

# Меняем пропуски
df.loc[index_insa_kitchen, 'kitchen_area'] = part_kitchen_median * df.loc[index_insa_kitchen, 'total_area']

# %%
# проверяем количество пропусков
df['kitchen_area'].isna().sum()
# Out:
# 147

# %% [markdown]
# Осталось 147 пропусков в столбце, что равно количеству квартир студий.

# %%
# Индексы где пропуски в значениях 'living_area'
index_insa_living = df.loc[(df['living_area'].isna() == True) & (df['studio']==False)].index

# Меняем пропуски
df.loc[index_insa_living, 'living_area'] = part_living_median * df.loc[index_insa_living, 'total_area']

# %%
# проверяем количество пропусков
df['living_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# Пропуски в столбцах заполнили, посмотрим есть ли там аномальные значения.

# %%
# числовое описание столбца
df['living_area'].describe()
# Out:
# count   23684.00
# mean       34.53
# std        22.06
# min         2.00
# 25%        19.00
# 50%        30.00
# 75%        42.10
# max       409.00
# Name: living_area, dtype: float64

# %%
# числовое описание столбца
df['kitchen_area'].describe()
# Out:
# count   23537.00
# mean       10.51
# std         5.95
# min         1.30
# 25%         7.00
# 50%         9.00
# 75%        12.00
# max       107.00
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Итак видим, что у нас есть слишком маленькие значения в `living_area` - 2.0  и в `kitchen_area` - 1.3. Рассмотрим детальнее.

# %%
# смотрим уникальные значения
df['living_area'].value_counts().sort_index(ascending=True)
# Out:
# 2.00        1
# 3.00        2
# 5.40        1
# 6.00        1
# 6.50        1
# 7.37        2
# 7.49        1
# 8.00        2
# 8.30        1
# 8.40        1
# 8.50        1
# 8.51        2
# 8.90        1
# 9.00        9
# 9.10        1
# 9.76        1
# 9.80        1
# 10.00      33
# 10.08       2
# 10.21       1
# 10.30       2
# 10.40       3
# 10.49       1
# 10.50       5
# 10.52       1
# 10.55       1
# 10.60       2
# 10.70       2
# 10.76       1
# 10.80       1
# 10.90       2
# 10.93       1
# 10.94       1
# 11.00      24
# 11.10       2
# 11.15       1
# 11.20       2
# 11.30       3
# 11.34       2
# 11.38       1
# 11.40       4
# 11.40       1
# 11.47       1
# 11.50       5
# 11.60       2
# 11.70       3
# 11.79       1
# 11.88       1
# 11.90       1
# 11.99       1
# 12.00      33
# 12.08       1
# 12.10       3
# 12.18       1
# 12.20       3
# 12.28       1
# 12.30       3
# 12.37       1
# 12.48       3
# 12.50       9
# 12.60       2
# 12.70       3
# 12.71       1
# 12.76       1
# 12.79       1
# 12.80       2
# 12.81       1
# 12.90       1
# 13.00      42
# 13.05       4
# 13.05       1
# 13.09       1
# 13.09       1
# 13.10       7
# 13.14       1
# 13.15       1
# 13.20       1
# 13.27       1
# 13.30       6
# 13.32       1
# 13.34       1
# 13.37       1
# 13.40       5
# 13.46       1
# 13.50      16
# 13.54       2
# 13.56       2
# 13.59       1
# 13.60       6
# 13.60       1
# 13.61       3
# 13.62       1
# 13.66       1
# 13.70       7
# 13.73       1
# 13.76       1
# 13.79       1
# 13.80       3
# 13.82       1
# 13.84       1
# 13.89       1
# 13.90       8
# 13.92       2
# 14.00     118
# 14.01       1
# 14.01       1
# 14.02       2
# 14.03       1
# 14.06       1
# 14.08       1
# 14.10      23
# 14.11       1
# 14.16       1
# 14.17       1
# 14.18      12
# 14.19       1
# 14.20      20
# 14.22       1
# 14.23       1
# 14.25       1
# 14.27       1
# 14.28       2
# 14.30      22
# 14.31       1
# 14.35       1
# 14.37       4
# 14.38       3
# 14.39       1
# 14.40      19
# 14.41       1
# 14.45       1
# 14.46       1
# 14.47       1
# 14.48       1
# 14.50      48
# 14.51       1
# 14.55       1
# 14.56       1
# 14.57       3
# 14.58       1
# 14.59       1
# 14.60      20
# 14.62       2
# 14.64       1
# 14.65       2
# 14.69       1
# 14.69       1
# 14.70      28
# 14.71       1
# 14.73       2
# 14.74       1
# 14.75       1
# 14.75       1
# 14.77       1
# 14.80      14
# 14.80       1
# 14.85       1
# 14.89       1
# 14.90      16
# 14.91       1
# 14.92       2
# 14.95       1
# 15.00     313
# 15.01       1
# 15.02       2
# 15.03       4
# 15.04       1
# 15.05       3
# 15.06       1
# 15.07       1
# 15.08       1
# 15.10      30
# 15.11       1
# 15.12       1
# 15.13       1
# 15.15       1
# 15.16       3
# 15.18       2
# 15.20      55
# 15.25       2
# 15.26       1
# 15.26       2
# 15.30      41
# 15.31       2
# 15.31       5
# 15.32       1
# 15.33       1
# 15.34       1
# 15.35       1
# 15.36       1
# 15.37       1
# 15.38       2
# 15.40      57
# 15.41       1
# 15.42       1
# 15.43       4
# 15.45       2
# 15.46       1
# 15.49       1
# 15.50      76
# 15.53       1
# 15.54       1
# 15.55       1
# 15.58       2
# 15.60      57
# 15.61       1
# 15.62       1
# 15.64       1
# 15.65       3
# 15.66       1
# 15.70      40
# 15.71       2
# 15.72       3
# 15.77       1
# 15.78       2
# 15.79       3
# 15.80      49
# 15.82       2
# 15.85       2
# 15.86       1
# 15.88       1
# 15.88       6
# 15.89       3
# 15.90      30
# 15.91       2
# 15.92       1
# 15.93       2
# 15.96       1
# 16.00     486
# 16.04       1
# 16.06       2
# 16.07       1
# 16.08       2
# 16.09       1
# 16.10      36
# 16.11       2
# 16.12       1
# 16.15       1
# 16.16       1
# 16.16       1
# 16.18       1
# 16.20      37
# 16.22       1
# 16.26       2
# 16.28       1
# 16.29       2
# 16.30      51
# 16.31       1
# 16.32       1
# 16.40      64
# 16.41       1
# 16.42       3
# 16.45       8
# 16.47       1
# 16.50      91
# 16.51       1
# 16.51       1
# 16.52       3
# 16.54       1
# 16.55       1
# 16.58       1
# 16.59       1
# 16.60      44
# 16.61       1
# 16.62       1
# 16.62       2
# 16.63       1
# 16.66       2
# 16.68       1
# 16.69       1
# 16.70      52
# 16.71       2
# 16.72       1
# 16.74       1
# 16.76       1
# 16.79       1
# 16.80      43
# 16.83       1
# 16.84       1
# 16.88       1
# 16.90      45
# 16.91       2
# 16.92       2
# 16.93       1
# 16.94       1
# 16.95       1
# 16.96       1
# 16.97       1
# 16.98       1
# 17.00     675
# 17.01       1
# 17.02      15
# 17.03       1
# 17.04       1
# 17.05       2
# 17.07       4
# 17.07       1
# 17.08       2
# 17.10      73
# 17.11       1
# 17.12       1
# 17.14       1
# 17.16       1
# 17.19       2
# 17.20      87
# 17.22       1
# 17.23       1
# 17.24       1
# 17.25       1
# 17.26       1
# 17.27       1
# 17.30      72
# 17.30       1
# 17.33       4
# 17.34       1
# 17.35       1
# 17.36       2
# 17.38       3
# 17.40      90
# 17.41       1
# 17.43       2
# 17.45       1
# 17.47       1
# 17.48       1
# 17.49       1
# 17.50     170
# 17.51       1
# 17.51       1
# 17.53       1
# 17.58      33
# 17.60      96
# 17.62       1
# 17.64       1
# 17.65       2
# 17.66       2
# 17.70       2
# 17.70      96
# 17.71       1
# 17.73       1
# 17.75       2
# 17.78       1
# 17.80     101
# 17.81       2
# 17.82       2
# 17.83       1
# 17.84       1
# 17.85       1
# 17.86       1
# 17.87       1
# 17.87       1
# 17.90      61
# 17.92       1
# 17.92       1
# 17.92       2
# 17.93       1
# 17.95       1
# 17.95       1
# 17.97       1
# 18.00     882
# 18.02       2
# 18.03       1
# 18.04       1
# 18.04       1
# 18.08       2
# 18.09       3
# 18.09       1
# 18.10      60
# 18.11       2
# 18.12       1
# 18.14       3
# 18.15       2
# 18.15      15
# 18.16       1
# 18.19       1
# 18.20      70
# 18.23       1
# 18.26       1
# 18.28       1
# 18.30      70
# 18.32       2
# 18.33       1
# 18.34       1
# 18.35       1
# 18.38       3
# 18.39       1
# 18.40      45
# 18.43       2
# 18.44       2
# 18.46       1
# 18.47       1
# 18.49       2
# 18.50     105
# 18.55       1
# 18.55       1
# 18.57       1
# 18.60      94
# 18.60       2
# 18.61       1
# 18.61       1
# 18.62       2
# 18.62       1
# 18.63       1
# 18.70      59
# 18.71       2
# 18.72      22
# 18.72       1
# 18.73       1
# 18.77       1
# 18.79       1
# 18.80      37
# 18.83       1
# 18.83       2
# 18.84       2
# 18.86       1
# 18.88       1
# 18.90      32
# 18.93       1
# 18.93       1
# 18.95       3
# 18.95       4
# 19.00     329
# 19.00       6
# 19.03       1
# 19.09       1
# 19.10      29
# 19.15       1
# 19.20      51
# 19.22       1
# 19.26       1
# 19.29      12
# 19.30      34
# 19.34       1
# 19.35       3
# 19.35       1
# 19.40       2
# 19.40      34
# 19.42       1
# 19.49       1
# 19.50      35
# 19.51       3
# 19.52       1
# 19.55       1
# 19.56       1
# 19.57       1
# 19.60      22
# 19.65       1
# 19.68       1
# 19.70      15
# 19.73       1
# 19.79       1
# 19.80      30
# 19.85      21
# 19.90      20
# 19.90       1
# 19.91       1
# 19.95       1
# 20.00     481
# 20.01       1
# 20.02       2
# 20.03       1
# 20.08       3
# 20.10      63
# 20.11       1
# 20.13       1
# 20.14       4
# 20.14       1
# 20.19       1
# 20.19       1
# 20.20      27
# 20.26       2
# 20.30      26
# 20.31       2
# 20.31       1
# 20.36       2
# 20.36       3
# 20.39       1
# 20.39       2
# 20.40      21
# 20.40       1
# 20.42      25
# 20.43       2
# 20.46       1
# 20.47       1
# 20.48       1
# 20.50      39
# 20.52       1
# 20.55       1
# 20.59       2
# 20.60      10
# 20.65       1
# 20.67       1
# 20.70       9
# 20.70       5
# 20.74       1
# 20.74       1
# 20.75       1
# 20.76       2
# 20.77       1
# 20.79       1
# 20.80      15
# 20.88       1
# 20.89       1
# 20.90       7
# 20.97       1
# 20.99      16
# 21.00     137
# 21.04       1
# 21.06       1
# 21.08       1
# 21.09       1
# 21.10      10
# 21.10       1
# 21.11       3
# 21.12       1
# 21.15       1
# 21.16       1
# 21.20      15
# 21.21       3
# 21.27       2
# 21.28       1
# 21.30      19
# 21.36       2
# 21.38       4
# 21.40      11
# 21.44       1
# 21.50      20
# 21.53       1
# 21.55      20
# 21.59       1
# 21.60      16
# 21.61       4
# 21.64       1
# 21.65       2
# 21.67       4
# 21.68       1
# 21.70       5
# 21.72       2
# 21.75       1
# 21.77       1
# 21.78       1
# 21.80       5
# 21.84       1
# 21.89       3
# 21.90       6
# 21.91       1
# 21.95       3
# 22.00      98
# 22.01       1
# 22.04       1
# 22.06       1
# 22.10       6
# 22.12      21
# 22.15       1
# 22.20       7
# 22.23       1
# 22.29       2
# 22.30      10
# 22.35       2
# 22.35       3
# 22.35       1
# 22.37       1
# 22.38       1
# 22.40      10
# 22.41       1
# 22.43       1
# 22.45       1
# 22.50      14
# 22.52       1
# 22.57       1
# 22.60      10
# 22.62       1
# 22.69      32
# 22.70       9
# 22.75       1
# 22.80       7
# 22.80       1
# 22.81       1
# 22.82       1
# 22.86       3
# 22.90       7
# 22.92       3
# 22.97       2
# 23.00      55
# 23.10       1
# 23.14       1
# 23.19       1
# 23.20       2
# 23.20       5
# 23.26      16
# 23.30       8
# 23.31       1
# 23.35       1
# 23.37       3
# 23.40       6
# 23.43       3
# 23.43       1
# 23.44       1
# 23.48       3
# 23.50       7
# 23.54       2
# 23.60       7
# 23.62       1
# 23.70       8
# 23.71       2
# 23.77       1
# 23.77       1
# 23.80       3
# 23.82      43
# 23.86       2
# 23.88       4
# 23.90       5
# 23.94       1
# 23.99       1
# 24.00      69
# 24.05       3
# 24.10       4
# 24.11       2
# 24.16       3
# 24.20      12
# 24.22       2
# 24.28       1
# 24.30       8
# 24.39      25
# 24.40       6
# 24.41       1
# 24.42       1
# 24.45       2
# 24.50       9
# 24.50       1
# 24.54       1
# 24.56       4
# 24.60       3
# 24.62       5
# 24.64       1
# 24.67       5
# 24.70      14
# 24.73       2
# 24.75       1
# 24.77       1
# 24.79       1
# 24.80       4
# 24.83       1
# 24.86       1
# 24.89       1
# 24.90       5
# 24.90       1
# 24.95       1
# 24.96      35
# 25.00     108
# 25.01       1
# 25.07       2
# 25.10       2
# 25.13       5
# 25.18       2
# 25.20       9
# 25.24       3
# 25.30       5
# 25.30       6
# 25.35       2
# 25.38       1
# 25.40       9
# 25.41       1
# 25.41       3
# 25.43       1
# 25.44       1
# 25.44       1
# 25.47       1
# 25.50      19
# 25.52      37
# 25.58       2
# 25.60       9
# 25.64       1
# 25.70       1
# 25.70       9
# 25.75       3
# 25.80       8
# 25.81       3
# 25.81       1
# 25.87       2
# 25.90       8
# 25.90       1
# 25.92       1
# 25.95       1
# 25.95       1
# 25.97       1
# 25.98       1
# 26.00     121
# 26.03       1
# 26.04       2
# 26.09      28
# 26.10      15
# 26.13       4
# 26.20      15
# 26.21       3
# 26.21       1
# 26.26       1
# 26.28       1
# 26.29       1
# 26.30      12
# 26.32       3
# 26.38       3
# 26.40      12
# 26.43       2
# 26.50      25
# 26.51       1
# 26.55       2
# 26.60       1
# 26.60      32
# 26.60       3
# 26.61       1
# 26.66      20
# 26.70      20
# 26.75       1
# 26.79       1
# 26.80      34
# 26.83       2
# 26.87       1
# 26.90      24
# 26.94       1
# 26.94       3
# 27.00     311
# 27.05       1
# 27.06       3
# 27.06       1
# 27.10      27
# 27.11       2
# 27.12       1
# 27.20      34
# 27.22       1
# 27.23      22
# 27.25       1
# 27.28       2
# 27.29       1
# 27.30      47
# 27.33       1
# 27.38       1
# 27.40       2
# 27.40      67
# 27.42       1
# 27.43       1
# 27.46       1
# 27.50      65
# 27.51       2
# 27.57       2
# 27.57       1
# 27.60      34
# 27.67       1
# 27.68       1
# 27.69       1
# 27.70      48
# 27.74       1
# 27.75       1
# 27.77       1
# 27.79      10
# 27.80      31
# 27.85       2
# 27.88       1
# 27.89       1
# 27.90      29
# 27.91       1
# 27.92       1
# 27.95       1
# 27.96       1
# 28.00     423
# 28.01       1
# 28.02       1
# 28.02       1
# 28.04       1
# 28.07       1
# 28.08       1
# 28.09       1
# 28.10      42
# 28.13       1
# 28.14       1
# 28.15       1
# 28.18       1
# 28.19       1
# 28.20      36
# 28.23       1
# 28.25       1
# 28.26       1
# 28.30      50
# 28.30       1
# 28.30       1
# 28.31       1
# 28.33       2
# 28.34       1
# 28.36       1
# 28.36      16
# 28.40      43
# 28.41       1
# 28.42       1
# 28.43       1
# 28.45       1
# 28.47       1
# 28.47       4
# 28.48       1
# 28.50      57
# 28.53       1
# 28.54       1
# 28.55       1
# 28.60      45
# 28.64       1
# 28.66       1
# 28.70      37
# 28.70       2
# 28.71       2
# 28.71       1
# 28.73       1
# 28.76       2
# 28.77       1
# 28.80      25
# 28.80       1
# 28.81       1
# 28.81       3
# 28.84       1
# 28.85       1
# 28.86       1
# 28.88       1
# 28.90      23
# 28.90       1
# 28.93       9
# 28.98       1
# 28.98       2
# 29.00     319
# 29.01       1
# 29.04       1
# 29.08       1
# 29.10       2
# 29.10      21
# 29.13       1
# 29.16       1
# 29.16       1
# 29.20      33
# 29.21       1
# 29.21       2
# 29.22       1
# 29.27       1
# 29.30      33
# 29.33       2
# 29.34       2
# 29.38       1
# 29.40      32
# 29.41       1
# 29.43       1
# 29.44       1
# 29.48       1
# 29.50      19
# 29.50      70
# 29.52       2
# 29.55       3
# 29.55       1
# 29.56       1
# 29.60       1
# 29.60      39
# 29.61       5
# 29.61       1
# 29.67       1
# 29.70      67
# 29.72       1
# 29.72       2
# 29.74       1
# 29.76       1
# 29.77       1
# 29.78       1
# 29.78       2
# 29.80      41
# 29.81       1
# 29.83       1
# 29.84       3
# 29.84       1
# 29.85       2
# 29.89       2
# 29.90      44
# 29.92       1
# 29.95       2
# 30.00     598
# 30.01       1
# 30.04       1
# 30.04       3
# 30.05       1
# 30.06      16
# 30.08       1
# 30.10       1
# 30.10      49
# 30.12       2
# 30.12       2
# 30.15       1
# 30.16       1
# 30.17       1
# 30.20      41
# 30.23       2
# 30.27       1
# 30.29       1
# 30.30      51
# 30.31       1
# 30.32       1
# 30.35       1
# 30.35       1
# 30.39       1
# 30.40      45
# 30.40       1
# 30.50       1
# 30.50      66
# 30.52       3
# 30.52       2
# 30.52       1
# 30.55       2
# 30.57       1
# 30.57       1
# 30.59       1
# 30.60      44
# 30.61       1
# 30.62       1
# 30.63      32
# 30.68       1
# 30.69       1
# 30.70      36
# 30.72       1
# 30.74       1
# 30.75       2
# 30.75       1
# 30.80       1
# 30.80      37
# 30.81       2
# 30.82       1
# 30.83       1
# 30.89       1
# 30.90      26
# 30.90       1
# 30.92       1
# 30.97       2
# 31.00     381
# 31.01       2
# 31.03       2
# 31.04       1
# 31.05       1
# 31.06       1
# 31.07       1
# 31.10      34
# 31.12       1
# 31.14       1
# 31.18       1
# 31.20      21
# 31.20      53
# 31.23       1
# 31.25       1
# 31.26       1
# 31.29       1
# 31.30      31
# 31.38       1
# 31.40      32
# 31.41       2
# 31.42       1
# 31.42       1
# 31.42       1
# 31.43       2
# 31.44       1
# 31.47       2
# 31.48       1
# 31.48       3
# 31.50      55
# 31.51       1
# 31.52       1
# 31.54       3
# 31.55       3
# 31.59       1
# 31.60       1
# 31.60      33
# 31.61       2
# 31.62       1
# 31.64       1
# 31.65       1
# 31.65       1
# 31.70      33
# 31.71       1
# 31.73       1
# 31.74       1
# 31.76      20
# 31.77       1
# 31.80      21
# 31.81       1
# 31.84       1
# 31.84       1
# 31.88       1
# 31.90      23
# 31.99       1
# 32.00     319
# 32.02       1
# 32.04       1
# 32.05       1
# 32.05       1
# 32.06       1
# 32.08       2
# 32.10      24
# 32.20       1
# 32.20      20
# 32.22       2
# 32.26       1
# 32.27       2
# 32.30      23
# 32.31       1
# 32.33      14
# 32.35       2
# 32.37       1
# 32.38       1
# 32.40      25
# 32.44       1
# 32.46       1
# 32.50      41
# 32.53       1
# 32.56       4
# 32.60      26
# 32.61       1
# 32.62       1
# 32.62       1
# 32.68       1
# 32.70      31
# 32.71       1
# 32.73       1
# 32.73       1
# 32.79       1
# 32.79       1
# 32.80      28
# 32.81       1
# 32.84       1
# 32.84       2
# 32.90      22
# 32.90      22
# 32.95       1
# 33.00     214
# 33.01       1
# 33.03       1
# 33.06       1
# 33.07       2
# 33.08       1
# 33.10      25
# 33.13       1
# 33.18       1
# 33.20      19
# 33.26       1
# 33.26       1
# 33.30       4
# 33.30      25
# 33.36       1
# 33.40      22
# 33.47      10
# 33.47       1
# 33.50      35
# 33.52       1
# 33.52       1
# 33.57       1
# 33.58       2
# 33.60      23
# 33.63       1
# 33.67       2
# 33.70      22
# 33.72       1
# 33.73       1
# 33.75       1
# 33.80      17
# 33.81       3
# 33.87       1
# 33.90      18
# 33.92       2
# 33.92       2
# 33.98       2
# 34.00     188
# 34.03      31
# 34.10      19
# 34.14       1
# 34.15       3
# 34.20      26
# 34.20       1
# 34.26       4
# 34.29       1
# 34.30      17
# 34.32       1
# 34.37       1
# 34.37       1
# 34.40      23
# 34.41       1
# 34.43       1
# 34.44       1
# 34.49       2
# 34.50      12
# 34.51       2
# 34.54       1
# 34.58       1
# 34.60      25
# 34.60      11
# 34.63       2
# 34.66       1
# 34.70      11
# 34.71       1
# 34.76       1
# 34.79       1
# 34.80      24
# 34.83       4
# 34.87       1
# 34.88       1
# 34.88       1
# 34.90      13
# 34.94       1
# 34.95       1
# 35.00       1
# 35.00     194
# 35.01       1
# 35.05       2
# 35.05       2
# 35.07       1
# 35.10      19
# 35.11       1
# 35.17      17
# 35.17       1
# 35.20      17
# 35.22       1
# 35.30      14
# 35.33       4
# 35.34       3
# 35.38       1
# 35.39       3
# 35.40      11
# 35.45       4
# 35.48       1
# 35.50      19
# 35.54       1
# 35.55       3
# 35.56       3
# 35.60      15
# 35.61       1
# 35.65       1
# 35.68       1
# 35.70      27
# 35.73      19
# 35.74       1
# 35.76       1
# 35.77       1
# 35.79       2
# 35.80      14
# 35.81       1
# 35.88       2
# 35.89       1
# 35.90      16
# 35.90       1
# 35.91       1
# 35.92       1
# 36.00     170
# 36.02       4
# 36.04       1
# 36.07       1
# 36.08       3
# 36.10       1
# 36.10       6
# 36.12       1
# 36.13       2
# 36.13       1
# 36.15       3
# 36.19       1
# 36.20      11
# 36.27       1
# 36.30      16
# 36.30       7
# 36.35       1
# 36.40      19
# 36.42       1
# 36.45       1
# 36.50      19
# 36.53       1
# 36.57       1
# 36.60      20
# 36.70      19
# 36.70       1
# 36.76       2
# 36.76       1
# 36.78       1
# 36.79       1
# 36.80      12
# 36.81       1
# 36.86       1
# 36.87      14
# 36.90      17
# 36.95       1
# 36.95       1
# 36.98       1
# 37.00     140
# 37.02       1
# 37.04       1
# 37.10       2
# 37.10      21
# 37.13       1
# 37.15       3
# 37.20      26
# 37.21       3
# 37.28       1
# 37.30      24
# 37.30       1
# 37.40      24
# 37.44       6
# 37.49       2
# 37.50      37
# 37.52       1
# 37.60      15
# 37.61       2
# 37.66       2
# 37.66       1
# 37.70      17
# 37.74       1
# 37.80      25
# 37.87       1
# 37.90      16
# 38.00     159
# 38.00      12
# 38.03       1
# 38.05       1
# 38.07       1
# 38.10      12
# 38.17       2
# 38.18       1
# 38.20      15
# 38.20       1
# 38.29       1
# 38.30      11
# 38.33       2
# 38.34       1
# 38.39       1
# 38.40      14
# 38.40       1
# 38.44       1
# 38.50      23
# 38.51       1
# 38.57       9
# 38.60      15
# 38.63       1
# 38.63       1
# 38.68       2
# 38.70      15
# 38.73       1
# 38.74       1
# 38.80      20
# 38.85       1
# 38.90      11
# 38.91       1
# 38.95       1
# 38.95       2
# 38.99       1
# 39.00     187
# 39.07       1
# 39.10      17
# 39.14       2
# 39.18       2
# 39.19       2
# 39.20      22
# 39.25       1
# 39.30      20
# 39.31       1
# 39.40      28
# 39.41       1
# 39.42       1
# 39.44       1
# 39.50      36
# 39.59       1
# 39.60      22
# 39.62       2
# 39.66       1
# 39.70      27
# 39.71      18
# 39.71       1
# 39.71       1
# 39.78       1
# 39.80      19
# 39.82       1
# 39.85       1
# 39.90      21
# 39.93       1
# 39.99       1
# 40.00     225
# 40.05       1
# 40.06       1
# 40.10      10
# 40.16       1
# 40.20      22
# 40.22       2
# 40.27       5
# 40.30      15
# 40.32       3
# 40.33       1
# 40.39       1
# 40.40      23
# 40.41       1
# 40.43       1
# 40.44       2
# 40.50       1
# 40.50      28
# 40.56       1
# 40.57       1
# 40.59       1
# 40.60       5
# 40.61       2
# 40.61       1
# 40.70      19
# 40.78       2
# 40.79       1
# 40.80      15
# 40.82       1
# 40.83       1
# 40.84      20
# 40.90      16
# 40.92       1
# 40.95       1
# 41.00     133
# 41.03       1
# 41.05       1
# 41.06       1
# 41.07       1
# 41.08       1
# 41.10      17
# 41.17       2
# 41.18       1
# 41.19       1
# 41.20      14
# 41.30      25
# 41.34       1
# 41.35       1
# 41.35       1
# 41.40      15
# 41.41       9
# 41.44       1
# 41.45       1
# 41.46       2
# 41.50      21
# 41.60      23
# 41.63       2
# 41.69       1
# 41.70      19
# 41.80      11
# 41.86       1
# 41.90      32
# 41.92       1
# 41.97      14
# 41.98       1
# 42.00     217
# 42.10      28
# 42.14       1
# 42.17       1
# 42.20      30
# 42.26       2
# 42.26       1
# 42.30      27
# 42.31       1
# 42.40      24
# 42.41       1
# 42.43       1
# 42.48       1
# 42.50      31
# 42.54       1
# 42.54       7
# 42.55       1
# 42.60       1
# 42.60      25
# 42.70      24
# 42.79       1
# 42.80      34
# 42.83       1
# 42.90      24
# 42.91       1
# 43.00     231
# 43.05       1
# 43.10      33
# 43.11      10
# 43.15       1
# 43.20      27
# 43.28       2
# 43.30      33
# 43.32       1
# 43.39       1
# 43.40      30
# 43.45       1
# 43.45       1
# 43.46       1
# 43.50      38
# 43.51       1
# 43.53       1
# 43.56       2
# 43.60      30
# 43.62       1
# 43.63       1
# 43.68       5
# 43.70      25
# 43.71       1
# 43.78       1
# 43.80      22
# 43.81       1
# 43.83       2
# 43.89       1
# 43.90      19
# 43.90       1
# 43.92       1
# 44.00     169
# 44.00       1
# 44.04       1
# 44.05       1
# 44.10      16
# 44.10       1
# 44.11       1
# 44.13       1
# 44.15       1
# 44.17       1
# 44.19       1
# 44.20      18
# 44.24       7
# 44.30       1
# 44.30      14
# 44.40      18
# 44.47       1
# 44.50      24
# 44.53       1
# 44.56       1
# 44.58       1
# 44.60      21
# 44.70       1
# 44.70      10
# 44.80      21
# 44.81       9
# 44.90      19
# 44.91       1
# 44.92       1
# 44.98       1
# 44.99       2
# 45.00     148
# 45.04       1
# 45.10      11
# 45.11       1
# 45.13       1
# 45.15       1
# 45.18       1
# 45.20      14
# 45.23       1
# 45.26       1
# 45.30      15
# 45.34       1
# 45.38      16
# 45.38       1
# 45.40      16
# 45.45       1
# 45.50      27
# 45.55       1
# 45.60      22
# 45.66       2
# 45.70      18
# 45.72       1
# 45.80      12
# 45.82       1
# 45.83       1
# 45.85       1
# 45.86       1
# 45.90      13
# 45.92       1
# 45.94       5
# 45.95       1
# 46.00     112
# 46.01       1
# 46.05       1
# 46.10      11
# 46.11       1
# 46.13       1
# 46.14       1
# 46.15       1
# 46.20      11
# 46.30      10
# 46.34       1
# 46.40      19
# 46.50      19
# 46.51       4
# 46.57       1
# 46.60      14
# 46.64       1
# 46.70       9
# 46.75       1
# 46.80       1
# 46.80      13
# 46.90      14
# 47.00     137
# 47.08       8
# 47.10      17
# 47.11       2
# 47.20      22
# 47.24       1
# 47.25       2
# 47.30      15
# 47.37       1
# 47.40      27
# 47.41       1
# 47.43       1
# 47.50      19
# 47.53       1
# 47.60      18
# 47.65       4
# 47.68       1
# 47.69       1
# 47.70      16
# 47.80      14
# 47.82       1
# 47.90       9
# 47.99       3
# 48.00       1
# 48.00     133
# 48.05       2
# 48.10      11
# 48.13       1
# 48.20      18
# 48.21       6
# 48.25       1
# 48.27       2
# 48.30      14
# 48.30       1
# 48.35       1
# 48.36       1
# 48.38       1
# 48.40      13
# 48.41       2
# 48.42       1
# 48.45       1
# 48.46       1
# 48.48       1
# 48.49       1
# 48.50       2
# 48.50      25
# 48.55       1
# 48.60      21
# 48.62       1
# 48.70      13
# 48.78       2
# 48.80      16
# 48.84       1
# 48.88       3
# 48.90      13
# 48.93       1
# 48.94       1
# 49.00     100
# 49.01       1
# 49.10      11
# 49.12       1
# 49.18       2
# 49.20       8
# 49.25       1
# 49.27       3
# 49.28       1
# 49.29       1
# 49.30      14
# 49.33       1
# 49.35       7
# 49.40       7
# 49.46       1
# 49.50      14
# 49.58       1
# 49.60      16
# 49.69       1
# 49.70      14
# 49.74       1
# 49.80      10
# 49.87       1
# 49.90      10
# 49.92       6
# 49.98       3
# 50.00     127
# 50.02       1
# 50.08       1
# 50.09       1
# 50.10      12
# 50.16       1
# 50.20       1
# 50.20      10
# 50.25       1
# 50.26       1
# 50.26       1
# 50.28       2
# 50.30       9
# 50.34       1
# 50.40       7
# 50.47       1
# 50.48       2
# 50.50      13
# 50.54       1
# 50.60       4
# 50.64       1
# 50.70       9
# 50.80       8
# 50.81       1
# 50.90       9
# 51.00      69
# 51.05       5
# 51.07       1
# 51.10       3
# 51.20      12
# 51.26       1
# 51.30       9
# 51.40       7
# 51.50      11
# 51.60       8
# 51.62       7
# 51.70      13
# 51.76       1
# 51.78       1
# 51.80       9
# 51.88       1
# 51.90       9
# 51.90       1
# 51.96       1
# 52.00      81
# 52.02       1
# 52.10       5
# 52.13       1
# 52.18       2
# 52.20      11
# 52.21       2
# 52.26       1
# 52.30       2
# 52.30       7
# 52.40      11
# 52.50      10
# 52.53       1
# 52.58       1
# 52.60      14
# 52.65       1
# 52.70      11
# 52.75       5
# 52.77       1
# 52.80       5
# 52.86       1
# 52.90       6
# 52.94       1
# 53.00      80
# 53.10       5
# 53.15       1
# 53.17       1
# 53.20      11
# 53.26       1
# 53.30       8
# 53.31       1
# 53.32       3
# 53.33       1
# 53.35       2
# 53.38       2
# 53.40      10
# 53.50      15
# 53.60       4
# 53.66       1
# 53.70       9
# 53.80       7
# 53.89       6
# 53.90       6
# 53.94       1
# 54.00      81
# 54.09       2
# 54.10       3
# 54.13       1
# 54.17       2
# 54.20       3
# 54.30       8
# 54.40       1
# 54.40       7
# 54.43       1
# 54.45       1
# 54.48       1
# 54.50      13
# 54.60       7
# 54.70       8
# 54.74       1
# 54.74       1
# 54.80       8
# 54.85       1
# 54.90      11
# 54.91       1
# 55.00      63
# 55.02       3
# 55.10      11
# 55.13       1
# 55.19       1
# 55.20       8
# 55.22       1
# 55.30       5
# 55.35       1
# 55.38       1
# 55.40       5
# 55.50      12
# 55.53       1
# 55.59       5
# 55.60       9
# 55.70       9
# 55.80       8
# 55.81       1
# 55.84       2
# 55.90       8
# 55.93       1
# 56.00      73
# 56.10       5
# 56.12       1
# 56.15       1
# 56.20       5
# 56.21       2
# 56.30       6
# 56.40       6
# 56.50       8
# 56.53       1
# 56.60       2
# 56.67       1
# 56.70       5
# 56.72       7
# 56.80       2
# 56.86       1
# 56.90       8
# 57.00      39
# 57.06       1
# 57.10       7
# 57.20      10
# 57.29       2
# 57.30      10
# 57.35       1
# 57.40       9
# 57.50       9
# 57.51       1
# 57.60       5
# 57.70       3
# 57.75       1
# 57.80      10
# 57.86       2
# 57.90       3
# 58.00      49
# 58.10       3
# 58.18       1
# 58.20       1
# 58.20       3
# 58.30       4
# 58.40       1
# 58.44       1
# 58.50       3
# 58.59       1
# 58.60       2
# 58.63       1
# 58.70       3
# 58.76       1
# 58.80       3
# 58.82       1
# 58.99       1
# 59.00      28
# 59.10       7
# 59.12       1
# 59.20       4
# 59.30       3
# 59.40       1
# 59.50       4
# 59.56       5
# 59.60       5
# 59.61       1
# 59.70       7
# 59.75       1
# 59.80       5
# 59.90       2
# 60.00      72
# 60.10       3
# 60.13       3
# 60.20       2
# 60.30       1
# 60.30       6
# 60.30       1
# 60.33       1
# 60.40       5
# 60.50       6
# 60.52       1
# 60.60       1
# 60.69       4
# 60.70       3
# 60.77       1
# 60.80       2
# 60.90       5
# 61.00      25
# 61.10       4
# 61.20       3
# 61.26       4
# 61.30       3
# 61.32       1
# 61.35       1
# 61.40       1
# 61.43       1
# 61.49       1
# 61.50       6
# 61.60       3
# 61.70       3
# 61.80       6
# 61.83       2
# 61.90       1
# 62.00       1
# 62.00      30
# 62.10       2
# 62.20       1
# 62.30       1
# 62.39       6
# 62.40       3
# 62.50       6
# 62.60       8
# 62.70       2
# 62.75       3
# 62.80       2
# 62.90       2
# 62.96       1
# 63.00      36
# 63.10       6
# 63.20       4
# 63.30       6
# 63.31       1
# 63.40       4
# 63.50       5
# 63.53       4
# 63.60       2
# 63.70       5
# 63.72       1
# 63.80       4
# 63.90       7
# 64.00      37
# 64.10       1
# 64.10       4
# 64.20       4
# 64.30       4
# 64.32       2
# 64.40       6
# 64.50       4
# 64.60       5
# 64.66       4
# 64.70       4
# 64.80       6
# 64.90       2
# 64.97       1
# 65.00      26
# 65.30       3
# 65.40       5
# 65.50       3
# 65.60       3
# 65.70       3
# 65.72       1
# 65.80       2
# 65.80       2
# 65.90       3
# 65.93       1
# 65.93       1
# 66.00      22
# 66.01       1
# 66.10       2
# 66.20       1
# 66.22       1
# 66.24       1
# 66.30       3
# 66.40       1
# 66.42       1
# 66.50       5
# 66.53       1
# 66.60       3
# 66.70       1
# 66.80       1
# 66.90       2
# 66.93       3
# 66.99       1
# 67.00      29
# 67.01       1
# 67.10       2
# 67.20       4
# 67.30       2
# 67.40       1
# 67.50       1
# 67.50       4
# 67.60       4
# 67.80       4
# 67.81       1
# 67.84       1
# 67.90       2
# 68.00      36
# 68.07       2
# 68.10       5
# 68.30       1
# 68.40       3
# 68.48       1
# 68.50       4
# 68.60       2
# 68.63       2
# 68.70       3
# 68.80       3
# 68.90       3
# 69.00      14
# 69.10       4
# 69.20       1
# 69.28       1
# 69.30       4
# 69.37       1
# 69.48       1
# 69.50       2
# 69.60       2
# 69.70       2
# 69.75       1
# 69.77       2
# 69.80       3
# 69.88       1
# 69.90       3
# 70.00      35
# 70.10       3
# 70.17       1
# 70.30       2
# 70.34       1
# 70.40       3
# 70.48       1
# 70.50       5
# 70.52       1
# 70.60       2
# 70.70       1
# 70.90       2
# 70.90       5
# 71.00      15
# 71.10       2
# 71.20       1
# 71.30       3
# 71.40       2
# 71.47       1
# 71.50       2
# 71.70       3
# 71.72       1
# 71.90       2
# 72.00      19
# 72.04       1
# 72.10       7
# 72.20       3
# 72.30       2
# 72.40       2
# 72.50       1
# 72.52       1
# 72.60       1
# 72.70       2
# 72.79       1
# 72.80       2
# 73.00      18
# 73.10       2
# 73.20       2
# 73.30       3
# 73.40       4
# 73.50       3
# 73.60       2
# 73.74       4
# 73.80       1
# 73.90       2
# 74.00      11
# 74.10       1
# 74.16       2
# 74.20       1
# 74.30       1
# 74.40       4
# 74.60       2
# 74.80       2
# 74.87       1
# 74.99       1
# 75.00      25
# 75.10       3
# 75.16       1
# 75.20       4
# 75.24       1
# 75.25       1
# 75.40       1
# 75.44       1
# 75.50       2
# 75.60       1
# 75.67       1
# 75.70       1
# 75.80       1
# 75.83       1
# 76.00      12
# 76.01       3
# 76.10       2
# 76.20       3
# 76.30       2
# 76.40       7
# 76.50       2
# 76.63       1
# 76.65       1
# 76.70       1
# 76.80       3
# 76.90       1
# 76.97       1
# 77.00      12
# 77.10       1
# 77.14       2
# 77.20       1
# 77.30       1
# 77.35       1
# 77.40       1
# 77.50       1
# 77.60       2
# 77.61       1
# 77.71       1
# 77.71       1
# 77.80       1
# 78.00      21
# 78.03       1
# 78.28       2
# 78.40       1
# 78.50       1
# 78.60       2
# 78.90       3
# 79.00      10
# 79.20       3
# 79.28       1
# 79.30       1
# 79.30       3
# 79.34       1
# 79.40       3
# 79.42       1
# 79.50       2
# 79.70       1
# 79.74       1
# 79.98       1
# 80.00      32
# 80.10       1
# 80.20       3
# 80.30       1
# 80.39       1
# 80.50       2
# 80.62       1
# 80.70       1
# 80.80       2
# 80.90       2
# 81.00       8
# 81.10       1
# 81.11       1
# 81.30       4
# 81.40       2
# 81.50       2
# 81.60       2
# 81.66       1
# 81.70       1
# 81.90       1
# 81.90       1
# 82.00      10
# 82.05       1
# 82.10       1
# 82.20       1
# 82.25       1
# 82.30       1
# 82.40       4
# 82.55       3
# 82.80       2
# 82.81       1
# 82.90       1
# 83.00       9
# 83.20       1
# 83.27       1
# 83.50       2
# 83.60       3
# 83.70       1
# 83.78       1
# 83.80       3
# 83.94       1
# 83.95       1
# 84.00       8
# 84.10       2
# 84.12       1
# 84.20       2
# 84.50       4
# 84.52       1
# 84.60       1
# 84.69       1
# 84.70       1
# 85.00      13
# 85.08       2
# 85.10       1
# 85.20       1
# 85.30       1
# 85.60       2
# 85.75       1
# 86.00      11
# 86.10       1
# 86.20       4
# 86.22       1
# 86.43       1
# 86.60       1
# 86.67       1
# 86.70       1
# 87.00      10
# 87.20       1
# 87.23       1
# 87.41       1
# 87.50       1
# 87.70       1
# 87.80       1
# 87.92       2
# 88.00      11
# 88.03       1
# 88.10       1
# 88.20       4
# 88.30       1
# 88.49       2
# 88.71       1
# 89.00       2
# 89.05       1
# 89.10       1
# 89.11       2
# 89.20       2
# 89.22       1
# 89.28       1
# 89.30       1
# 89.40       2
# 89.50       2
# 89.60       1
# 89.62       3
# 89.70       1
# 89.90       1
# 90.00      20
# 90.19       1
# 90.20       1
# 90.60       1
# 90.70       1
# 90.76       2
# 91.00       5
# 91.15       1
# 91.20       1
# 91.24       1
# 91.70       2
# 91.77       1
# 91.80       2
# 91.89       1
# 92.00       4
# 92.10       1
# 92.30       4
# 92.34       2
# 92.50       1
# 92.60       1
# 92.70       1
# 92.80       1
# 92.90       1
# 93.00       4
# 93.10       2
# 93.20       1
# 93.50       1
# 93.60       1
# 94.00       6
# 94.10       1
# 94.40       1
# 94.54       1
# 94.80       2
# 94.89       3
# 94.90       1
# 95.00      13
# 95.10       2
# 95.20       1
# 95.40       2
# 95.41       1
# 95.45       1
# 95.60       2
# 95.70       1
# 95.90       1
# 96.00       4
# 96.30       1
# 96.40       1
# 96.43       1
# 96.60       1
# 96.70       1
# 97.00       5
# 97.20       1
# 97.30       1
# 97.54       1
# 97.60       1
# 98.00       6
# 98.19       1
# 98.20       2
# 98.50       1
# 98.70       1
# 98.70       1
# 98.90       1
# 99.00       4
# 99.10       1
# 99.21       1
# 99.26       1
# 99.30       1
# 99.50       2
# 99.60       2
# 99.66       1
# 99.70       1
# 99.80       1
# 99.90       1
# 100.00      9
# 100.10      1
# 100.23      1
# 100.40      1
# 100.70      1
# 100.90      1
# 101.00      8
# 101.14      1
# 101.20      1
# 101.54      1
# 101.82      1
# 102.00      5
# 102.10      1
# 102.20      1
# 102.30      2
# 102.50      2
# 102.80      2
# 103.00      2
# 103.10      1
# 103.30      2
# 103.60      2
# 103.70      1
# 103.71      1
# 103.80      1
# 104.00      7
# 104.10      2
# 104.20      2
# 104.54      1
# 104.76      1
# 104.80      2
# 104.94      1
# 105.00      5
# 105.30      1
# 105.80      1
# 106.00      4
# 106.10      1
# 106.20      1
# 106.40      1
# 106.50      1
# 106.64      1
# 107.00      6
# 107.03      1
# 107.60      1
# 108.00      3
# 108.80      1
# 109.00      3
# 109.40      1
# 109.51      1
# 110.00      5
# 110.30      1
# 110.40      2
# 110.80      1
# 111.00      3
# 111.10      1
# 111.17      2
# 111.60      1
# 111.74      1
# 111.86      2
# 112.00      6
# 112.20      1
# 112.25      1
# 112.40      1
# 112.70      1
# 112.99      1
# 113.00      1
# 113.44      1
# 114.00      2
# 114.29      1
# 114.70      1
# 114.80      1
# 115.00      4
# 115.50      1
# 115.71      1
# 115.80      1
# 116.00      1
# 116.20      1
# 117.00      3
# 117.10      1
# 117.30      1
# 117.40      2
# 118.40      1
# 118.50      1
# 118.90      1
# 119.00      1
# 119.30      1
# 119.50      1
# 119.90      1
# 120.00      3
# 121.00      3
# 121.60      1
# 122.00      3
# 122.10      1
# 123.00      2
# 123.10      1
# 123.27      1
# 123.60      2
# 123.90      1
# 124.00      1
# 124.79      1
# 124.90      1
# 125.00      2
# 125.10      1
# 125.50      2
# 125.70      1
# 125.90      1
# 125.92      1
# 126.00      2
# 126.40      2
# 126.60      2
# 127.00      2
# 127.70      1
# 128.00      2
# 129.00      1
# 130.00      4
# 130.30      2
# 130.46      1
# 131.00      4
# 131.50      1
# 132.00      2
# 132.73      1
# 133.00      1
# 133.30      1
# 133.40      1
# 134.00      1
# 134.70      1
# 134.80      1
# 135.15      1
# 136.00      1
# 136.10      1
# 136.13      1
# 136.20      1
# 136.70      1
# 137.70      1
# 138.80      1
# 139.00      1
# 139.40      1
# 139.80      1
# 140.00      5
# 141.00      2
# 142.00      4
# 142.37      1
# 143.00      1
# 144.07      1
# 144.50      1
# 144.60      2
# 145.00      6
# 145.40      1
# 145.50      1
# 145.90      1
# 147.00      2
# 147.20      2
# 148.00      2
# 148.60      1
# 149.40      1
# 149.63      1
# 150.00      3
# 150.40      1
# 150.80      1
# 151.00      1
# 151.10      1
# 151.40      1
# 151.60      1
# 152.00      1
# 153.00      1
# 153.90      1
# 154.00      1
# 154.70      1
# 155.00      1
# 155.10      1
# 155.50      1
# 157.00      1
# 158.82      1
# 159.20      2
# 159.50      2
# 159.60      1
# 159.90      1
# 160.00      9
# 160.10      1
# 160.60      1
# 161.40      1
# 162.00      3
# 163.20      1
# 163.50      1
# 164.30      1
# 164.70      1
# 165.00      1
# 165.50      1
# 166.70      1
# 167.00      4
# 167.33      1
# 168.30      1
# 170.00      1
# 170.80      1
# 171.00      1
# 172.43      1
# 174.00      1
# 174.30      1
# 175.00      1
# 176.20      1
# 176.60      1
# 177.00      1
# 177.30      1
# 179.00      1
# 179.20      1
# 180.00      6
# 181.80      1
# 182.00      1
# 182.80      1
# 183.00      1
# 183.70      1
# 184.00      1
# 184.90      1
# 187.00      2
# 187.90      1
# 188.70      1
# 189.40      1
# 190.00      2
# 193.00      1
# 193.50      1
# 194.00      1
# 195.00      1
# 198.00      1
# 199.00      1
# 200.00      2
# 205.96      1
# 206.86      1
# 207.03      1
# 211.00      1
# 216.00      1
# 218.00      1
# 220.00      2
# 222.00      1
# 225.90      1
# 226.32      1
# 226.89      1
# 230.00      1
# 239.40      1
# 239.48      1
# 248.50      1
# 248.70      1
# 250.00      4
# 250.70      1
# 255.70      1
# 260.00      1
# 264.50      1
# 274.00      1
# 279.60      1
# 280.26      1
# 283.61      2
# 300.00      1
# 301.50      1
# 312.50      1
# 322.30      1
# 332.00      1
# 347.50      1
# 357.92      1
# 409.00      1
# Name: living_area, dtype: int64

# %%
# смотрим общий график
df['living_area'].hist(figsize = (12,4), bins = 100);

# %%
# смотрим квартиры жилой площадью до 12 кв. метров
df['living_area'].hist(figsize = (12,4), bins = 100, range = (0,12));

# %%
# смотрим квартиры жилой площадью от 150 кв. метров
df['living_area'].hist(figsize = (12,4), bins = 100, range = (150,500));

# %% [markdown]
# Видим, что у нас имеются  квартиры с очень маленькой жилой площадью меньше 6 кв. метров, что не похоже на квартиру, предположительно это некорректные значения, рассмотрим их детальнее - скорее всего их правильнее будет удалить.

# %%
# срез маленьких по  жилой площади квартир
df.query('living_area < 6')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3241              7     4440000       41.00           2017-07-02      1
# 13911            20     6350000       52.00           2018-02-06      2
# 21933            15     6100000       77.60           2019-02-28      4
# 23561            14    64990000      139.00           2015-11-24      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 3241             2.65            17         3.00     17         False  ...
# 13911            3.00             6         2.00      2         False  ...
# 21933            2.50             9         5.40      1         False  ...
# 23561            3.00             8         3.00      8         False  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 3241          11.00        0  Санкт-Петербург          19272.00
# 13911          9.00        0  Санкт-Петербург          32453.00
# 21933          9.80        0  Санкт-Петербург          29338.00
# 23561         16.00        1  Санкт-Петербург          33255.00
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 3241             13073.00              0.00            nan              0.00
# 13911             6521.00              0.00            nan              1.00
# 21933            11270.00              1.00         584.00              0.00
# 23561             5975.00              1.00         630.00              3.00
#
#        ponds_nearest  days_exposition
# 3241             nan           216.00
# 13911        1012.00            91.00
# 21933            nan            33.00
# 23561         100.00           280.00
#
# [4 rows x 22 columns]

# %% [markdown]
# Попробуем заменить некорректные значения жилой площади, на основании остальных данных общей площади, площади кухни и  медианной доли нежилой площади.

# %%
# меняем некорректную жилую площадь на подходящую 
df.loc[df['living_area'] < 6, 'living_area'] = df['total_area'] - df['kitchen_area'] - df['total_area']*part_other

# %% [markdown]
# Для удобства округлим значения в столбце до десятых

# %%
# округляем значения до десятых
df['living_area'] = round(df['living_area'],1)

# %%
# числовое описание столбца
df['living_area'].describe()
# Out:
# count   23684.00
# mean       34.54
# std        22.05
# min         6.00
# 25%        19.00
# 50%        30.00
# 75%        42.10
# max       409.00
# Name: living_area, dtype: float64

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000      108.00           2019-03-07      3
# 1             7     3350000       40.40           2018-12-04      1
# 2            10     5196000       56.00           2015-08-20      2
# 3             0    64900000      159.00           2015-07-24      3
# 4             2    10000000      100.00           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16        51.00      8         False  ...
# 1            2.65            11        18.60      1         False  ...
# 2            2.65             5        34.30      4         False  ...
# 3            2.65            14        90.20      9         False  ...
# 4            3.03            14        32.00     13         False  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0         25.00        0  Санкт-Петербург          18863.00
# 1         11.00        2   поселок Шушары          12817.00
# 2          8.30        0  Санкт-Петербург          21741.00
# 3         27.41        0  Санкт-Петербург          28098.00
# 4         41.00        0  Санкт-Петербург          31856.00
#
#   cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0            16028.00              1.00         482.00              2.00
# 1            18603.00              0.00            nan              0.00
# 2            13933.00              1.00          90.00              2.00
# 3             6800.00              2.00          84.00              3.00
# 4             8098.00              2.00         112.00              1.00
#
#    ponds_nearest  days_exposition
# 0         755.00              nan
# 1            nan            81.00
# 2         574.00           558.00
# 3         234.00           424.00
# 4          48.00           121.00
#
# [5 rows x 22 columns]

# %%
# смотрим уникальные значение
df['kitchen_area'].value_counts().sort_index(ascending=True)
# Out:
# 1.30         1
# 2.00         7
# 2.07         1
# 2.24         3
# 2.28         1
# 2.30         1
# 2.40         1
# 2.59         2
# 2.76         1
# 2.89         1
# 2.97         1
# 3.00         7
# 3.03         1
# 3.07         1
# 3.10         3
# 3.19         1
# 3.20         1
# 3.26         1
# 3.30         1
# 3.40         1
# 3.45         4
# 3.47         1
# 3.50         4
# 3.55         1
# 3.56         1
# 3.59         1
# 3.62         1
# 3.67         1
# 3.69         2
# 3.70         1
# 3.72         1
# 3.72         1
# 3.74         1
# 3.76         1
# 3.77         1
# 3.78         1
# 3.79         9
# 3.80         3
# 3.88         3
# 3.91         2
# 3.97        10
# 3.98         1
# 3.99         1
# 4.00        25
# 4.02         2
# 4.05         1
# 4.06         1
# 4.07         1
# 4.08         1
# 4.09         1
# 4.10         3
# 4.13         2
# 4.14        16
# 4.17         2
# 4.18         1
# 4.20         3
# 4.21         3
# 4.21         1
# 4.22         3
# 4.24         1
# 4.25         1
# 4.25         1
# 4.26         1
# 4.28         2
# 4.29         1
# 4.30         1
# 4.31        22
# 4.32         1
# 4.34         1
# 4.34         1
# 4.36         1
# 4.36         1
# 4.37         1
# 4.37         1
# 4.38         1
# 4.39         1
# 4.40         3
# 4.40         2
# 4.40         1
# 4.41         1
# 4.42         1
# 4.45         1
# 4.47         2
# 4.48        13
# 4.50         1
# 4.50         9
# 4.50         3
# 4.51         1
# 4.55         2
# 4.56         1
# 4.59         2
# 4.60         4
# 4.60         1
# 4.62         1
# 4.64         1
# 4.66        10
# 4.67         3
# 4.69         1
# 4.70         6
# 4.71         4
# 4.71         1
# 4.72         1
# 4.72         1
# 4.74         2
# 4.75         1
# 4.78         2
# 4.79         2
# 4.80        11
# 4.81         1
# 4.83        15
# 4.83         1
# 4.84         1
# 4.84         4
# 4.86         1
# 4.88         2
# 4.90         1
# 4.90        12
# 4.91         3
# 4.93         1
# 4.95         1
# 4.98         1
# 4.98         1
# 5.00       371
# 5.02         1
# 5.04         1
# 5.05         1
# 5.06         1
# 5.07         1
# 5.09         1
# 5.10        63
# 5.10         2
# 5.12         1
# 5.14         1
# 5.16         1
# 5.17         1
# 5.17        22
# 5.19         1
# 5.20       117
# 5.21         1
# 5.22         1
# 5.22         1
# 5.23         1
# 5.24         1
# 5.25         1
# 5.26         3
# 5.28         1
# 5.29         1
# 5.29         1
# 5.30       139
# 5.31         1
# 5.33         1
# 5.34        40
# 5.35         1
# 5.36         3
# 5.38         3
# 5.40         3
# 5.40       136
# 5.41         2
# 5.42         2
# 5.43         3
# 5.44         1
# 5.45         2
# 5.47         1
# 5.49         1
# 5.50       403
# 5.52        23
# 5.53         1
# 5.55         1
# 5.57         1
# 5.59         4
# 5.59         1
# 5.60       138
# 5.60         2
# 5.61         1
# 5.62         1
# 5.62         2
# 5.64         1
# 5.64         1
# 5.64         1
# 5.65         1
# 5.65         1
# 5.66         3
# 5.66         1
# 5.68         2
# 5.69        25
# 5.70        81
# 5.72         2
# 5.74         1
# 5.74         1
# 5.75         1
# 5.75         1
# 5.76         2
# 5.78         6
# 5.78         1
# 5.79         1
# 5.80        86
# 5.82         1
# 5.83         1
# 5.83         1
# 5.83         1
# 5.85         1
# 5.85         1
# 5.86         1
# 5.86        19
# 5.88         1
# 5.90         3
# 5.90        48
# 5.91         1
# 5.92         1
# 5.93         4
# 5.94         1
# 5.95         2
# 5.95         1
# 5.95         1
# 5.97         1
# 6.00      1300
# 6.01         1
# 6.01         1
# 6.02         1
# 6.02         1
# 6.03         1
# 6.03        26
# 6.05         1
# 6.05         2
# 6.08         1
# 6.08         2
# 6.10         1
# 6.10       111
# 6.10         2
# 6.12         3
# 6.14         1
# 6.16         1
# 6.16         1
# 6.17         1
# 6.17         2
# 6.19         2
# 6.19         1
# 6.20       282
# 6.21        24
# 6.22         1
# 6.22         1
# 6.23         2
# 6.23         2
# 6.24         1
# 6.24         1
# 6.25         2
# 6.26         2
# 6.26         1
# 6.27         1
# 6.28         2
# 6.28         2
# 6.29         4
# 6.30       296
# 6.30         2
# 6.31         1
# 6.31         2
# 6.33         1
# 6.33         2
# 6.34         1
# 6.35         1
# 6.36         1
# 6.37         1
# 6.38        14
# 6.40        95
# 6.41         1
# 6.43         1
# 6.45         5
# 6.47         2
# 6.47         1
# 6.50       263
# 6.50         5
# 6.52         1
# 6.53         1
# 6.55         2
# 6.55        20
# 6.57         4
# 6.58         2
# 6.59         5
# 6.60        84
# 6.60         2
# 6.61         1
# 6.62         1
# 6.62         1
# 6.64         2
# 6.65         1
# 6.66         3
# 6.67         5
# 6.70        91
# 6.71         1
# 6.72         2
# 6.72        23
# 6.73         1
# 6.74         1
# 6.76         2
# 6.77         1
# 6.78         1
# 6.79         3
# 6.80        83
# 6.81         1
# 6.82         1
# 6.83         1
# 6.84         1
# 6.84         1
# 6.86         1
# 6.86         1
# 6.90        33
# 6.90        73
# 6.91         1
# 6.91         1
# 6.93         1
# 6.93         1
# 6.95         3
# 6.95         1
# 6.97         4
# 6.98         4
# 7.00      1062
# 7.02         1
# 7.03         2
# 7.03         1
# 7.05         2
# 7.06         1
# 7.07        17
# 7.09         1
# 7.09         1
# 7.10       158
# 7.10         3
# 7.12         1
# 7.12         3
# 7.12         1
# 7.14         3
# 7.15         1
# 7.16         2
# 7.17         2
# 7.17         1
# 7.18         1
# 7.19         1
# 7.19         2
# 7.20       168
# 7.21         3
# 7.21         1
# 7.22         1
# 7.24        43
# 7.26         3
# 7.28         2
# 7.29         1
# 7.30        99
# 7.31         4
# 7.33         7
# 7.34         4
# 7.35         1
# 7.36         2
# 7.36         3
# 7.38         1
# 7.40        92
# 7.41         1
# 7.41        32
# 7.42         1
# 7.43         2
# 7.45         1
# 7.47         4
# 7.48         2
# 7.48         3
# 7.50       232
# 7.50         5
# 7.52         2
# 7.53         1
# 7.54         1
# 7.57         1
# 7.58         1
# 7.59        32
# 7.60        68
# 7.60         1
# 7.62         3
# 7.63         1
# 7.64         5
# 7.65         1
# 7.66         4
# 7.67         3
# 7.69         4
# 7.70        80
# 7.71         3
# 7.71         3
# 7.72         4
# 7.73         1
# 7.76        42
# 7.78         1
# 7.79         2
# 7.80       105
# 7.81         1
# 7.83         1
# 7.84         3
# 7.84         3
# 7.85         2
# 7.86         1
# 7.86         2
# 7.87         1
# 7.89         2
# 7.90         1
# 7.90        51
# 7.91         2
# 7.92         1
# 7.93        29
# 7.94         1
# 7.95         1
# 7.97         3
# 7.97         1
# 7.98         1
# 8.00      1113
# 8.01         1
# 8.02         2
# 8.02         2
# 8.03         1
# 8.03         1
# 8.05         2
# 8.06         1
# 8.07         2
# 8.07         1
# 8.08         2
# 8.09         2
# 8.09         1
# 8.10       153
# 8.10        17
# 8.11         1
# 8.12         1
# 8.13         1
# 8.15         1
# 8.16         1
# 8.18         1
# 8.19         2
# 8.19         2
# 8.20       235
# 8.21         3
# 8.22         2
# 8.23         1
# 8.24         2
# 8.24         1
# 8.25         2
# 8.28        16
# 8.28         1
# 8.29         1
# 8.29         1
# 8.30       272
# 8.31         2
# 8.32         2
# 8.33         2
# 8.34         1
# 8.35         2
# 8.38         2
# 8.38         1
# 8.40       214
# 8.41         2
# 8.43         1
# 8.43         1
# 8.44         1
# 8.45        14
# 8.45         1
# 8.47         2
# 8.47         2
# 8.48         2
# 8.48         2
# 8.50       415
# 8.52         1
# 8.52         1
# 8.53         1
# 8.54         1
# 8.57         1
# 8.57         1
# 8.58         1
# 8.59         1
# 8.59         1
# 8.60       151
# 8.60         2
# 8.61         1
# 8.62        22
# 8.63         1
# 8.64         2
# 8.65         6
# 8.66         5
# 8.66         1
# 8.67         1
# 8.68         1
# 8.69         1
# 8.70       150
# 8.71         1
# 8.71         3
# 8.72         2
# 8.73         1
# 8.74         2
# 8.76         1
# 8.76         1
# 8.76         1
# 8.77         1
# 8.79        11
# 8.80       111
# 8.81         1
# 8.81         2
# 8.82         1
# 8.83         1
# 8.84         3
# 8.84         3
# 8.85         2
# 8.87         2
# 8.88         2
# 8.90        74
# 8.91         3
# 8.93         1
# 8.93         1
# 8.94         1
# 8.95         1
# 8.96         1
# 8.97        21
# 8.98         1
# 8.98         1
# 9.00      1101
# 9.00         2
# 9.01         2
# 9.02         1
# 9.03         1
# 9.04         1
# 9.05         1
# 9.05         2
# 9.05         1
# 9.06         1
# 9.07         3
# 9.08         2
# 9.09         1
# 9.09         1
# 9.10        81
# 9.10         2
# 9.11         1
# 9.13         1
# 9.13         1
# 9.14        18
# 9.16         2
# 9.16         3
# 9.17         1
# 9.18         3
# 9.19         4
# 9.19         1
# 9.20       102
# 9.21         1
# 9.22         1
# 9.22         1
# 9.22         2
# 9.24         1
# 9.24         2
# 9.25         3
# 9.26         1
# 9.26         2
# 9.27         3
# 9.27         1
# 9.28         1
# 9.28         1
# 9.28         1
# 9.29         1
# 9.30       120
# 9.31         1
# 9.31        31
# 9.32         2
# 9.33         1
# 9.34         1
# 9.34         1
# 9.35         1
# 9.35         1
# 9.36         5
# 9.36         2
# 9.37         1
# 9.38         1
# 9.38         1
# 9.39         1
# 9.40       114
# 9.41         2
# 9.42         1
# 9.42         2
# 9.43         2
# 9.43         2
# 9.44         1
# 9.45         1
# 9.46         2
# 9.47         1
# 9.47         1
# 9.48         1
# 9.48        21
# 9.50       181
# 9.51         1
# 9.52         1
# 9.52         2
# 9.55         1
# 9.57         3
# 9.57         2
# 9.58         1
# 9.59         3
# 9.59         1
# 9.60       104
# 9.60         2
# 9.62         2
# 9.62         2
# 9.65         3
# 9.66        22
# 9.66         1
# 9.67         2
# 9.68         3
# 9.69         1
# 9.70        74
# 9.71         2
# 9.72         4
# 9.72         1
# 9.73         1
# 9.74         2
# 9.75         1
# 9.76         1
# 9.76         3
# 9.77         1
# 9.78         2
# 9.79         1
# 9.79         1
# 9.79         2
# 9.80       105
# 9.80         1
# 9.81         1
# 9.82         1
# 9.83        14
# 9.83         1
# 9.85         2
# 9.86         2
# 9.89         1
# 9.89         1
# 9.90         5
# 9.90        72
# 9.91         5
# 9.93         1
# 9.95         2
# 9.97         1
# 9.98         1
# 9.98         1
# 10.00     1282
# 10.01        2
# 10.02        4
# 10.02        2
# 10.03        5
# 10.05        3
# 10.05        2
# 10.06        2
# 10.07        1
# 10.08        5
# 10.09        1
# 10.09        3
# 10.10      111
# 10.10        1
# 10.11        1
# 10.12        1
# 10.12        4
# 10.13        1
# 10.14        1
# 10.15        4
# 10.17        3
# 10.17       14
# 10.18        7
# 10.19        1
# 10.19        2
# 10.20      161
# 10.21        2
# 10.22        2
# 10.24        2
# 10.25        2
# 10.26        1
# 10.26        3
# 10.27        2
# 10.28        3
# 10.29        2
# 10.30      172
# 10.31        2
# 10.32        1
# 10.33        1
# 10.33        2
# 10.34        2
# 10.34       32
# 10.35        3
# 10.36        2
# 10.37        4
# 10.38        2
# 10.38        1
# 10.39        2
# 10.40        1
# 10.40      127
# 10.41        2
# 10.42        1
# 10.42        1
# 10.43        2
# 10.43        1
# 10.44        5
# 10.45        1
# 10.45        2
# 10.46        1
# 10.47        1
# 10.47        1
# 10.48        2
# 10.49        1
# 10.50      154
# 10.51        5
# 10.52       17
# 10.52        2
# 10.53        1
# 10.54        3
# 10.55        1
# 10.55        1
# 10.56        4
# 10.58        2
# 10.59        3
# 10.59        3
# 10.60      131
# 10.60        1
# 10.62        1
# 10.62        1
# 10.63        2
# 10.64        1
# 10.64        4
# 10.66        3
# 10.67        1
# 10.68        2
# 10.69       18
# 10.69        5
# 10.70      148
# 10.71        1
# 10.72        2
# 10.72        1
# 10.73        3
# 10.74        1
# 10.74        3
# 10.75        3
# 10.76        3
# 10.78        4
# 10.78        3
# 10.79        1
# 10.80      163
# 10.81        2
# 10.84        1
# 10.84        6
# 10.84        1
# 10.86        2
# 10.86       17
# 10.87        1
# 10.88        1
# 10.88        4
# 10.89        1
# 10.90       67
# 10.91        4
# 10.91        1
# 10.92        1
# 10.93        1
# 10.94        4
# 10.95        6
# 10.95        1
# 10.98        2
# 10.99        1
# 11.00      797
# 11.03       10
# 11.04        2
# 11.05        2
# 11.06        1
# 11.07        1
# 11.07        2
# 11.09        2
# 11.10       57
# 11.10        1
# 11.11        7
# 11.12        5
# 11.12        1
# 11.13        1
# 11.14        2
# 11.16        1
# 11.17        1
# 11.17        3
# 11.18        3
# 11.20       77
# 11.21       16
# 11.22        1
# 11.22        1
# 11.23        1
# 11.24        7
# 11.24        2
# 11.25        1
# 11.26        2
# 11.27        1
# 11.28        1
# 11.28        1
# 11.29        1
# 11.29        1
# 11.30       84
# 11.31        2
# 11.31        2
# 11.33        2
# 11.34        2
# 11.35        5
# 11.36        5
# 11.37        1
# 11.38        7
# 11.39        1
# 11.40        1
# 11.40       75
# 11.41        2
# 11.42        1
# 11.43        1
# 11.43        3
# 11.44        3
# 11.45        1
# 11.45        1
# 11.46        1
# 11.47        2
# 11.49        1
# 11.50      125
# 11.50        1
# 11.51        3
# 11.51        1
# 11.52        3
# 11.53        2
# 11.55        5
# 11.55       14
# 11.56        1
# 11.57        1
# 11.57        1
# 11.59        1
# 11.59        2
# 11.60       64
# 11.60        2
# 11.62        2
# 11.63        2
# 11.64        1
# 11.65        1
# 11.66        2
# 11.67        2
# 11.67        1
# 11.69        1
# 11.70       60
# 11.71        1
# 11.71        3
# 11.72       11
# 11.73        1
# 11.74        1
# 11.74        1
# 11.74        1
# 11.76        1
# 11.78        1
# 11.78       11
# 11.80       51
# 11.81        3
# 11.81        1
# 11.84        1
# 11.85        5
# 11.87        1
# 11.90        2
# 11.90       48
# 11.92        2
# 11.93        1
# 11.93        1
# 11.95        1
# 11.95        4
# 11.98        1
# 12.00      662
# 12.01        1
# 12.02        2
# 12.03        2
# 12.05        3
# 12.07       18
# 12.08        3
# 12.10       45
# 12.11        1
# 12.14        1
# 12.14        1
# 12.15        1
# 12.17        2
# 12.17        1
# 12.18        3
# 12.20       59
# 12.21        1
# 12.22        2
# 12.23        2
# 12.24        3
# 12.24        4
# 12.25        1
# 12.26        1
# 12.27        2
# 12.29        1
# 12.29        1
# 12.30       58
# 12.31        1
# 12.32        1
# 12.33        1
# 12.35        9
# 12.37        1
# 12.38        1
# 12.38        1
# 12.39        1
# 12.40        2
# 12.40       63
# 12.41       19
# 12.43        1
# 12.43        2
# 12.44        1
# 12.45        1
# 12.47        1
# 12.47        1
# 12.50      104
# 12.52        2
# 12.52        3
# 12.53        1
# 12.55        2
# 12.56        1
# 12.57        2
# 12.57        2
# 12.58        1
# 12.59        8
# 12.60       66
# 12.60        2
# 12.63        1
# 12.66        2
# 12.66        2
# 12.69        1
# 12.70       42
# 12.71        1
# 12.72        1
# 12.72        1
# 12.75        1
# 12.76       15
# 12.76        2
# 12.78        1
# 12.79        1
# 12.80       36
# 12.83        2
# 12.84        1
# 12.84        2
# 12.85        3
# 12.86        2
# 12.87        1
# 12.88        1
# 12.88        1
# 12.89        1
# 12.90       34
# 12.92        1
# 12.93        1
# 12.93       10
# 12.94        1
# 12.95        1
# 12.96        4
# 13.00      323
# 13.02        1
# 13.02        1
# 13.04        1
# 13.05        2
# 13.06        1
# 13.10       39
# 13.10        9
# 13.11        1
# 13.14        2
# 13.16        1
# 13.16        1
# 13.17        1
# 13.19        1
# 13.20       49
# 13.21        1
# 13.21        1
# 13.22        1
# 13.24        1
# 13.24        3
# 13.24        1
# 13.25        4
# 13.26        2
# 13.27        1
# 13.28        4
# 13.28        1
# 13.29        1
# 13.30       47
# 13.31        2
# 13.31        1
# 13.32        1
# 13.33        1
# 13.34        1
# 13.35        1
# 13.36        1
# 13.38        2
# 13.39        1
# 13.40        2
# 13.40       53
# 13.41        1
# 13.41        1
# 13.42        1
# 13.43        1
# 13.43        1
# 13.45        8
# 13.47        2
# 13.49        2
# 13.50       66
# 13.52        1
# 13.53        2
# 13.53        1
# 13.55        6
# 13.58        1
# 13.59        1
# 13.60       46
# 13.62        7
# 13.63        1
# 13.64        2
# 13.65        1
# 13.66        1
# 13.67        3
# 13.69        1
# 13.69        2
# 13.70       34
# 13.72        1
# 13.73        1
# 13.74        2
# 13.76        1
# 13.77        1
# 13.79        3
# 13.79       14
# 13.80       36
# 13.81        1
# 13.81        1
# 13.83        1
# 13.84        4
# 13.84        1
# 13.86        1
# 13.86        1
# 13.88        1
# 13.90       27
# 13.93        1
# 13.93        1
# 13.95        1
# 13.97        5
# 14.00      381
# 14.02        1
# 14.04        3
# 14.05        1
# 14.06        1
# 14.09        1
# 14.10       23
# 14.14        5
# 14.14        1
# 14.17        1
# 14.20       40
# 14.22        1
# 14.24        1
# 14.27        2
# 14.28        1
# 14.29        1
# 14.30       36
# 14.31        2
# 14.31        7
# 14.33        1
# 14.36        1
# 14.40       34
# 14.43        1
# 14.46        1
# 14.48        5
# 14.49        1
# 14.50       47
# 14.51        1
# 14.52        1
# 14.55        1
# 14.55        1
# 14.56        1
# 14.57        1
# 14.58        2
# 14.59        2
# 14.60       27
# 14.61        2
# 14.64        2
# 14.65        1
# 14.66        6
# 14.70       35
# 14.72        1
# 14.74        1
# 14.74        1
# 14.76        1
# 14.77        1
# 14.80       36
# 14.83        2
# 14.84        1
# 14.85        1
# 14.90        1
# 14.90       26
# 14.93        1
# 14.93        2
# 14.95        1
# 14.97        1
# 14.97        2
# 14.98        1
# 14.98        1
# 15.00      351
# 15.00        7
# 15.03        1
# 15.03        1
# 15.07        2
# 15.09        1
# 15.10       32
# 15.10        2
# 15.15        1
# 15.17        5
# 15.18        1
# 15.20       28
# 15.24        1
# 15.26        1
# 15.26        1
# 15.30       33
# 15.33        2
# 15.34        3
# 15.35        1
# 15.36        1
# 15.37        1
# 15.39        1
# 15.40       24
# 15.42        1
# 15.43        1
# 15.50       46
# 15.52        7
# 15.54        1
# 15.55        1
# 15.57        1
# 15.60       27
# 15.61        1
# 15.62        1
# 15.69        5
# 15.69        2
# 15.70       12
# 15.72        2
# 15.78        1
# 15.78        1
# 15.79        1
# 15.80       14
# 15.83        1
# 15.84        1
# 15.85        2
# 15.86        3
# 15.90        2
# 15.90       16
# 15.98        1
# 16.00      180
# 16.03        1
# 16.03        5
# 16.05        1
# 16.07        2
# 16.07        1
# 16.10       14
# 16.14        1
# 16.20       15
# 16.21        4
# 16.22        2
# 16.25        5
# 16.26        1
# 16.27        1
# 16.30       16
# 16.31        1
# 16.32        1
# 16.38        7
# 16.38        1
# 16.40       18
# 16.42        1
# 16.45        2
# 16.46        1
# 16.47        2
# 16.47        1
# 16.48        1
# 16.50       34
# 16.53        1
# 16.55        2
# 16.60       14
# 16.64        1
# 16.66        1
# 16.67        1
# 16.70       13
# 16.71        1
# 16.72        1
# 16.72        4
# 16.74        1
# 16.74        1
# 16.76        1
# 16.77        1
# 16.78        1
# 16.80       19
# 16.83        1
# 16.88        1
# 16.88        1
# 16.89        1
# 16.90        5
# 16.90       11
# 16.91        1
# 16.92        2
# 16.97        1
# 17.00      118
# 17.02        1
# 17.06        2
# 17.07        2
# 17.09        2
# 17.10       15
# 17.12        1
# 17.20       14
# 17.22        1
# 17.24        8
# 17.28        1
# 17.30       13
# 17.34        1
# 17.40       17
# 17.41        1
# 17.44        1
# 17.48        1
# 17.50       18
# 17.53        1
# 17.55        2
# 17.59        2
# 17.59        1
# 17.60       14
# 17.61        1
# 17.64        1
# 17.70       12
# 17.71        1
# 17.76        2
# 17.80       20
# 17.81        1
# 17.85        1
# 17.86        1
# 17.87        1
# 17.90        6
# 17.93        2
# 17.95        1
# 18.00      103
# 18.07        1
# 18.10        6
# 18.10        3
# 18.12        1
# 18.16        1
# 18.20       10
# 18.25        1
# 18.28        3
# 18.30       13
# 18.33        1
# 18.34        2
# 18.40        1
# 18.40        6
# 18.41        1
# 18.45        4
# 18.45        2
# 18.50       13
# 18.55        1
# 18.59        1
# 18.60        8
# 18.62        3
# 18.64        1
# 18.69        1
# 18.70        8
# 18.74        1
# 18.78        1
# 18.79        2
# 18.80       11
# 18.88        2
# 18.90        9
# 18.93        1
# 18.97        4
# 19.00       69
# 19.09        1
# 19.10        9
# 19.14        1
# 19.19        1
# 19.20       12
# 19.21        1
# 19.28        1
# 19.29        1
# 19.30        6
# 19.31        3
# 19.34        1
# 19.35        2
# 19.39        1
# 19.40        7
# 19.42        1
# 19.45        1
# 19.48        1
# 19.50       12
# 19.51        1
# 19.60        5
# 19.61        1
# 19.64        1
# 19.66        2
# 19.67        1
# 19.69        1
# 19.70       12
# 19.80        5
# 19.90        5
# 19.92        1
# 19.94        1
# 20.00      137
# 20.04        1
# 20.07        1
# 20.10        4
# 20.12        1
# 20.16        1
# 20.19        1
# 20.20        2
# 20.22        1
# 20.24        2
# 20.30        3
# 20.31        1
# 20.34        2
# 20.38        2
# 20.40        1
# 20.50        7
# 20.52        1
# 20.52        1
# 20.56        1
# 20.60        7
# 20.62        1
# 20.69        3
# 20.70        7
# 20.77        1
# 20.80        5
# 20.86        1
# 20.90        4
# 20.91        1
# 20.92        1
# 21.00       41
# 21.09        1
# 21.10        5
# 21.20        4
# 21.21        2
# 21.22        1
# 21.24        1
# 21.25        1
# 21.29        1
# 21.30        7
# 21.38        1
# 21.40        6
# 21.43        1
# 21.50       12
# 21.53        1
# 21.55        1
# 21.55        2
# 21.60        3
# 21.70        5
# 21.74        1
# 21.76        2
# 21.80        3
# 21.82        1
# 21.87        1
# 21.90        1
# 21.90        6
# 22.00       55
# 22.10        5
# 22.15        1
# 22.20        3
# 22.22        1
# 22.30        8
# 22.31        1
# 22.40        6
# 22.41        3
# 22.43        1
# 22.46        1
# 22.50        9
# 22.60        4
# 22.70        5
# 22.72        1
# 22.76        1
# 22.78        1
# 22.80        1
# 22.84        1
# 22.90        3
# 23.00       42
# 23.10        6
# 23.10        3
# 23.19        1
# 23.20        2
# 23.25        1
# 23.28        1
# 23.29        1
# 23.30        8
# 23.38        1
# 23.40        1
# 23.40        2
# 23.42        2
# 23.43        1
# 23.45        1
# 23.50        6
# 23.53        2
# 23.60        4
# 23.70        1
# 23.71        1
# 23.79        3
# 23.80        4
# 23.90        5
# 24.00       31
# 24.03        1
# 24.10        1
# 24.10        1
# 24.20        1
# 24.30        3
# 24.40        6
# 24.50        7
# 24.60        1
# 24.66        1
# 24.70        5
# 24.80        1
# 24.89        1
# 24.90        1
# 25.00       63
# 25.02        1
# 25.10        2
# 25.11        1
# 25.17        1
# 25.20        3
# 25.30        4
# 25.34        1
# 25.40        2
# 25.47        1
# 25.50        1
# 25.52        1
# 25.60        2
# 25.69        1
# 25.70        1
# 25.86        1
# 25.86        1
# 25.90        2
# 26.00       30
# 26.10        2
# 26.20        1
# 26.21        1
# 26.38        1
# 26.40        3
# 26.50        2
# 26.57        1
# 26.60        1
# 26.70        1
# 26.72        2
# 26.76        1
# 26.78        1
# 26.80        1
# 26.85        1
# 26.90        2
# 26.90        3
# 26.97        1
# 27.00       17
# 27.07        1
# 27.10        1
# 27.12        1
# 27.20        1
# 27.24        2
# 27.30        1
# 27.40        3
# 27.41        1
# 27.50        1
# 27.57        1
# 27.59        2
# 27.60        1
# 27.71        1
# 27.76        1
# 27.76        1
# 27.90        5
# 27.93        1
# 28.00       28
# 28.10        1
# 28.20        1
# 28.30        2
# 28.40        3
# 28.50        1
# 28.52        1
# 28.56        1
# 28.60        1
# 28.63        1
# 28.64        1
# 28.70        1
# 28.80        2
# 29.00        8
# 29.09        1
# 29.10        2
# 29.20        1
# 29.30        2
# 29.31        3
# 29.40        5
# 29.50        1
# 29.70        1
# 29.80        2
# 29.84        1
# 29.86        1
# 29.90        4
# 30.00       60
# 30.00        1
# 30.09        1
# 30.17        1
# 30.20        3
# 30.29        1
# 30.50        1
# 30.59        1
# 30.60        2
# 30.80        1
# 30.90        2
# 31.00        9
# 31.03        1
# 31.20        2
# 31.30        1
# 31.40        1
# 31.47        1
# 31.50        1
# 31.60        1
# 31.70        2
# 31.73        2
# 31.78        1
# 31.80        1
# 32.00       12
# 32.10        3
# 32.30        1
# 32.40        1
# 32.41        2
# 32.55        1
# 32.59        1
# 32.60        1
# 32.70        1
# 32.80        1
# 32.90        1
# 33.00        9
# 33.10        1
# 33.60        1
# 33.79        2
# 33.80        1
# 33.90        2
# 33.97        1
# 34.00        5
# 34.10        1
# 34.19        1
# 34.30        1
# 34.34        1
# 34.40        1
# 34.48        1
# 34.51        1
# 34.60        1
# 34.70        2
# 34.74        1
# 34.78        1
# 34.80        1
# 35.00       25
# 35.05        1
# 35.10        1
# 35.17        1
# 35.35        1
# 35.40        1
# 35.50        2
# 35.60        1
# 35.70        1
# 35.90        2
# 36.00       12
# 36.20        2
# 36.30        2
# 36.40        2
# 36.50        1
# 36.60        1
# 36.72        1
# 37.00        5
# 37.50        1
# 37.60        1
# 37.70        3
# 37.78        1
# 37.80        1
# 37.90        1
# 37.93        1
# 38.00        6
# 38.10        1
# 38.86        1
# 39.00        5
# 39.10        2
# 39.31        1
# 39.66        2
# 39.70        1
# 39.90        1
# 40.00       24
# 40.10        1
# 40.20        3
# 40.30        1
# 40.34        1
# 40.40        1
# 40.52        1
# 40.70        1
# 41.00        8
# 41.10        1
# 41.30        1
# 41.55        1
# 41.60        1
# 41.90        1
# 42.00        3
# 42.24        1
# 42.40        2
# 42.50        2
# 42.60        1
# 42.70        1
# 42.80        2
# 42.93        1
# 43.00        2
# 43.20        1
# 43.28        1
# 43.40        3
# 43.80        1
# 44.00        3
# 44.70        2
# 44.90        1
# 45.00       15
# 45.50        1
# 46.00        4
# 46.80        1
# 47.00        1
# 48.00        3
# 48.28        2
# 48.30        1
# 48.50        1
# 49.20        1
# 49.40        1
# 50.00       12
# 50.20        1
# 50.86        1
# 51.00        3
# 51.80        1
# 52.41        1
# 53.00        2
# 53.10        1
# 54.00        1
# 54.20        1
# 54.30        1
# 54.53        1
# 54.66        1
# 55.50        1
# 55.70        1
# 56.00        3
# 56.20        1
# 58.00        1
# 58.40        1
# 60.00        3
# 62.00        1
# 62.50        1
# 62.88        1
# 62.93        1
# 63.00        2
# 63.40        1
# 64.00        3
# 65.00        2
# 65.52        1
# 66.00        1
# 68.79        1
# 68.97        1
# 70.00        1
# 72.00        1
# 72.79        1
# 75.00        1
# 77.00        2
# 85.19        1
# 86.21        1
# 87.20        1
# 93.00        1
# 93.20        1
# 100.00       1
# 100.70       1
# 107.00       1
# Name: kitchen_area, dtype: int64

# %%
# смотрим общий график
df['kitchen_area'].hist(figsize = (12,4), bins = 100);

# %%
# смотрим кухни до 3 кв. метров
df['kitchen_area'].hist(figsize = (12,4), bins = 100, range = (0,3));

# %% [markdown]
# Видим, что у нас  есть  очень маленькие площади кухни, до 3 кв. метров  значения не адекватные.  Заменим их также как маленькие значения в жилой площади.

# %%
# срез маленьких по площади кухни квартир
df.query('kitchen_area < 3')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 906              15     2600000       27.00           2017-07-10      1
# 6260              9     3100000       24.00           2018-06-25      2
# 7948              3     5967734       66.40           2017-02-07      2
# 8727              9     2200000       18.40           2018-08-20      1
# 9135             17     2920000       23.29           2018-12-12      1
# 9409              5     2100000       16.00           2017-12-10      1
# 11030             6     5350000       32.00           2016-04-20      1
# 12037             5     1900000       15.00           2018-06-27      1
# 16360             2     2720000       25.70           2017-10-30      1
# 16941             9     1550000       15.00           2018-08-21      1
# 17826             5     2940000       34.70           2017-10-09      1
# 17953             3     1400000       13.00           2017-12-03      1
# 19536             3     1850000       13.00           2019-03-11      1
# 19548             2     1686000       13.20           2018-12-17      1
# 19632             5     1190000       14.00           2018-07-29      1
# 19797             0     3800000       13.00           2018-07-04      1
# 19894             4     2400000       12.00           2017-07-19      1
# 20207             7     4250000       28.50           2019-05-01      1
# 21409             4     1870000       20.00           2018-03-06      1
# 22345             6     2050000       17.20           2019-01-13      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 906              2.75            23        18.00     18         False  ...
# 6260             3.00             5        16.00      5         False  ...
# 7948             2.65             4        44.40      2         False  ...
# 8727             2.52             3        14.00      3         False  ...
# 9135             2.65             3        21.00      1         False  ...
# 9409             2.65             6        13.00      1         False  ...
# 11030            2.65            14        16.00     10         False  ...
# 12037            2.50             5         8.50      1         False  ...
# 16360            2.65            19        22.60     11         False  ...
# 16941            2.70             9         8.50      1         False  ...
# 17826            2.65            26        15.50     14         False  ...
# 17953            2.60             9         7.40      1         False  ...
# 19536            3.40             5         7.40      2         False  ...
# 19548            2.65             5         7.50      1         False  ...
# 19632            2.65             5        11.00      1         False  ...
# 19797            2.65             5        10.00      3         False  ...
# 19894            2.55             5        10.00      2         False  ...
# 20207            2.80            14        19.50     10         False  ...
# 21409            2.50             5        14.00      1         False  ...
# 22345            2.77            23         9.80      1         False  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 906            2.00        0  Санкт-Петербург          22131.00
# 6260           2.00        0  Санкт-Петербург          31960.00
# 7948           2.89        0  Санкт-Петербург          44870.00
# 8727           2.40        0           Пушкин          20710.00
# 9135           2.00        0  Санкт-Петербург          19506.00
# 9409           2.76        0  Санкт-Петербург          20735.00
# 11030          2.00        0  Санкт-Петербург          19008.00
# 12037          2.59        0     Сосновый Бор               nan
# 16360          2.00        0  Санкт-Петербург          14472.00
# 16941          2.59        0  Санкт-Петербург          51048.00
# 17826          2.30        1   поселок Мурино               nan
# 17953          2.24        0  Санкт-Петербург          14350.00
# 19536          2.24        0  Санкт-Петербург          24915.00
# 19548          2.28        0  Санкт-Петербург          19891.00
# 19632          2.00        0  Санкт-Петербург           9898.00
# 19797          2.24        0  Санкт-Петербург          21302.00
# 19894          2.07        0  Санкт-Петербург          21314.00
# 20207          1.30        0  Санкт-Петербург          37199.00
# 21409          2.00        0  Санкт-Петербург          16652.00
# 22345          2.97        0  Санкт-Петербург          33645.00
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 906              17459.00              0.00            nan              1.00
# 6260              4914.00              2.00         426.00              1.00
# 7948             20802.00              0.00            nan              0.00
# 8727             30687.00              0.00            nan              1.00
# 9135              4008.00              0.00            nan              2.00
# 9409              2111.00              2.00         228.00              3.00
# 11030             3953.00              0.00            nan              1.00
# 12037                 nan               nan            nan               nan
# 16360            13268.00              0.00            nan              0.00
# 16941            16376.00              0.00            nan              1.00
# 17826                 nan               nan            nan               nan
# 17953            15945.00              0.00            nan              1.00
# 19536             5483.00              1.00         644.00              0.00
# 19548             4165.00              1.00         361.00              1.00
# 19632            11122.00              0.00            nan              0.00
# 19797             1242.00              1.00         592.00              3.00
# 19894              964.00              1.00         886.00              2.00
# 20207            12721.00              0.00            nan              0.00
# 21409            15654.00              1.00         619.00              1.00
# 22345            13513.00              0.00            nan              0.00
#
#        ponds_nearest  days_exposition
# 906           411.00            10.00
# 6260          936.00            54.00
# 7948             nan           335.00
# 8727          155.00            59.00
# 9135           45.00           107.00
# 9409           72.00             3.00
# 11030          69.00           210.00
# 12037            nan            45.00
# 16360            nan           109.00
# 16941        1079.00            42.00
# 17826            nan           318.00
# 17953         185.00           410.00
# 19536            nan            24.00
# 19548         155.00            19.00
# 19632            nan             4.00
# 19797          27.00             9.00
# 19894          45.00           200.00
# 20207            nan              nan
# 21409         937.00            45.00
# 22345            nan             7.00
#
# [20 rows x 22 columns]

# %%
# меняем некорректную площадь кухни на подходящую 
df.loc[df['kitchen_area'] < 3, 'kitchen_area'] = df['total_area'] - df['kitchen_area'] - df['total_area']*part_other

# %% [markdown]
# Для удобства округлим значения в столбце до десятых

# %%
# округляем значения до десятых
df['kitchen_area'] = round(df['kitchen_area'],1)

# %%
# числовое описание столбца
df['kitchen_area'].describe()
# Out:
# count   23537.00
# mean       10.52
# std         5.95
# min         3.00
# 25%         7.00
# 50%         9.00
# 75%        12.00
# max       107.00
# Name: kitchen_area, dtype: float64

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000      108.00           2019-03-07      3
# 1             7     3350000       40.40           2018-12-04      1
# 2            10     5196000       56.00           2015-08-20      2
# 3             0    64900000      159.00           2015-07-24      3
# 4             2    10000000      100.00           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16        51.00      8         False  ...
# 1            2.65            11        18.60      1         False  ...
# 2            2.65             5        34.30      4         False  ...
# 3            2.65            14        90.20      9         False  ...
# 4            3.03            14        32.00     13         False  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0         25.00        0  Санкт-Петербург          18863.00
# 1         11.00        2   поселок Шушары          12817.00
# 2          8.30        0  Санкт-Петербург          21741.00
# 3         27.40        0  Санкт-Петербург          28098.00
# 4         41.00        0  Санкт-Петербург          31856.00
#
#   cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0            16028.00              1.00         482.00              2.00
# 1            18603.00              0.00            nan              0.00
# 2            13933.00              1.00          90.00              2.00
# 3             6800.00              2.00          84.00              3.00
# 4             8098.00              2.00         112.00              1.00
#
#    ponds_nearest  days_exposition
# 0         755.00              nan
# 1            nan            81.00
# 2         574.00           558.00
# 3         234.00           424.00
# 4          48.00           121.00
#
# [5 rows x 22 columns]

# %% [markdown]
# Заменили пропуски и некорректные значения в столбцах на логически подходящие.  В квартирах студиях пропуски в столбце 'kitchen_area' не меняли, так как в таких квартирах нет отдельной кухни, в этом столбце 147 пропусков.

# %% [markdown]
# #### Столбец  'days_exposition'

# %%
# Смотрим уникальные значения
df['days_exposition'].value_counts().sort_index(ascending=True)
# Out:
# 1.00         1
# 2.00         3
# 3.00       158
# 4.00       176
# 5.00       152
# 6.00       124
# 7.00       234
# 8.00       138
# 9.00       143
# 10.00      127
# 11.00      135
# 12.00      108
# 13.00      127
# 14.00      148
# 15.00      126
# 16.00      100
# 17.00      116
# 18.00      129
# 19.00      121
# 20.00      139
# 21.00      124
# 22.00      125
# 23.00      112
# 24.00      116
# 25.00       83
# 26.00      104
# 27.00      110
# 28.00      126
# 29.00      122
# 30.00      208
# 31.00       66
# 32.00       90
# 33.00       88
# 34.00      115
# 35.00      120
# 36.00       90
# 37.00       96
# 38.00       79
# 39.00       81
# 40.00       93
# 41.00       76
# 42.00      115
# 43.00      107
# 44.00      138
# 45.00      880
# 46.00       91
# 47.00       77
# 48.00       78
# 49.00       70
# 50.00       61
# 51.00       52
# 52.00       84
# 53.00       81
# 54.00      110
# 55.00       75
# 56.00       86
# 57.00       74
# 58.00       72
# 59.00      106
# 60.00      538
# 61.00      109
# 62.00       74
# 63.00       99
# 64.00       88
# 65.00       74
# 66.00       70
# 67.00       93
# 68.00       73
# 69.00       68
# 70.00       73
# 71.00       70
# 72.00       73
# 73.00       66
# 74.00      106
# 75.00       69
# 76.00       55
# 77.00       64
# 78.00       51
# 79.00       60
# 80.00       65
# 81.00       59
# 82.00       64
# 83.00       62
# 84.00       75
# 85.00       70
# 86.00       58
# 87.00       43
# 88.00       65
# 89.00      101
# 90.00      203
# 91.00       71
# 92.00       81
# 93.00       69
# 94.00       49
# 95.00       64
# 96.00       55
# 97.00       66
# 98.00       68
# 99.00       52
# 100.00      54
# 101.00      42
# 102.00      59
# 103.00      57
# 104.00      70
# 105.00      57
# 106.00      54
# 107.00      53
# 108.00      46
# 109.00      39
# 110.00      48
# 111.00      54
# 112.00      66
# 113.00      72
# 114.00      51
# 115.00      58
# 116.00      67
# 117.00      57
# 118.00      58
# 119.00      62
# 120.00      64
# 121.00      43
# 122.00      33
# 123.00      46
# 124.00      39
# 125.00      46
# 126.00      50
# 127.00      39
# 128.00      38
# 129.00      27
# 130.00      46
# 131.00      49
# 132.00      44
# 133.00      44
# 134.00      52
# 135.00      45
# 136.00      40
# 137.00      48
# 138.00      40
# 139.00      55
# 140.00      42
# 141.00      39
# 142.00      44
# 143.00      48
# 144.00      45
# 145.00      56
# 146.00      43
# 147.00      38
# 148.00      16
# 149.00      33
# 150.00      41
# 151.00      40
# 152.00      34
# 153.00      32
# 154.00      45
# 155.00      40
# 156.00      40
# 157.00      35
# 158.00      34
# 159.00      36
# 160.00      41
# 161.00      47
# 162.00      40
# 163.00      36
# 164.00      30
# 165.00      32
# 166.00      36
# 167.00      33
# 168.00      48
# 169.00      34
# 170.00      30
# 171.00      26
# 172.00      38
# 173.00      34
# 174.00      36
# 175.00      32
# 176.00      32
# 177.00      28
# 178.00      33
# 179.00      47
# 180.00      43
# 181.00      38
# 182.00      38
# 183.00      31
# 184.00      25
# 185.00      28
# 186.00      29
# 187.00      24
# 188.00      31
# 189.00      36
# 190.00      26
# 191.00      36
# 192.00      22
# 193.00      31
# 194.00      25
# 195.00      26
# 196.00      30
# 197.00      31
# 198.00      23
# 199.00      38
# 200.00      24
# 201.00      29
# 202.00      32
# 203.00      27
# 204.00      22
# 205.00      27
# 206.00      20
# 207.00      23
# 208.00      23
# 209.00      23
# 210.00      30
# 211.00      29
# 212.00      22
# 213.00      21
# 214.00      22
# 215.00      26
# 216.00      33
# 217.00      31
# 218.00      25
# 219.00      28
# 220.00      17
# 221.00      16
# 222.00      21
# 223.00      17
# 224.00      19
# 225.00      26
# 226.00      22
# 227.00      16
# 228.00      23
# 229.00      22
# 230.00      18
# 231.00      23
# 232.00      33
# 233.00      24
# 234.00      17
# 235.00      18
# 236.00      15
# 237.00      19
# 238.00      23
# 239.00      24
# 240.00      21
# 241.00      18
# 242.00      12
# 243.00      10
# 244.00      20
# 245.00      28
# 246.00      24
# 247.00      13
# 248.00      15
# 249.00      24
# 250.00      15
# 251.00      21
# 252.00      22
# 253.00      18
# 254.00      13
# 255.00      14
# 256.00      19
# 257.00      15
# 258.00      16
# 259.00      26
# 260.00      15
# 261.00      17
# 262.00      10
# 263.00      18
# 264.00      22
# 265.00      20
# 266.00      21
# 267.00       9
# 268.00      19
# 269.00      15
# 270.00      15
# 271.00      21
# 272.00      26
# 273.00      21
# 274.00      13
# 275.00      18
# 276.00      17
# 277.00      22
# 278.00      20
# 279.00      17
# 280.00      21
# 281.00      15
# 282.00      13
# 283.00      13
# 284.00      20
# 285.00      22
# 286.00      19
# 287.00      14
# 288.00      12
# 289.00      16
# 290.00      17
# 291.00       9
# 292.00      14
# 293.00      14
# 294.00      17
# 295.00      11
# 296.00      18
# 297.00      11
# 298.00      17
# 299.00      13
# 300.00      19
# 301.00      18
# 302.00      14
# 303.00      17
# 304.00       9
# 305.00       9
# 306.00      17
# 307.00      20
# 308.00      14
# 309.00      10
# 310.00      13
# 311.00      12
# 312.00      13
# 313.00      21
# 314.00      13
# 315.00      14
# 316.00      13
# 317.00      13
# 318.00      16
# 319.00      12
# 320.00      15
# 321.00      10
# 322.00       9
# 323.00      16
# 324.00      19
# 325.00      20
# 326.00      14
# 327.00      15
# 328.00      16
# 329.00      17
# 330.00      12
# 331.00       9
# 332.00      13
# 333.00       9
# 334.00       8
# 335.00      21
# 336.00      14
# 337.00      13
# 338.00      13
# 339.00      13
# 340.00       8
# 341.00       8
# 342.00      14
# 343.00      13
# 344.00      10
# 345.00       9
# 346.00      11
# 347.00      14
# 348.00      15
# 349.00      16
# 350.00      21
# 351.00       9
# 352.00      11
# 353.00      11
# 354.00      14
# 355.00      12
# 356.00      13
# 357.00      16
# 358.00       8
# 359.00       9
# 360.00      17
# 361.00      12
# 362.00       7
# 363.00      12
# 364.00      18
# 365.00      17
# 366.00      14
# 367.00      13
# 368.00       8
# 369.00      12
# 370.00      18
# 371.00      10
# 372.00      12
# 373.00       3
# 374.00      12
# 375.00       9
# 376.00      14
# 377.00      13
# 378.00      17
# 379.00      13
# 380.00       8
# 381.00      11
# 382.00       6
# 383.00      18
# 384.00       9
# 385.00      20
# 386.00       7
# 387.00      13
# 388.00      23
# 389.00      13
# 390.00      13
# 391.00      13
# 392.00       9
# 393.00       8
# 394.00      12
# 395.00      10
# 396.00      12
# 397.00       9
# 398.00       8
# 399.00       8
# 400.00       8
# 401.00      13
# 402.00      12
# 403.00      10
# 404.00      10
# 405.00       5
# 406.00      15
# 407.00       9
# 408.00       9
# 409.00      10
# 410.00      11
# 411.00      15
# 412.00      12
# 413.00      12
# 414.00      13
# 415.00       6
# 416.00       7
# 417.00      10
# 418.00      18
# 419.00      11
# 420.00       9
# 421.00       5
# 422.00      13
# 423.00       8
# 424.00      11
# 425.00      12
# 426.00      11
# 427.00       6
# 428.00      13
# 429.00       6
# 430.00      11
# 431.00      15
# 432.00       9
# 433.00       8
# 434.00      10
# 435.00      10
# 436.00      15
# 437.00       7
# 438.00      10
# 439.00      16
# 440.00      10
# 441.00      13
# 442.00       9
# 443.00      11
# 444.00       8
# 445.00       9
# 446.00       6
# 447.00      16
# 448.00       8
# 449.00      13
# 450.00       6
# 451.00       8
# 452.00       5
# 453.00      13
# 454.00       5
# 455.00       7
# 456.00       5
# 457.00       4
# 458.00       5
# 459.00       8
# 460.00       8
# 461.00       6
# 462.00       7
# 463.00       4
# 464.00       8
# 465.00       7
# 466.00       6
# 467.00       9
# 468.00      19
# 469.00      11
# 470.00       6
# 471.00       5
# 472.00       6
# 473.00       9
# 474.00       4
# 475.00       8
# 476.00       8
# 477.00      10
# 478.00       7
# 479.00       8
# 480.00      13
# 481.00       9
# 482.00       9
# 483.00      11
# 484.00       9
# 485.00       7
# 486.00       4
# 487.00       8
# 488.00      10
# 489.00       7
# 490.00       4
# 491.00       9
# 492.00       4
# 493.00       7
# 494.00       6
# 495.00       4
# 496.00       4
# 497.00       7
# 498.00       8
# 499.00       5
# 500.00       5
# 501.00       6
# 502.00       7
# 503.00       7
# 504.00       6
# 505.00      10
# 506.00       7
# 507.00      11
# 508.00       3
# 509.00       7
# 510.00       6
# 511.00       5
# 512.00       5
# 513.00       4
# 514.00       3
# 515.00       4
# 516.00       9
# 517.00       6
# 518.00       7
# 519.00       5
# 520.00       7
# 521.00       7
# 522.00       3
# 523.00       7
# 524.00       8
# 525.00       4
# 526.00       1
# 527.00       3
# 528.00       6
# 529.00       3
# 530.00       3
# 531.00       6
# 532.00       4
# 533.00       6
# 534.00       4
# 535.00       2
# 536.00       7
# 537.00       5
# 538.00       2
# 539.00       8
# 540.00       4
# 541.00       6
# 542.00       5
# 543.00       8
# 544.00       6
# 545.00       6
# 546.00       7
# 547.00       7
# 548.00       2
# 549.00      13
# 550.00       4
# 551.00       9
# 552.00       8
# 553.00       7
# 554.00       5
# 555.00       3
# 556.00       6
# 557.00       6
# 558.00       6
# 559.00       7
# 560.00       6
# 561.00       5
# 562.00       6
# 563.00       5
# 564.00       6
# 565.00       5
# 566.00       6
# 567.00       2
# 568.00       4
# 569.00       4
# 570.00       7
# 571.00       5
# 572.00       2
# 573.00       7
# 574.00      10
# 575.00       9
# 576.00       4
# 577.00       2
# 578.00       6
# 579.00       6
# 580.00       5
# 581.00       8
# 582.00       5
# 583.00       3
# 584.00       7
# 585.00       6
# 586.00       4
# 587.00       6
# 588.00       4
# 589.00       3
# 590.00       5
# 591.00       7
# 592.00       2
# 593.00       4
# 594.00      11
# 595.00       5
# 596.00       3
# 597.00       1
# 598.00       4
# 599.00       8
# 600.00       4
# 601.00       6
# 602.00       6
# 603.00       3
# 604.00       3
# 605.00       4
# 606.00       5
# 607.00       3
# 608.00       5
# 609.00       2
# 610.00       4
# 611.00       3
# 612.00       2
# 613.00       5
# 614.00       3
# 615.00       5
# 616.00       6
# 617.00       5
# 618.00       4
# 619.00       2
# 620.00       4
# 621.00       6
# 622.00       5
# 623.00       4
# 624.00       5
# 625.00       4
# 626.00      10
# 627.00       5
# 628.00       1
# 629.00       2
# 630.00       3
# 631.00       4
# 634.00       1
# 635.00       7
# 636.00       3
# 637.00       5
# 638.00       7
# 640.00       3
# 641.00       3
# 642.00       2
# 643.00       4
# 644.00       1
# 645.00       2
# 646.00       3
# 647.00       3
# 648.00       5
# 649.00       7
# 650.00       4
# 651.00       2
# 652.00       2
# 653.00       7
# 654.00       5
# 655.00       2
# 656.00       4
# 657.00       1
# 658.00       5
# 659.00       3
# 660.00       4
# 661.00       6
# 662.00       5
# 663.00       2
# 664.00       4
# 665.00       2
# 666.00       3
# 667.00       6
# 668.00       3
# 669.00       2
# 671.00       1
# 672.00       6
# 673.00       1
# 674.00       4
# 675.00       3
# 676.00       6
# 677.00       4
# 678.00       4
# 679.00       5
# 680.00       3
# 681.00       1
# 682.00       5
# 683.00       3
# 684.00       2
# 686.00       4
# 688.00       5
# 689.00       4
# 690.00       8
# 692.00       2
# 693.00       1
# 694.00       4
# 696.00       1
# 697.00       1
# 698.00       3
# 699.00       1
# 700.00       2
# 701.00       3
# 702.00       5
# 703.00       5
# 704.00       6
# 705.00       3
# 706.00       3
# 707.00       6
# 708.00       2
# 709.00       1
# 710.00       3
# 711.00       3
# 712.00       1
# 713.00       4
# 714.00       3
# 715.00       6
# 716.00       1
# 717.00       2
# 718.00       3
# 719.00      11
# 720.00       2
# 721.00       4
# 722.00       5
# 723.00       1
# 724.00       4
# 725.00       5
# 726.00       6
# 727.00       5
# 729.00       3
# 730.00       1
# 731.00       3
# 732.00       2
# 733.00       3
# 734.00       1
# 735.00       3
# 737.00       2
# 739.00       1
# 740.00       4
# 741.00       3
# 742.00       1
# 743.00       7
# 744.00       1
# 745.00       1
# 746.00       4
# 747.00       1
# 748.00       1
# 750.00       5
# 751.00       2
# 752.00       3
# 753.00       1
# 754.00       3
# 755.00       1
# 756.00       2
# 757.00       3
# 758.00       5
# 759.00       3
# 760.00       7
# 762.00       1
# 763.00       2
# 764.00       3
# 765.00       5
# 767.00       2
# 768.00       1
# 769.00       1
# 770.00       3
# 773.00       1
# 774.00       1
# 775.00       1
# 776.00       2
# 777.00       2
# 778.00       3
# 779.00       4
# 780.00       2
# 781.00       4
# 782.00       2
# 783.00       1
# 784.00       1
# 785.00       3
# 786.00       1
# 787.00       4
# 788.00      10
# 789.00       1
# 790.00       2
# 791.00       2
# 792.00       4
# 793.00       1
# 794.00       2
# 795.00       1
# 796.00       5
# 797.00       1
# 798.00       2
# 799.00       2
# 800.00       3
# 801.00       2
# 802.00       3
# 803.00       1
# 804.00       3
# 806.00       3
# 807.00       1
# 808.00       2
# 810.00       2
# 812.00       2
# 813.00       2
# 814.00       3
# 815.00       2
# 816.00       3
# 817.00       2
# 818.00       1
# 819.00       2
# 820.00       2
# 821.00       1
# 822.00       1
# 823.00       3
# 825.00       3
# 826.00       2
# 828.00       2
# 830.00       1
# 831.00       1
# 832.00       1
# 834.00       3
# 835.00       4
# 836.00       2
# 837.00       2
# 838.00       2
# 839.00       2
# 840.00       2
# 841.00       2
# 842.00       1
# 843.00       2
# 844.00       1
# 845.00       3
# 846.00       2
# 847.00       1
# 848.00       3
# 849.00       2
# 850.00       1
# 851.00       1
# 852.00       3
# 853.00       2
# 854.00       1
# 856.00       4
# 857.00       2
# 858.00       4
# 859.00       2
# 863.00       3
# 864.00       6
# 865.00       2
# 866.00       1
# 868.00       2
# 869.00       5
# 870.00       5
# 871.00       1
# 872.00       3
# 873.00       1
# 875.00       2
# 876.00       1
# 877.00       4
# 879.00       4
# 880.00       1
# 881.00       4
# 884.00       2
# 885.00       1
# 886.00       3
# 888.00       5
# 889.00       2
# 890.00       1
# 891.00       2
# 892.00       2
# 893.00       2
# 894.00       1
# 895.00       3
# 896.00       2
# 897.00       1
# 898.00       1
# 900.00       6
# 901.00       2
# 903.00       2
# 905.00       1
# 906.00       1
# 907.00       1
# 910.00       4
# 911.00       2
# 912.00       2
# 914.00       1
# 915.00       2
# 917.00       2
# 918.00       2
# 919.00       5
# 920.00       1
# 921.00       1
# 922.00       2
# 923.00       1
# 924.00       3
# 925.00       1
# 927.00       2
# 928.00       1
# 931.00       2
# 933.00       1
# 934.00       1
# 937.00       1
# 938.00       1
# 939.00       4
# 940.00       3
# 942.00       2
# 943.00       2
# 945.00       1
# 946.00       5
# 947.00       4
# 948.00       2
# 951.00       1
# 954.00       1
# 955.00       1
# 956.00       3
# 957.00       1
# 959.00       2
# 960.00       3
# 961.00       2
# 962.00       2
# 963.00       1
# 964.00       1
# 966.00       2
# 967.00       2
# 969.00       1
# 970.00       4
# 971.00       1
# 972.00       2
# 974.00       4
# 975.00       1
# 976.00       1
# 977.00       2
# 978.00       1
# 979.00       3
# 980.00       2
# 982.00       1
# 983.00       2
# 984.00       1
# 985.00       1
# 986.00       1
# 987.00       1
# 988.00       2
# 991.00       1
# 992.00       1
# 993.00       1
# 994.00       1
# 996.00       1
# 998.00       2
# 999.00       1
# 1000.00      2
# 1001.00      5
# 1002.00      2
# 1004.00      3
# 1005.00      2
# 1006.00      1
# 1007.00      1
# 1008.00      2
# 1011.00      1
# 1012.00      2
# 1013.00      2
# 1014.00      1
# 1015.00      1
# 1016.00      1
# 1017.00      1
# 1018.00      2
# 1021.00      1
# 1022.00      1
# 1028.00      1
# 1030.00      2
# 1032.00      1
# 1037.00      1
# 1039.00      2
# 1043.00      3
# 1045.00      1
# 1046.00      3
# 1047.00      2
# 1048.00      4
# 1049.00      1
# 1050.00      1
# 1052.00      1
# 1054.00      3
# 1055.00      2
# 1057.00      1
# 1058.00      1
# 1059.00      1
# 1060.00      1
# 1061.00      2
# 1064.00      1
# 1065.00      3
# 1066.00      1
# 1067.00      2
# 1069.00      2
# 1070.00      1
# 1071.00      1
# 1072.00      1
# 1074.00      1
# 1075.00      3
# 1076.00      1
# 1077.00      2
# 1078.00      4
# 1079.00      2
# 1080.00      1
# 1081.00      1
# 1082.00      1
# 1084.00      1
# 1085.00      3
# 1088.00      2
# 1089.00      1
# 1090.00      1
# 1091.00      1
# 1092.00      2
# 1093.00      2
# 1094.00      2
# 1095.00      4
# 1099.00      2
# 1100.00      1
# 1101.00      1
# 1103.00      2
# 1104.00      1
# 1105.00      1
# 1106.00      1
# 1107.00      1
# 1109.00      1
# 1110.00      1
# 1111.00      1
# 1112.00      1
# 1114.00      1
# 1116.00      1
# 1117.00      1
# 1119.00      1
# 1123.00      2
# 1125.00      1
# 1127.00      1
# 1130.00      1
# 1131.00      2
# 1133.00      1
# 1135.00      1
# 1136.00      1
# 1140.00      1
# 1141.00      2
# 1146.00      1
# 1147.00      1
# 1148.00      1
# 1149.00      2
# 1150.00      2
# 1151.00      1
# 1153.00      2
# 1154.00      1
# 1155.00      2
# 1157.00      1
# 1160.00      2
# 1161.00      2
# 1163.00      1
# 1164.00      2
# 1166.00      2
# 1168.00      1
# 1171.00      2
# 1174.00      1
# 1175.00      1
# 1177.00      2
# 1178.00      1
# 1179.00      1
# 1181.00      3
# 1182.00      1
# 1183.00      1
# 1187.00      1
# 1194.00      2
# 1196.00      1
# 1199.00      2
# 1200.00      1
# 1201.00      1
# 1202.00      2
# 1206.00      1
# 1209.00      1
# 1210.00      1
# 1212.00      1
# 1213.00      1
# 1214.00      2
# 1217.00      1
# 1218.00      1
# 1223.00      1
# 1225.00      1
# 1226.00      2
# 1228.00      1
# 1229.00      1
# 1231.00      1
# 1232.00      1
# 1239.00      2
# 1240.00      1
# 1252.00      1
# 1255.00      1
# 1257.00      1
# 1265.00      1
# 1268.00      1
# 1273.00      1
# 1275.00      2
# 1277.00      1
# 1278.00      1
# 1280.00      1
# 1281.00      1
# 1283.00      1
# 1292.00      1
# 1293.00      1
# 1299.00      1
# 1305.00      1
# 1309.00      1
# 1312.00      1
# 1313.00      1
# 1314.00      2
# 1315.00      1
# 1318.00      1
# 1322.00      1
# 1325.00      1
# 1332.00      1
# 1334.00      1
# 1336.00      1
# 1341.00      1
# 1344.00      1
# 1345.00      1
# 1346.00      2
# 1349.00      1
# 1350.00      1
# 1355.00      1
# 1360.00      1
# 1361.00      1
# 1362.00      1
# 1363.00      1
# 1365.00      1
# 1368.00      1
# 1373.00      1
# 1375.00      2
# 1391.00      1
# 1395.00      1
# 1396.00      1
# 1406.00      1
# 1413.00      1
# 1417.00      1
# 1430.00      1
# 1434.00      1
# 1441.00      1
# 1452.00      1
# 1458.00      1
# 1477.00      1
# 1484.00      1
# 1485.00      1
# 1489.00      1
# 1497.00      1
# 1512.00      2
# 1513.00      1
# 1553.00      1
# 1572.00      1
# 1580.00      1
# Name: days_exposition, dtype: int64

# %%
# смотрим количество пропусков
df['days_exposition'].isna().sum()
# Out:
# 3181

# %% [markdown]
#  В этом столбце  указаны данные о том сколько дней было размещено объявление (от публикации до снятия).  Предположительно пропуски в столбцах означают что объявление ещё не снято с публикации, квартира на момент  взятия данных ещё не проданы. Оставим  пропуски как есть.

# %% [markdown]
# #### Столбцы 'airports_nearest', 'cityCenters_nearest', 'parks_around3000', 'parks_nearest ponds_around3000', 'ponds_nearest'

# %% [markdown]
# По вводным данным нам известно, что  есть два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %%
# смотрим количество пропусков
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total               86
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area              147
# balcony                     0
# locality_name               0
# airports_nearest         5540
# cityCenters_nearest      5517
# parks_around3000         5516
# parks_nearest           15614
# ponds_around3000         5516
# ponds_nearest           14585
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Во всех столбцах примерно одинаковое количество пропусков, кроме столбца `parks_nearest` и `ponds_nearest` в них расстояние до ближайщего парка и водоема , предположительно большое количество пропусков в этих столбцах связанно с тем, что  до парка и водоема расстояние автомотически не получено из-за их отсутствия рядом с населенным пунктом. Расссмотрим детальнее.

# %%
# Смотрим строки с пропусками
df[df['airports_nearest'].isna()].head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 5             10     2890000       30.40           2018-09-10      1
# 8             20     2900000       33.16           2018-05-23      1
# 12            10     3890000       54.00           2016-06-30      2
# 22            20     5000000       58.00           2017-04-24      2
# 30            12     2200000       32.80           2018-02-19      1
# 37            10     1990000       45.80           2017-10-28      2
# 38            10     3150000       40.00           2018-03-29      1
# 47            17     3600000       56.10           2018-10-18      3
# 60             3     2740000       35.00           2018-01-01      1
# 62             0     4800000       78.60           2017-09-17      3
# 64            13     3100000       44.30           2017-11-07      2
# 66             6     3450000       34.00           2015-12-16      1
# 68            11     4150000       74.00           2017-08-04      3
# 69             6     4010000       50.70           2018-09-16      2
# 76            12     2800000       55.10           2016-05-14      3
# 79            12     2590000       55.70           2017-12-18      3
# 80             8     4050000       79.10           2018-02-23      3
# 81             9    10949000       68.00           2018-12-27      1
# 84            11     2400000       43.90           2019-03-13      2
# 88             0     1700000       33.10           2019-04-09      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 5             2.65            12        14.40      5         False  ...
# 8             2.65            27        15.40     26         False  ...
# 12            2.65             5        30.00      5         False  ...
# 22            2.75            25        30.00     15         False  ...
# 30            2.65             9        18.60      2         False  ...
# 37            2.50             5        26.00      1         False  ...
# 38            2.75            18        16.30      9         False  ...
# 47            2.65             4        42.50      3         False  ...
# 60            2.65            12        19.90      8         False  ...
# 62            2.80             9        48.80      5         False  ...
# 64            2.50             5        29.00      5         False  ...
# 66            2.60            17        17.40      8         False  ...
# 68            2.80             5        44.00      1         False  ...
# 69            2.60             5        28.90      5         False  ...
# 76            2.60             5        38.40      1         False  ...
# 79            2.50             4        42.60      4         False  ...
# 80            3.00            15        45.20      1         False  ...
# 81            2.65            10        38.60      6         False  ...
# 84            2.65             2        27.50      1         False  ...
# 88            2.65             5        18.40      1         False  ...
#
#     kitchen_area  balcony                        locality_name  \
# 5           9.10        0            городской поселок Янино-1
# 8           8.80        0                       поселок Мурино
# 12          9.00        0                            Сертолово
# 22         11.00        2                      деревня Кудрово
# 30          5.70        0                             Коммунар
# 37          7.90        0  поселок городского типа Красный Бор
# 38         11.60        0                       поселок Мурино
# 47          5.70        1                              Гатчина
# 60          6.00        0                       поселок Мурино
# 62         11.90        2                            Сертолово
# 64          5.30        0                              Гатчина
# 66         11.50        2                       поселок Мурино
# 68          8.00        2                  деревня Федоровское
# 69          9.00        2                               Выборг
# 76          4.90        0                              Кировск
# 79          7.00        0                              Кировск
# 80         12.00        1              деревня Новое Девяткино
# 81         11.70        0                      Санкт-Петербург
# 84          5.20        0                              Кировск
# 88          6.40        0      поселок городского типа Лебяжье
#
#     airports_nearest cityCenters_nearest  parks_around3000  parks_nearest  \
# 5                nan                 nan               nan            nan
# 8                nan                 nan               nan            nan
# 12               nan                 nan               nan            nan
# 22               nan                 nan               nan            nan
# 30               nan                 nan               nan            nan
# 37               nan                 nan               nan            nan
# 38               nan                 nan               nan            nan
# 47               nan                 nan               nan            nan
# 60               nan                 nan               nan            nan
# 62               nan                 nan               nan            nan
# 64               nan                 nan               nan            nan
# 66               nan                 nan               nan            nan
# 68               nan                 nan               nan            nan
# 69               nan                 nan               nan            nan
# 76               nan                 nan               nan            nan
# 79               nan                 nan               nan            nan
# 80               nan                 nan               nan            nan
# 81               nan                 nan               nan            nan
# 84               nan                 nan               nan            nan
# 88               nan                 nan               nan            nan
#
#     ponds_around3000  ponds_nearest  days_exposition
# 5                nan            nan            55.00
# 8                nan            nan           189.00
# 12               nan            nan            90.00
# 22               nan            nan            60.00
# 30               nan            nan            63.00
# 37               nan            nan           196.00
# 38               nan            nan           103.00
# 47               nan            nan           179.00
# 60               nan            nan            11.00
# 62               nan            nan             5.00
# 64               nan            nan           143.00
# 66               nan            nan           186.00
# 68               nan            nan           234.00
# 69               nan            nan           194.00
# 76               nan            nan           606.00
# 79               nan            nan           463.00
# 80               nan            nan           235.00
# 81               nan            nan              nan
# 84               nan            nan              nan
# 88               nan            nan              nan
#
# [20 rows x 22 columns]

# %% [markdown]
# По полученным данным видим, что картографические данные пропущены без привязки к населенному пункту, встречаются и в самом Санкт-Петербурге. Восстановить или заменить пропуски не получится, недостаточно данных, оставим все как есть.
#
# Проверим столбцы на аномальные значения

# %%
# числовое описание столбца
df['airports_nearest'].describe()
# Out:
# count   18144.00
# mean    28794.71
# std     12634.03
# min         0.00
# 25%     18581.00
# 50%     26726.00
# 75%     37284.00
# max     84869.00
# Name: airports_nearest, dtype: float64

# %%
# смотрим график
df['airports_nearest'].hist(figsize = (12,4), bins = 100);

# %%
# смотрим маленькие значения
df['airports_nearest'].hist(figsize = (12,4), range=(0,6000),bins=50);

# %% [markdown]
# Видим, что есть значение "0", посмотрим эти значения

# %%
# строки с маленьким значением
df.query('airports_nearest < 6000')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 21075             0     7000000       34.70           2018-09-23      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 21075            2.70             9        19.80      3         False  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 21075          6.00        2  Санкт-Петербург              0.00
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 21075            22801.00              0.00            nan              0.00
#
#        ponds_nearest  days_exposition
# 21075            nan            60.00
#
# [1 rows x 22 columns]

# %% [markdown]
# Всего 1 строка заменим её на NaN

# %%
# Меняем значение"0" на NaN
df.loc[df['airports_nearest'] < 1, 'airports_nearest'] = np.nan

# %% [markdown]
# Расстояние измеряется в метрах, заменим тип данных на целочисленный

# %%
# меняем тип данных
df['airports_nearest'] = df['airports_nearest'].astype('Int64')

# %% [markdown]
# **Столбец `cityCenters_nearest`**

# %%
# числовое описание стлобца
df['cityCenters_nearest'].describe()
# Out:
# count   18167.00
# mean    14195.04
# std      8609.20
# min       181.00
# 25%      9238.00
# 50%     13101.00
# 75%     16293.00
# max     65968.00
# Name: cityCenters_nearest, dtype: float64

# %%
# смотрим график
df['cityCenters_nearest'].hist(figsize = (12,4), bins = 100);

# %% [markdown]
# В этом столбце аномальных значений нет.

# %% [markdown]
# **Столбец `parks_around3000`**

# %%
# числовое описание столбца
df['parks_around3000'].describe()
# Out:
# count   18168.00
# mean        0.61
# std         0.80
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         1.00
# max         3.00
# Name: parks_around3000, dtype: float64

# %%
# смотрим уникальные значения
df['parks_around3000'].value_counts()
# Out:
# 0.00    10102
# 1.00     5675
# 2.00     1745
# 3.00      646
# Name: parks_around3000, dtype: int64

# %% [markdown]
# Большинство значений "0" вероятно - если парка в радиусе 3 км нет, ставился "0",  можно заменить пропуски в этом столбце на "0".

# %%
# Меняем пропуски на "0"
df['parks_around3000'] = df['parks_around3000'].fillna(0)

# %%
# меняем тип данных на целочисленный
df['parks_around3000'] = df['parks_around3000'].astype('int')

# %% [markdown]
# **Столбец `parks_nearest`**

# %%
# числовое описание столбца
df['parks_nearest'].describe()
# Out:
# count   8070.00
# mean     490.74
# std      342.43
# min        1.00
# 25%      288.00
# 50%      454.50
# 75%      612.00
# max     3190.00
# Name: parks_nearest, dtype: float64

# %%
# смотрим график
df['parks_nearest'].hist(figsize = (12,4), bins = 100);

# %%
# меняем тип данных 
df['parks_nearest'] = df['parks_nearest'].astype('Int64')

# %% [markdown]
# В этом столбце аномальных значений нет.

# %% [markdown]
# **Столбец `ponds_around3000`**

# %%
# числовое описание столбца
df['ponds_around3000'].describe()
# Out:
# count   18168.00
# mean        0.77
# std         0.94
# min         0.00
# 25%         0.00
# 50%         1.00
# 75%         1.00
# max         3.00
# Name: ponds_around3000, dtype: float64

# %%
# смотрим уникальные значения
df['ponds_around3000'].value_counts()
# Out:
# 0.00    9069
# 1.00    5714
# 2.00    1888
# 3.00    1497
# Name: ponds_around3000, dtype: int64

# %% [markdown]
# Также как и в столбце `parks_around3000`,  большинство значений "0", заменим пропуски на "0"

# %%
# Меняем пропуски на "0"
df['ponds_around3000'] = df['ponds_around3000'].fillna(0)

# %%
# меняем тип данных на целочисленный
df['ponds_around3000'] = df['ponds_around3000'].astype('int')

# %% [markdown]
# **Столбец `ponds_nearest`**

# %%
# числовое описание столбца
df['ponds_nearest'].describe()
# Out:
# count   9099.00
# mean     518.15
# std      277.74
# min       13.00
# 25%      294.00
# 50%      503.00
# 75%      730.00
# max     1344.00
# Name: ponds_nearest, dtype: float64

# %%
# смотрим график
df['ponds_nearest'].hist(figsize = (12,4), bins = 100);

# %%
# меняем тип данных на целочисленный
df['ponds_nearest'] = df['ponds_nearest'].astype('Int64')

# %% [markdown]
# Аномальных значений нет

# %% [markdown]
# #### Поиск дубликатов

# %%
df.duplicated().sum()
# смотрим количество дубликатов
# Out:
# 0

# %% [markdown]
# Явных дубликатов не найдено.Посмотрим есть ли дубликаты по нескольким столбцам, по которым  совпадения маловероятны.

# %%
df[df[['total_images', 'last_price','first_day_exposition','total_area']].duplicated(keep=False)].sort_values(by='last_price')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 9658              1     2533531       42.50           2016-09-08      1
# 18417             1     2533531       42.50           2016-09-08      1
# 19044             3     4370000       38.00           2016-06-23      1
# 19317             3     4370000       38.00           2016-06-23      1
# 10096            10     4400000       44.00           2017-11-22      1
# 21132            10     4400000       44.00           2017-11-22      2
# 14734            10     5142565       54.65           2018-10-01      2
# 18616            10     5142565       54.65           2018-10-01      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 9658             2.56            18        19.80      7         False  ...
# 18417            2.56            18        20.00     10         False  ...
# 19044            2.65             9        19.50      1         False  ...
# 19317            2.65             9        21.60      2         False  ...
# 10096            2.65            17        17.00     14         False  ...
# 21132            2.65             9        27.00      8         False  ...
# 14734            2.65             5        26.00      3         False  ...
# 18616            2.65             5        26.00      5         False  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 9658           7.30        0       Никольское               NaN
# 18417          7.30        0       Никольское               NaN
# 19044          6.60        0  Санкт-Петербург             27103
# 19317          6.60        0  Санкт-Петербург             27103
# 10096         13.00        2  Санкт-Петербург             42901
# 21132          6.00        1  Санкт-Петербург             49917
# 14734          9.40        0  Санкт-Петербург             47303
# 18616          9.40        0  Санкт-Петербург             47303
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 9658                  nan                 0            NaN                 0
# 18417                 nan                 0            NaN                 0
# 19044             7640.00                 1            624                 0
# 19317             7640.00                 1            624                 0
# 10096             9267.00                 0            NaN                 0
# 21132            16755.00                 1            235                 0
# 14734            25866.00                 1            251                 1
# 18616            25866.00                 1            251                 1
#
#        ponds_nearest  days_exposition
# 9658             NaN           627.00
# 18417            NaN           627.00
# 19044            NaN           620.00
# 19317            NaN           620.00
# 10096            NaN            71.00
# 21132            NaN            72.00
# 14734            350           145.00
# 18616            350           145.00
#
# [8 rows x 22 columns]

# %% [markdown]
# Итак, видим что есть совпадения. В строках 9658 и 18417 немного различается жилая площадь и этаж, скорее всего разные квартиры. Строки 19044 и 19317 - также различия в жилой площади и этаже, остальные также отличаются в жилой площади и этаже. Будем считать  эти квартиры разными квартирами.

# %%
# общая информация
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23684 entries, 0 to 23685
# Data columns (total 22 columns):
# total_images            23684 non-null int64
# last_price              23684 non-null int32
# total_area              23684 non-null float64
# first_day_exposition    23684 non-null datetime64[ns]
# rooms                   23684 non-null int64
# ceiling_height          23684 non-null float64
# floors_total            23598 non-null Int64
# living_area             23684 non-null float64
# floor                   23684 non-null int64
# is_apartment            23684 non-null bool
# studio                  23684 non-null bool
# open_plan               23684 non-null bool
# kitchen_area            23537 non-null float64
# balcony                 23684 non-null int32
# locality_name           23684 non-null object
# airports_nearest        18143 non-null Int64
# cityCenters_nearest     18167 non-null float64
# parks_around3000        23684 non-null int32
# parks_nearest           8070 non-null Int64
# ponds_around3000        23684 non-null int32
# ponds_nearest           9099 non-null Int64
# days_exposition         20503 non-null float64
# dtypes: Int64(4), bool(3), datetime64[ns](1), float64(6), int32(4), int64(3), object(1)
# memory usage: 4.0+ MB

# %% [markdown]
# #### Результат предобработки данных

# %% [markdown]
# Предобработка обнаружила несколько проблем в данных:
# - пропущенные значения
# - аномальные значения
# - разные формы написания слова поселок.
#
# В столбце `ceiling_height` пропуски заменены медианами, аномальные значения удалены. Предположительные опечатки исправили на логически верные значения.
#
# В столбцах `living_area` и `kitchen_area` пропуски заменены на медианные, аномально маленькие значения удалены, так же учтены квартиры студии их 147, - в строках где студии в столбце `kitchen_area` оставлено NaN. Изменили тип данных в числовых столбцах и столбце с датой.
#
# В столбце `last_price` были аномальные значения как сильно маленькие так и сильно большие. Удалили их
#
# В столбце `rooms` - присутствовали значения 0 комнат. Заменили их на подходящиее значение.
#
# В столбце `locality_name` - были обнаружены значения где "поселок" написан с буквой "ё" - исправлено.
#
# В столбцах с расстояниями airports_nearest, cityCenters_nearest, parks_nearest, ponds_nearest было обнаружено, что значения отсутствуют во всех 4 столбцах. Поэтому заполнить пропуски получилось по минимуму,  только в двух столбцах.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# ### Цена квадратного метра

# %%
# добавляем столбец с ценой кв. метра и сразу меняем тип данных
df['price_square_meter'] = (df['last_price'] / df['total_area']).astype(int)

# %%
# смотрим таблицу
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000      108.00           2019-03-07      3
# 1             7     3350000       40.40           2018-12-04      1
# 2            10     5196000       56.00           2015-08-20      2
# 3             0    64900000      159.00           2015-07-24      3
# 4             2    10000000      100.00           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16        51.00      8         False  ...
# 1            2.65            11        18.60      1         False  ...
# 2            2.65             5        34.30      4         False  ...
# 3            2.65            14        90.20      9         False  ...
# 4            3.03            14        32.00     13         False  ...
#
#    balcony    locality_name  airports_nearest  cityCenters_nearest  \
# 0        0  Санкт-Петербург             18863             16028.00
# 1        2   поселок Шушары             12817             18603.00
# 2        0  Санкт-Петербург             21741             13933.00
# 3        0  Санкт-Петербург             28098              6800.00
# 4        0  Санкт-Петербург             31856              8098.00
#
#   parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 0                1            482                 2            755
# 1                0            NaN                 0            NaN
# 2                1             90                 2            574
# 3                2             84                 3            234
# 4                2            112                 1             48
#
#    days_exposition  price_square_meter
# 0              nan              120370
# 1            81.00               82920
# 2           558.00               92785
# 3           424.00              408176
# 4           121.00              100000
#
# [5 rows x 23 columns]

# %% [markdown]
# ### День недели, месяц и год публикации объявления

# %%
# добавляем столбец с днём недели пудликации
df['public_day'] = df['first_day_exposition'].dt.weekday

# %%
# добавляем столбец  с месяцем публикации
df['public_month'] = df['first_day_exposition'].dt.month

# %%
# добавляем столбец с годом публикации
df['public_year'] = df['first_day_exposition'].dt.year

# %%
# смотрим таблицу
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000      108.00           2019-03-07      3
# 1             7     3350000       40.40           2018-12-04      1
# 2            10     5196000       56.00           2015-08-20      2
# 3             0    64900000      159.00           2015-07-24      3
# 4             2    10000000      100.00           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16        51.00      8         False  ...
# 1            2.65            11        18.60      1         False  ...
# 2            2.65             5        34.30      4         False  ...
# 3            2.65            14        90.20      9         False  ...
# 4            3.03            14        32.00     13         False  ...
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0             16028.00                 1            482                 2
# 1             18603.00                 0            NaN                 0
# 2             13933.00                 1             90                 2
# 3              6800.00                 2             84                 3
# 4              8098.00                 2            112                 1
#
#   ponds_nearest  days_exposition  price_square_meter  public_day  \
# 0           755              nan              120370           3
# 1           NaN            81.00               82920           1
# 2           574           558.00               92785           3
# 3           234           424.00              408176           4
# 4            48           121.00              100000           1
#
#    public_month  public_year
# 0             3         2019
# 1            12         2018
# 2             8         2015
# 3             7         2015
# 4             6         2018
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Этаж квартиры; варианты — первый, последний, другой

# %%
# Функция возвращает категории этажей
def floor_category(row):
    if row['floor']==1:
        return 'первый'
    elif row['floor']==row['floors_total']:
        return 'последний'
    else:
        return 'другой'
    
# добавляем в новый столбец результат работы функции
df['floor_category'] = df.apply(floor_category, axis=1)

# %%
# смотрим уникальные значения в новом столбце
df['floor_category'].value_counts()
# Out:
# другой       17437
# последний     3331
# первый        2916
# Name: floor_category, dtype: int64

# %% [markdown]
# ### Соотношение жилой и общей площади, а также отношение площади кухни к общей

# %%
# соотношение жилой и общей площади
df['living_ratio'] = round(df['living_area'] / df['total_area'],2)

# %%
# соотношение площади кухни к общей
df['kitchen_ratio'] = round(df['kitchen_area'] / df['total_area'],2)

# %%
# смотрим таблицу
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000      108.00           2019-03-07      3
# 1             7     3350000       40.40           2018-12-04      1
# 2            10     5196000       56.00           2015-08-20      2
# 3             0    64900000      159.00           2015-07-24      3
# 4             2    10000000      100.00           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16        51.00      8         False  ...
# 1            2.65            11        18.60      1         False  ...
# 2            2.65             5        34.30      4         False  ...
# 3            2.65            14        90.20      9         False  ...
# 4            3.03            14        32.00     13         False  ...
#
#    ponds_around3000  ponds_nearest  days_exposition  price_square_meter  \
# 0                 2            755              nan              120370
# 1                 0            NaN            81.00               82920
# 2                 2            574           558.00               92785
# 3                 3            234           424.00              408176
# 4                 1             48           121.00              100000
#
#   public_day  public_month  public_year  floor_category  living_ratio  \
# 0          3             3         2019          другой          0.47
# 1          1            12         2018          первый          0.46
# 2          3             8         2015          другой          0.61
# 3          4             7         2015          другой          0.57
# 4          1             6         2018          другой          0.32
#
#    kitchen_ratio
# 0           0.23
# 1           0.27
# 2           0.15
# 3           0.17
# 4           0.41
#
# [5 rows x 29 columns]

# %% [markdown]
# Добавили все необходимые столбцы

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Время продажи квартиры

# %% [markdown]
# Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
# смотрим общий график
df['days_exposition'].hist(figsize=(12,4), bins=100);

# %%
# смотрим значения до 100 дней
df['days_exposition'].hist(range=(0,100),figsize=(12,4), bins=100);

# %%
# смотрим значения от 100 дней до 400
df['days_exposition'].hist(range=(100,400),figsize=(12,4), bins=100);

# %%
# смотрим значения от 400 дней
df['days_exposition'].hist(range=(400,1600),figsize=(12,4), bins=100);

# %%
print('Медиана =', df['days_exposition'].median())
print('Среднее =', df['days_exposition'].mean())
# Out:
# Медиана = 95.0
# Среднее = 180.9277178949422

# %% [markdown]
# На графиках видим, что есть аномальные выбросы количества объявлений со сроком публикации в 45 и 60 дней, так же наблюдается повышенное значение на 90 днях. Скорее всего это объявления, автоматически снятые с публикации по истечении срока размещения.

# %% [markdown]
# Из полученных данных видим, что большее число продаж совершается от 90 до 200 дней примммерно 6-7 месяцев. Это подтверждает среднее значение в 180 дней. Быстрой продажей можно назвать продажи до 45 дней -первый пик 2 гистограммы. Необычайно долгие продажи начинаются от 2 лет - нижняя гистограмма

# %%
# смотрим значения до 300 дней с ограничением по оси y для исключения влияния выбросов
df['days_exposition'].plot.hist(ylim=(0,600), range=(0,300),figsize=(12,4), bins=150);

# %%
# смотрим значения до 60 дней с ограничением по оси y для исключения влияния выбросов
df['days_exposition'].plot.hist(ylim=(0,300), range=(0,60),figsize=(12,4), bins=60);

# %% [markdown]
# По полученным данным видим, что первые два дня завершённых объявлений практически нет, а начиная с третьего дня их количество уходит в усреднённый максимум, и, затем, происходит плавное снижение на протяжении всего срока объявлений без явных скачков, за исключением дней, соответствующих завершению определённых периодов(7 дней, 30, 45, 60, 90)

# %%
# числовое описание столбца
df['days_exposition'].describe()
# Out:
# count   20503.00
# mean      180.93
# std       219.78
# min         1.00
# 25%        45.00
# 50%        95.00
# 75%       232.00
# max      1580.00
# Name: days_exposition, dtype: float64

# %% [markdown]
# Можно считать что продажи прошли очень быстро, если  объявление было снято с публикации до 45 дней, а если объевление снято после 240 дней, тогда продажи прошли необычно долго. Предположим, что обычно продажа занимает от 95 до 180 дней.

# %% [markdown]
# ### Зависимость стоимости от различных факторов

# %% [markdown]
# Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.

# %% [markdown]
# #### Зависимость цены от площади

# %%
df.plot(x='total_area', y='last_price', kind='scatter', grid=True, figsize=(12,4), alpha=0.5);

# %%
# коэффициент корреляции Пирсона
df['last_price'].corr(df['total_area'])
# Out:
# 0.7190155492593442

# %% [markdown]
# По полученным данным видим, что зависимость цены от площади есть. При возрастании площади, возрастает цена.

# %% [markdown]
# #### Зависимость цены от количества комнат

# %%
df.plot(x='rooms', y='last_price', kind='scatter', grid=True, figsize=(12,4), alpha=0.5);

# %%
# коэффициент корреляции Пирсона
df['last_price'].corr(df['rooms'])
# Out:
# 0.4191332669000307

# %% [markdown]
# Видим, что зависимость цены от количества комнат есть, это и понятно, чем больше комнат, тем больше площадь, тем выше цена, цена возрастает от 1 до 3 комнат, далее начинает постепенно снижаться. Как показывает  жизненный опыт продать квартиру с большим числом комнат сложнее, так как за неё необходимо платить большую коммунальную плату, поэтому люди чаще предпочитают квартиры не большие.

# %% [markdown]
# #### Зависимость цены от удалённости от центра

# %%
df.plot(x='cityCenters_nearest', y='price_square_meter', kind='scatter', grid=True, figsize=(12,4), alpha=0.5);

# %%
# коэффициент корреляции Пирсона
df['price_square_meter'].corr(df['cityCenters_nearest'])
# Out:
# -0.33818913741387785

# %% [markdown]
# Видим, что зависимость цены за квадратный метр от растояния до центра есть,  ближе к центру квартиры значительно дороже остальных, на расстоянии 5-6 км  есть не большой подьем стоимости, потом цена снижается. Также можно отметить что на расстоянии 45-55 км большое количество объевлений, по карте там Гатчина.

# %% [markdown]
# #### Зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом

# %%
# Вычислим среднюю цену в каждой категории 
category_floor_mean = df.groupby('floor_category')['last_price'].mean();

# %%
category_floor_mean.plot(x='floor_category', y='last_price', kind='bar', grid=True, figsize=(6,5));

# %% [markdown]
# По графику видим - первый этаж самый дешёвый, средняя цена ниже всех. Полы  холодные видимо, не любят первый этаж))) Более предпочтителен последний этаж, не большая разница с другими этажами. Зависимость цены от этажа прослеживается.

# %% [markdown]
# #### Изучите зависимость от даты размещения: дня недели, месяца и года.

# %%
# Вычислим среднюю цену в каждой категории 
public_day_median = df.groupby('public_day')['last_price'].median();

# %%
public_day_median.plot(x='public_month', y='last_price', kind='bar', grid=True, figsize=(12,4));

# %%
df.plot(x='public_day', y='last_price', kind='scatter', grid=True, figsize=(12,4), alpha=0.5);

# %%
# коэффициент корреляции Пирсона
df['last_price'].corr(df['public_day'])
# Out:
# -0.002635122062637365

# %%
# Вычислим среднюю цену в каждой категории 
public_month_median = df.groupby('public_month')['last_price'].median();

# %%
public_month_median.plot(x='public_month', y='last_price', kind='bar', grid=True, figsize=(12,4));

# %%
df.plot(x='public_month', y='last_price', kind='scatter', grid=True, figsize=(12,4), alpha=0.5);

# %%
# коэффициент корреляции Пирсона
df['last_price'].corr(df['public_month'])
# Out:
# -0.001380622983316004

# %%
# Вычислим среднюю цену в каждой категории 
public_year_median = df.groupby('public_year')['last_price'].median();

# %%
public_year_median.plot(x='public_year', y='last_price', kind='bar', grid=True, figsize=(12,4));

# %%
df.plot(x='public_month', y='last_price', kind='scatter', grid=True, figsize=(12,4), alpha=0.5);

# %%
# коэффициент корреляции Пирсона
df['last_price'].corr(df['public_year'])
# Out:
# -0.0511545202796594

# %% [markdown]
# Зависимость цены от дня недели и месяца размещения объявления не прослеживается. Видим, что есть зависимость цены от года максимальная цена была в 2014 году, далее цена начала снижаться до 2016 года. В 16-17-18 цена практически не менялась, в 19 начала расти.

# %% [markdown]
# **Вывод**
#
# По полученным данным видим, что больше всего на стоимость квартиры влияет её площадь,  при возрастании площади, возрастает цена. Среднее влияние оказывает удаленность от центра и количество комнат особенно хорошо видна зависимость на отрезке 1-3 комнаты. Также надо отметить, что есть зависимость от этажа - средняя цена квартир на первом этаже заметно ниже, чем на других и последнем этаже. Дата размещения не оказывает влияния на цену.

# %% [markdown]
# ### Анализ по населенным пунктам

# %% [markdown]
# Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.

# %% [markdown]
# Сгруппируем данные по количеству объявлений и стоимости квадратного метра

# %%
top10_locality_name = df.groupby('locality_name')['price_square_meter'].agg(['count', 'mean']).sort_values(by='count', ascending=False).head(10)
top10_locality_name.columns = ['count', 'price_square_meter']
top10_locality_name
# Out:
#                    count  price_square_meter
# locality_name
# Санкт-Петербург    15708           114501.86
# поселок Мурино       555            85653.16
# поселок Шушары       440            78676.90
# Всеволожск           398            68654.01
# Пушкин               369           103125.37
# Колпино              338            75424.15
# поселок Парголово    327            90175.49
# Гатчина              307            68745.69
# деревня Кудрово      299            92473.09
# Выборг               237            58141.49

# %% [markdown]
# Найдем населённый пункт с самой низкой стоимостью за квадратный метр.

# %%
# Населённый пункт, где cамая низкая стоимость жилья
top10_locality_name.loc[top10_locality_name['price_square_meter']==top10_locality_name['price_square_meter'].min()]
# Out:
#                count  price_square_meter
# locality_name
# Выборг           237            58141.49

# %% [markdown]
# Теперь с самой высокой стоимостью за квадратный метр

# %%
# Населённый пункт, где cамая высокая стоимость жилья
top10_locality_name.loc[top10_locality_name['price_square_meter']==top10_locality_name['price_square_meter'].max()]
# Out:
#                  count  price_square_meter
# locality_name
# Санкт-Петербург  15708           114501.86

# %% [markdown]
# Самое большое количество объявлений в Санкт- Петербурге в нем же и самые дорогие квартиры. Самые дешёвые квартиры в выборке из 10 самых популярных населённых пунктов в Выборге.

# %% [markdown]
# ### Поиск центральной зоны

# %% [markdown]
# Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (locality_name). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.

# %%
locality_spb = df.loc[df['locality_name']=='Санкт-Петербург',['last_price', 'cityCenters_nearest']].reset_index(drop=True) 
locality_spb['cityCenters_km'] = (locality_spb['cityCenters_nearest']/1000).round()
locality_spb.head(10)
# Out:
#    last_price  cityCenters_nearest  cityCenters_km
# 0    13000000             16028.00           16.00
# 1     5196000             13933.00           14.00
# 2    64900000              6800.00            7.00
# 3    10000000              8098.00            8.00
# 4     7915000             11634.00           12.00
# 5     5400000             15008.00           15.00
# 6     5050000             13878.00           14.00
# 7     4650000             14259.00           14.00
# 8     6700000             10698.00           11.00
# 9     4180000             14616.00           15.00

# %%
prices_km = locality_spb.pivot_table(index='cityCenters_km', values='last_price', aggfunc='mean')
prices_km.head(10)
# Out:
#                 last_price
# cityCenters_km
# 0.00           31449115.85
# 1.00           19590002.09
# 2.00           16547181.49
# 3.00           11126581.00
# 4.00           12213019.38
# 5.00           14188456.34
# 6.00           15248205.13
# 7.00           14775152.59
# 8.00            9260095.71
# 9.00            6962378.96

# %%
prices_km.plot(grid=True, figsize=(12,4));

# %% [markdown]
# По полученным данным видим, что чем ближе к центру тем выше цена, квартиры на расстоянии 0-2 км  самые дорогие (примерно от 17 до 32 млн), далее идет снижение цены до 12 млн (судя по картам на таком расстоянии появляются как промзоны, так и старые районы советской застройки возможно из-за этого снижение цен), а затем наблюдается повышение цен на расстоянии от 5 до 7 км от центра от 12 до 15 млн - из-за появления на этом расстоянии современной элитной застройки - ближе к центру нельзя - историческая зона. Определим границу центра все что в радиусе 2 км это "Центр-прям центр" Санкт-Петербурга, а центральной зоной можно назвать расстояние до 7 км.

# %% [markdown]
# ###  Сравнение центра города со всеми объявлениями в городе

# %% [markdown]
# Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?

# %% [markdown]
# Выделим сигмент квартир в центре и по всему городу

# %%
# Сегмент квартир в центре
spb_center = df.query('cityCenters_nearest <= 7000 ')
spb_center.head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 3              0    64900000      159.00           2015-07-24      3
# 24             8     6500000       97.20           2015-10-31      2
# 35             6    15500000      149.00           2017-06-26      5
# 51             7    45000000      161.00           2017-10-17      3
# 52            20    11795000      136.00           2017-09-22      6
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 3             2.65            14        90.20      9         False  ...
# 24            2.65             3        46.50      1         False  ...
# 35            2.65             5       104.00      4         False  ...
# 51            3.20             8        38.00      4         False  ...
# 52            3.00             2        94.00      2         False  ...
#
#     ponds_around3000  ponds_nearest  days_exposition  price_square_meter  \
# 3                  3            234           424.00              408176
# 24                 3            124           265.00               66872
# 35                 1            779           644.00              104026
# 51                 3             99           541.00              279503
# 52                 0            NaN              nan               86727
#
#    public_day  public_month  public_year  floor_category  living_ratio  \
# 3           4             7         2015          другой          0.57
# 24          5            10         2015          первый          0.48
# 35          0             6         2017          другой          0.70
# 51          1            10         2017          другой          0.24
# 52          4             9         2017       последний          0.69
#
#     kitchen_ratio
# 3            0.17
# 24           0.20
# 35           0.11
# 51           0.31
# 52           0.08
#
# [5 rows x 29 columns]

# %%
# Сегмент квартир по всему городу
spb = df.query(' locality_name == "Санкт-Петербург" ') 
spb.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000      108.00           2019-03-07      3
# 2            10     5196000       56.00           2015-08-20      2
# 3             0    64900000      159.00           2015-07-24      3
# 4             2    10000000      100.00           2018-06-19      2
# 7             5     7915000       71.60           2019-04-18      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16        51.00      8         False  ...
# 2            2.65             5        34.30      4         False  ...
# 3            2.65            14        90.20      9         False  ...
# 4            3.03            14        32.00     13         False  ...
# 7            2.65            24        40.60     22         False  ...
#
#    ponds_around3000  ponds_nearest  days_exposition  price_square_meter  \
# 0                 2            755              nan              120370
# 2                 2            574           558.00               92785
# 3                 3            234           424.00              408176
# 4                 1             48           121.00              100000
# 7                 0            NaN              nan              110544
#
#   public_day  public_month  public_year  floor_category  living_ratio  \
# 0          3             3         2019          другой          0.47
# 2          3             8         2015          другой          0.61
# 3          4             7         2015          другой          0.57
# 4          1             6         2018          другой          0.32
# 7          3             4         2019          другой          0.57
#
#    kitchen_ratio
# 0           0.23
# 2           0.15
# 3           0.17
# 4           0.41
# 7           0.26
#
# [5 rows x 29 columns]

# %% [markdown]
# Изучим площадь, цену, число комнат, высоту потолков в обоих сегментах.

# %%
#  Цикл рисует графики для обоих сегментов  по необходимым параметрам
for column in ['total_area','last_price', 'rooms', 'ceiling_height']:
    spb_center.plot(y=column, kind='hist', grid=True, figsize=(12,4),\
                    bins=100, alpha=0.9, legend=True, label='СПБ центр - '+column);
    spb.plot(y=column, kind='hist', grid=True, figsize=(12,4), bins=100, alpha=0.5, legend=True, label='СПБ - '+column);
    plt.show()

# %% [markdown]
# По полученным данным видим, что доля квартир с большой площадью в центре значительно выше, чем по всему Санкт-Петербургу, и в центре квартиры дороже. В центральной зане чаще продают 2 и 3 комнатные кварты, по городу 1 и 2 комнатные квартиры. (2 комнатные квартиры любят везде) В центре больше квартир с высокими потолками.

# %% [markdown]
# Выделим факторы, которые влияют на стоимость квартиры число комнат, этаж, удалённость от центра, дата размещения объявления, и сравним весь город  и центр

# %% [markdown]
# Проверим влияет ли удалённость от центра на стоимость квартиры

# %%
# в центре
spb_center.plot(x='cityCenters_nearest', y='price_square_meter', kind='scatter', grid=True, figsize=(12,4), alpha=0.5);

# %%
# коэффициент корреляции Пирсона
spb_center['price_square_meter'].corr(spb_center['cityCenters_nearest'])
# Out:
# -0.017044897934205733

# %%
# во всем городе
spb.plot(x='cityCenters_nearest', y='price_square_meter', kind='scatter', grid=True, figsize=(12,4), alpha=0.5);

# %%
# коэффициент корреляции Пирсона
spb['price_square_meter'].corr(spb['cityCenters_nearest'])
# Out:
# -0.33139499904401837

# %% [markdown]
# Видим, что в центре зависимость центы от растояния практически нет, а вот во всем городе есть.

# %% [markdown]
# Проверим влияет ли числокомнат на стоимость квартир.

# %%
# в центре
spb_center.plot(x='rooms', y='last_price', kind='scatter', grid=True, figsize=(12,4), alpha=0.5);

# %%
# коэффициент корреляции Пирсона
spb_center['last_price'].corr(spb_center['rooms'])
# Out:
# 0.3609058293778134

# %%
# во всем городе
spb.plot(x='rooms', y='last_price', kind='scatter', grid=True, figsize=(12,4), alpha=0.5);

# %%
# коэффициент корреляции Пирсона
spb['last_price'].corr(spb['rooms'])
# Out:
# 0.429730754191473

# %% [markdown]
# Количество комнат в центре и в городе практически одинаковое в городе чуть-чуть больше.

# %% [markdown]
# Проверим влияет ли этаж на стоимость квартир

# %%
# Вычислим среднюю цену в каждой категории этажей
category_floor_mean_spb_center = spb_center.groupby('floor_category')['last_price'].mean();

# %%
# в центре
category_floor_mean_spb_center.plot(x='floor_category', y='last_price', kind='bar', grid=True, figsize=(6,5));

# %%
# Вычислим среднюю цену в каждой категории этажей
category_floor_mean_spb = spb.groupby('floor_category')['last_price'].mean();

# %%
# весь город
category_floor_mean_spb.plot(x='floor_category', y='last_price', kind='bar', grid=True, figsize=(6,5));

# %% [markdown]
# Тут разница не наблюдается, также как и по всем квартирам во всех населенных пунктах, в центре Санкт-Петербурга и во всем городе первый этаж самый дешёвый, последний этаж самый дорогой.

# %% [markdown]
# Проверим влияет ли дата размещения на стоимость квартиры.

# %%
spb_center.plot(x='public_day', y='last_price', kind='scatter', grid=True, figsize=(12,4), alpha=0.5);

# %%
# коэффициент корреляции Пирсона
spb_center['last_price'].corr(df['public_day'])
# Out:
# 0.018470428469953393

# %%
spb.plot(x='public_day', y='last_price', kind='scatter', grid=True, figsize=(12,4), alpha=0.5);

# %%
# коэффициент корреляции Пирсона
spb['last_price'].corr(df['public_day'])
# Out:
# 0.0020572886530934335

# %% [markdown]
# День никак не влияет на стоимость квартиры.

# %%
spb_center.plot(x='public_month', y='last_price', kind='scatter', grid=True, figsize=(12,4), alpha=0.5);

# %%
# коэффициент корреляции Пирсона
spb_center['last_price'].corr(df['public_month'])
# Out:
# -0.01908325878981345

# %%
spb.plot(x='public_month', y='last_price', kind='scatter', grid=True, figsize=(12,4), alpha=0.5);

# %%
# коэффициент корреляции Пирсона
spb['last_price'].corr(df['public_month'])
# Out:
# -0.006185473124461109

# %% [markdown]
#  В каком месяце продают тоже не влияет.

# %%
# Вычислим среднюю цену в каждой категории 
spb_center_year_median = spb_center.groupby('public_year')['last_price'].median();

# %%
spb_center_year_median.plot(x='public_year', y='last_price', kind='bar', grid=True, figsize=(12,4));

# %%
spb_center.plot(x='public_year', y='last_price', kind='scatter', grid=True, figsize=(12,4), alpha=0.5);

# %%
# коэффициент корреляции Пирсона
spb_center['last_price'].corr(df['public_year'])
# Out:
# -0.04632530730548348

# %%
# Вычислим среднюю цену в каждой категории 
spb_year_median = spb_center.groupby('public_year')['last_price'].median();

# %%
spb_year_median.plot(x='public_year', y='last_price', kind='bar', grid=True, figsize=(12,4));

# %%
spb.plot(x='public_year', y='last_price', kind='scatter', grid=True, figsize=(12,4), alpha=0.5);

# %%
# коэффициент корреляции Пирсона
spb['last_price'].corr(df['public_year'])
# Out:
# -0.05313628205566023

# %% [markdown]
# Год также не влияет. Дата размещения объяыления никак не влияет на стоимость квартиры.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# На основе проведенного анализа  выявили:
#
# Больше всего квартир продаётся в Санкт-Пербрге - 15708 объявлений из 23684.
#
# Квартир с площадями 30-45 кв.м встречаются чаще всего- это, похоже, самые популярные 1 и 2-х комнатные.Сделан вывод, что больше всего квартир продаются по цене в диапазоне 2-7 млн. Пик же продажи квартир идет в по цене около 3,8 млн.
#
# Больше всего на стоимость квартиры влияет её площадь, чем больше площадь тем выше стоимость и это понятно. Среднее влияние оказывает удаленность от центра, чем дальше от центра тем дешевли квартиры,  и количество комнат от 1 до 3.Определили что есть зависимость от этажа - первый этаж  по стоимости существенно ниже чем все остальные. Также  определили, что зависимость цены от дня недели и месяца размещения объявления не прослеживается, но есть зависимость цены от года максимальная цена была в 2014 году, далее цена начала снижаться до 2016 года. В 16-17-18 цена практически не менялась, в 19 начала расти.
#
# Определили центральную зону Санкт-Петербурга до 7 км. От 0 до 2 км -  это "Самый центр" тут самые  дорогие квартиры примерно от 17 до 32 млн, далее идет снижение цены до 12 млн (судя по картам на таком расстоянии появляются как промзоны, так и старые районы советской застройки возможно из-за этого снижение цен), а затем наблюдается повышение цен на расстоянии от 5 до 7 км от центра от 12 до 15 млн - из-за появления на этом расстоянии современной элитной застройки - ближе к центру нельзя - историческая зона.
#
# В центре чаще продают кварты с большей площедью, чем во всем городе. Стоимость квартир в центре выше, чем во всем городе.
# В Центре чаще продают 2 и 3 комнатные квартиры, а по Городу  1-2 комнатные.
# Если в Городе есть зависимость от расстояния до центра, то в Центре такой зависимости нет. Центр есть центр.
